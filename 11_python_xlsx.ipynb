# %% [markdown]
# # Scrivere e creare file di Excel

# %% [markdown]
# Se stai seguendo questo corso, immagino che tu abbia già aperto un file di Excel. La maggior parte delle persone che fa lavori d'ufficio è probabile che ne apra parecchi ogni giorno. Questo perché è piuttosto facile da usare e può memorizzare molti dati in forma strutturata.
#
# Excel, e in generale tutti i software definiti come ["fogli elettronici" o "fogli di calcolo](https://it.wikipedia.org/wiki/Foglio_elettronico)" (in inglese *spreadsheet*) consentono di memorizzare dati tabellari, ovvero sotto forma di classiche tabelle, le cui celle sono individuabili dall'incrocio di una riga con una colonna.
#
# Avendo a disposizione una tabella, convenzionalmente gli utenti tendono a strutturare i dati nello stesso modo che abbiamo visto nei file CSV, ovvero una "griglia" (matrice) di dati in cui le righe rappresentano i "record", ovvero delle entità, e le colonne rappresentano delle proprietà di queste entità. In pratica in una cella viene memorizzata una specifica proprietà di una specifica entità.
#
# Purtroppo, a volte è difficile e logorante elaborare manualmente centinaia di dati, e soprattutto centinaia di file. Per questo, potremmo usare Python!
#
# Python non offre supporto per i file Excel nativamente nella libreria standard. Tuttavia esistono alcune librerie di terze parti. Con esse, è possibile creare e modificare i file Excel e in questo notebook vedremo le basi di un paio di queste librerie. Esistono anche altri strumenti per manipolare le tabelle di Excel; potete leggere di più in questa [pagina dedicata](https://www.python-excel.org/).

# %% [markdown]
# ## Perché XLSX e non CSV?
#
# - I file CSV non fanno distinzione tra tipo di dato, tutto è testo. Sta a noi convertire i dati nel tipo corretto. XLXS supporta un maggior numero di tipi di dati.
# - I dato che i file CSV sono scritti in testo semplice (*plain text*) e chiunque può aprirli con un qualunque editor di testo, possono essere facilmente corrotti e potremmo anche non accorgercene. I file XLSX hanno dei sistemi di controllo dell'errore.
# - I CSV non possono contenere formule (in modo nativo e consistente).
# - Non esiste uno standard in tutto il mondo per quanto riguarda la separazione dei valori: i paesi di lingua inglese usano la virgola, mentre in gran parte dell'europa continentale si tende ad usare il punto e virgola.
# - I file XLXS sono più facili da usare rispetto ai CSV.

# %% [markdown]
# ## Formati dei file

# %% [markdown]
# Per i file `.xlsx` (Excel 2007-oggi):
#
# - `openpyxl`: è il pacchetto più usato per leggere e scrivere file `.xlsx` utilizzando python. Ottimo per compilare i fogli di calcolo in modo "lineare", mantenendo il formato "tabellare". Se è necessario creare fogli con strutture più complesse e formattazioni, è preferibile preparare dei template che poi saranno compilati nelle parti interessate. Legge tutti i formati (`.xlsx/xlsm/xltx/xltm`).
#
# - `xlsxwriter`: un pacchetto alternativo per la lettura e la scrittura di file e la formattazione di file `.xlsx.`. È lo strumento giusto se vuoi creare da zero un file di Excel strutturato, anche in modo complesso, usando formattazioni speciali, formule e grafici.
#
#
# Per i file `.xls` (Excel 97-2003):
#
# - `xlrd`: lettura delle vecchie versioni di file Excel `.xls`.
# - `xlwt`: scrittura e formattazione delle vecchie versioni di file Excel `.xls`.

# %% [markdown]
# ## Nomenclatura Excel
#
# Seguendo la nomenclatura Microsoft, i fogli elettronici sono composti da:
#
# - Cartella di lavoro (*workbook*): è l'intero file, che può contenere più fogli.
# - Foglio di lavoro (*worksheet*): è un singolo foglio, contenuto nella cartella di lavoro.
# - Cella (*cell*): punto di incrocio tra una Riga (*row*) e una Colonna (*column*) all'interno di un Foglio di lavoro.

# %% [markdown]
# ## Spreadsheet softwares
#
# Prima di lavorare con Python su un foglio di calcolo dovresti conoscere <u>**molto bene**</u> Excel o qualunque altro software di questa categoria:
#
# - Microsoft Excel;
# - LibreOffice;
# - OpenOffice;
# - Google Fogli (Sheets)
#
# Se non sei ancora a livello "molto bene", sappi che devi innanzitutto saper fare le sequenti cose con un foglio di calcolo:
#
# **COMPILAZIONE** (immissione i dati):
# - compilare un'intera tabella usando solo la tastiera;
# - selezionare intervalli di celle, colonne, righe folgio completo;
# - copiare, tagliare, incollare:
#     - celle da altre porzioni di tabella e da altri file;
#     - fogli all'interno del file stesso e tra file diversi;
# - formattare le celle;
#     - aspetto del testo, font, dimensione, colore testo e sfondo...;
#     - formato dei dati (testo, numeri, date, valuta...);
# - inserire, rimuovere, tagliare, incollare righe e colonne;
#
# **PROGRAMMAZIONE** (logica dei calcoli):
# - scrivere riferimenti ad altre celle/intervalli e a celle/intervalli in altri fogli;
# - scrivere espressioni: scrivere formule e usare funzioni;
# - utilizzare la formattazione condizionale;
#
# > CHE BELLO!! Le macro, il linguaggio VBA o gli Office Script non ci servono! ABBIAMO PYTHON!!
#
# **MANIPOLAZIONE DATI**:
# - importare dati da CSV;
# - applicazione filtri automatici;
#     - applicazione filtro;
#     - applicazione ordinamento;
# - rimozione dei duplicati;
# - convalida dei dati;
# - creazione grafici;
#
# **VISUALIZZAZIONE, STAMPA e ESPORTAZIONE**:
# - gestire lo zoom;
# - gestione layout (normale, di pagina);
# - gestione stampa;
#     - area stampa;
#     - margini, intestazione, piè pagina;
#     - orientamento e adatta alla pagina;
# - sicurezza (blocco delle celle);
# - esportazione in PDF;
# - esportare dati in CSV;

# %% [markdown]
# ## Modulo `openpyxl`
#
# - [Sito ufficiale](https://openpyxl.readthedocs.io/en/stable/) della documentazione.
# - [Pagina su PyPi](https://pypi.org/project/openpyxl/) (Python Package Index).
# - [Repo Git](https://foss.heptapod.net/openpyxl/openpyxl).
#
# Poiché si tratta di una libreria esterna, bisogna per prima cosa installarla (meglio in un virtual enviroment):

# %% [markdown]
# ```bash
# # MAC/LINUX:
# (my_venv) $ pip install openpyxl
#
# # WINDOWS:
# (my_venv) C:\my_proj> pip install openpyxl
# ```

# %% [markdown]
# Se sei su Windows, non hai creato un virtual environment (male!;) e devi usare il `py` launcher:
#
# ```powershell
# C:\my_proj> py -m pip install docxtpl
# ```

# %% [markdown]
# ### Nomenclatura `openpyxl`
#
# Seguendo la nomenclatura di `openpyxl`, i fogli elettronici sono composti da:
#
# - oggetto di tipo `Workbook`, la *cartella di lavoro*;
# - oggetto di tipo `Worksheet`, il *foglio di lavoro*;
# - oggetto di tipo `Cell`, la *cella*.

# %% [markdown]
# ### Creare un file
#
# Ora siamo pronti a lavorare con la libreria. Vediamo dunque il processo di creazione e salvataggio di un nuovo file Excel.
#
# Prima di tutto, dobbiamo importare la classe `Workbook`, la quale ci permette di creare oggetti che fungono da [*interfaccia*](https://it.wikipedia.org/wiki/Interfaccia_(informatica)#Interfaccia_nella_programmazione_orientata_agli_oggetti) tra il nostro codice e i documenti XLSX. In altre parole, gli oggetti di tipo `Workbook` sono oggetti equipaggiati con attributi, proprietà e metodi utili per manipolare i fogli di calcolo.
#
# Come seconda cosa, dobbiamo creare una nuova cartella di lavoro (*workbook*) e salvarla in una variabile. Per impostazione predefinita, `openpyxl` (esattamente come fa Excel) crea un workbook con un unico foglio di lavoro, vuoto. Possiamo quindi usare la proprietà `Workbook.active` per accedere al foglio attivo.
#
# In questo modo creiamo l'ambiente di lavoro che utilizzeremo successivamente.

# %% [markdown]
# ```python
# from openpyxl import Workbook    # importa la classe Workbook
#
# nuovo_book = Workbook()          # crea la cartella di lavoro
# nuovo_sheet = nuovo_book.active  # seleziona il foglio di lavoro attivo
# ```

# %% [markdown]
# Dopo aver ottenuto la variabile che puntata al nostro nuovo foglio, possiamo iniziare a riempirlo di dati.
#
# Cominciamo con lo scrivere una semplice lista di parole.
#
# ### Accedere a una cella
#
# Per scrivere un dato in una cella, come su Excel, dobbiamo prima selezionarla. Abbiamo due modi per farlo:
#
# - Tramite le sue coordinate "classiche" sotto forma di stringa. È come se il foglio fosse un enorme dizionario le cui chiavi sono le coordinate di ciascuna cella. Ad esempio:
#     - `nuovo_sheet['A1']`, in cui la lettera rappresenta la colonna e il numero la riga.
#
# *oppure*
#
# - Tramite il numero di riga e di colonna, passate come argomenti al metodo `Worksheet.cell()`. Ad esempio:
#     - `nuovo_sheet.cell(row=1, column=1)`.
#
# #### Modo statico
# Il primo modo, anche se a prima vista sembra intuitivo, in realtà è abbastanza inutile. Funziona bene se abbiamo un file di Excel già in parte "preparato" (come una sorta di template) e vogliamo scrivere/leggere in punti precisi del foglio che sono stabiliti a priori. In questo modo è comoda la notazione lettera-numero, perché rispetta quella usata da Excel. Es. `'A1' -> A` (column) `1` (row). Tuttavia siamo costretti a scrivere le "coordinate" in modo hard-coded nel codice perché, anche se possibile, è poco pratico comporre le stringhe delle chiavi (lettera-numero) in modo dinamico e automatico.

# %% [markdown]
# Nel seguente esempio scriviamo il nome di 5 animali nella prima colonna del foglio attivo (che in è anche l'unico, dato che creaiamo il file "da zero"):

# %%
from openpyxl import Workbook

nuovo_book = Workbook()          # creo l'oggetto per interfacciarmi col workbook
nuovo_sheet = nuovo_book.active  # seleziono il worksheet attivo

# scrivo i dati uno alla volta
nuovo_sheet['A1'] = 'gatto'
nuovo_sheet['A2'] = 'cane'
nuovo_sheet['A3'] = 'pappagallo'
nuovo_sheet['A4'] = 'criceto'

# salvo il file (come fare un "flush")
nuovo_book.save('./files_esercizi/outputs/nuovo_file.xlsx')

# %% [markdown]
# #### Modo dinamico
# Se vogliamo automatizzare la compilazione di una tabella, il primo metodo si rivela problematico. Se dobbiamo scrivere i dati nelle celle, passando da una all'altra in modo sequenziale, useremo di probabilmente un ciclo `for`. In questo caso ci farebbero comodo degli indici numerici, uno per le righe e uno per le colonne. Il metodo `Worksheet.cell()` accetta esattamente due integer come argomenti. Es. `row=1` e `column=1`.

# %% [markdown]
# Se avete eseguito la cella precedente, ora nell'ambiente di esecuzione abbiamo l'oggetto `nuovo_book` ancora disponibile. Potremmo quindi provare ad aggiungere altri dati, ma questa volta utilizzando il metodo appena descritto:

# %%
# NOTA: assicurati prima di aver eseguito la cella precedente!

nuovi_dati = ['micio', 'fido', 'loreto', 'chuck']

for idx, nome in enumerate(nuovi_dati): 
    nuovo_sheet.cell(row=idx+1, column=2).value = nome

nuovo_book.save('./files_esercizi/outputs/nuovo_file.xlsx')

# %% [markdown]
# > ATTENZIONE: Righe e colonne vengono numerate a partire da `1` e non da zero `0`, come siamo abituati con le liste o altre sequenze.

# %% [markdown]
# Se provate ad aprire il file `nuovo_file.xlsx` nella cartella `files_esercizi/outputs/` dovreste vedere le prime due colonne compilate.

# %% [markdown]
# ### Cursore: tenere traccia della posizione attuale
#
# Quando scrivi su un foglio di calcolo è utile immaginare di stare compilarlo a mano, con la tastiera. Spostiamo in orizzontale o in verticale il nostro _**cursore**_ e poi inseriamo i dati.
#
# Se dunque scriviamo su un foglio e usiamo il metodo `Worksheet.cell()`, potrebbe essere utile creare uno strumento "cursore" che tenga traccia della nostra posizione attuale all'interno del foglio di lavoro. Lo possiamo usare per dire a Python da dove vogliamo che inizi a scrivere e lo possiamo modificare per "spostarci" in un'altro punto.
#
# Infatti, anche se usiamo la funzione `enumerate()`, che ci consente di usare l'indice di un oggetto come una sorta di contatore/cursore, questo è relativo all'oggetto che stiamo scrivendo: potremmo essere alla posizione con indice `10` di quell'oggetto, ma non è detto che siamo anche alla decima riga o colonna del nostro foglio.
#
# Ecco alcune idee per implementare un cursore:
#
# ```python
# cursor = [1, 1]  # [row, column]
# ```
# oppure
#
# ```python
# cursor = {'row': 1, 'col': 1}
# ```
#
# oppure
#
# ```python
# row_cursor = 1
# col_cursor = 1

# %%
from openpyxl import Workbook

nuovo_book = Workbook()          # creo l'oggetto per interfacciarmi col workbook
nuovo_sheet = nuovo_book.active  # seleziono il worksheet attivo

data1 = ['a', 'b', 'c']
data2 = ['d', 'e', 'f']

# iniziamo a scrivere dalla cella "E10"
row_cursor = 10
col_cursor = 5

for idx, value in enumerate(data1):
    nuovo_sheet.cell(row=row_cursor, column=col_cursor+idx).value = value

# finito di scrivere la riga, ne salto una e riparto a scrivere
row_cursor += 2

for idx, value in enumerate(data2):
    nuovo_sheet.cell(row=row_cursor, column=col_cursor+idx).value = value

nuovo_book.save('./files_esercizi/outputs/nuovo_file_cursore.xlsx')

# %% [markdown]
# Prima di passare all'esempio successivo, diamo un'occhiata agli oggetti che abbiamo appena creato e manipolato:

# %%
# Workbook
print(type(nuovo_book))

# Worksheet
print(type(nuovo_sheet))

# Cell
print(type(nuovo_sheet['A1']))
print(type(nuovo_sheet.cell(row=1, column=1)))
# Out:
# <class 'openpyxl.workbook.workbook.Workbook'>
# <class 'openpyxl.worksheet.worksheet.Worksheet'>
# <class 'openpyxl.cell.cell.Cell'>
# <class 'openpyxl.cell.cell.Cell'>

# %% [markdown]
# ### Scrittura di una lista di liste (matrice)
#
# Immaginiamo di voler scrivere su un file di Excel la seguente tabella:
#
# |      | `A`               | `B`               | `C`                    | `D`                 |
# |------|-------------------|-------------------|------------------------|---------------------|
# | `1`  | **COMUNE**        | **PROVINCIA**     | **ABITANTI LOCALITA'** | **QUOTA LOCALITA'** |
# | `2`  | CAGLIARI          | CAGLIARI          | 203650                 | 6                   |
# | `3`  | SASSARI           | SASSARI           | 98762                  | 225                 |
# | `4`  | QUARTU SANT'ELENA | CAGLIARI          | 60618                  | 6                   |
# | `5`  | NUORO             | NUORO             | 37218                  | 549                 |
# | `6`  | OLBIA             | OLBIA-TEMPIO      | 34336                  | 15                  |
# | `7`  | ALGHERO           | SASSARI           | 33677                  | 7                   |
# | `8`  | IGLESIAS          | CARBONIA IGLESIAS | 25733                  | 200                 |
# | `9`  | CARBONIA          | CARBONIA IGLESIAS | 25512                  | 111                 |
# | `10` | ORISTANO          | ORISTANO          | 25398                  | 9                   |

# %% [markdown]
# Potremmo rappresentarla come un oggetto Python in molti modi. Il più semplice è una cosiddetta *matrice*, in particolare una matrice bi-dimensionale, a due dimensioni, in questo caso: righe e colonne. Il concetto di [*matrice*](https://it.wikipedia.org/wiki/Matrice) arriva dalla matematica.
#
# In informatica le matrici vengono implementate in molti modi, di solito utilizzando gli [*array*](https://it.wikipedia.org/wiki/Array), ovvero elenchi di valori, come le liste Python.
#
# Dato che le liste Python possono contenere altre liste, il metodo più usato e pratico è quello di annidare due liste.

# %%
matrice = [
    ['COMUNE',             'PROVINCIA',         'ABITANTI LOCALITA\'', 'QUOTA LOCALITA\''],
    ['CAGLIARI',           'CAGLIARI',          203650,                6                 ],
    ['SASSARI',            'SASSARI',           98762,                 225               ],
    ['QUARTU SANT\'ELENA', 'CAGLIARI',          60618,                 6                 ],
    ['NUORO',              'NUORO',             37218,                 549               ],
    ['OLBIA',              'OLBIA-TEMPIO',      34336,                 15                ],
    ['ALGHERO',            'SASSARI',           33677,                 7                 ],
    ['IGLESIAS',           'CARBONIA IGLESIAS', 25733,                 200               ],
    ['CARBONIA',           'CARBONIA IGLESIAS', 25512,                 111               ],
    ['ORISTANO',           'ORISTANO',          25398,                 9                 ]
]

# %% [markdown]
# Creiamo una lista che contiene le righe e poi ciascuna riga è a sua volta una lista che contiene i valori di ciascuna colonna.
#
# Per accedere a un dato, prima dobbiamo indicare in quale riga si trova, e poi in quale colonna. Tramite la notazione a subscription `[ ]` è molto semplice!
#
# Se vogliamo accedere all'elemento che contiene il numero di abitanti di `"QUARTU SANT'ELENA"`, dobbiamo selezionare la quarta riga e poi spostarci nella terza riga:

# %%
matrice[3][2]  # row 4, col 3
# Out:
# 60618

# %% [markdown]
# Compilare un foglio di Excel è un gioco da ragazzi: cicliamo ogni riga e, ad ogni iterazione, cicliamo le colonne di ciascuna riga.

# %%
from openpyxl import Workbook

tabella = [
    ['COMUNE', 'PROVINCIA', 'ABITANTI LOCALITA\'', 'QUOTA LOCALITA\''],
    ['CAGLIARI', 'CAGLIARI', 203650, 6],
    ['SASSARI', 'SASSARI', 98762, 225],
    ['QUARTU SANT\'ELENA', 'CAGLIARI', 60618, 6],
    ['NUORO', 'NUORO', 37218, 549],
    ['OLBIA', 'OLBIA-TEMPIO', 34336, 15],
    ['ALGHERO', 'SASSARI', 33677, 7],
    ['IGLESIAS', 'CARBONIA IGLESIAS', 25733, 200],
    ['CARBONIA', 'CARBONIA IGLESIAS', 25512, 111],
    ['ORISTANO', 'ORISTANO', 25398, 9]
]

sardegna_book = Workbook()           # creo l'oggetto per interfacciarmi col workbook
nuovo_sheet = sardegna_book.active   # seleziono il worksheet attivo

for row_id, row in enumerate(tabella):   # per ciascuna riga
    for col_id, cell in enumerate(row):  # per ciascuna colonna
        
        # scrivo la cella
        nuovo_sheet.cell(row=row_id+1, column=col_id+1).value = cell

sardegna_book.save('./files_esercizi/outputs/comuni_sardi.xlsx')

# %% [markdown]
# ### Rotazione di una matrice (trasposizione)
#
# E se volessimo "girare" la tabella, ovvero mettere le proprietà nelle righe e i comuni nelle colonne?
#
# In matematica e informatica sono stati scritti centinaia di libri sull'argomento "come manipolare le matrici". In realtà le tecniche di trasformazione delle matrici e il calcolo cosiddetto matriciale è una branca della matematica, e su di essa si fonda l'intera scienza informatica. In teoria qualunque problema è rappresentabile e risolvibile tramite le matrici e, dato il funzionamento dell'elettronica, a basso livello i processori e soprattutto le memorie utilizzano continuamente strutture matriciali per leggere, spostare e trasformare i dati.
#
# Per ruotare di 90° in senso orario una matrice a bi-dimensionale (2D), mantenendo l'ordine degli elementi potete usare questo pattern:
#
# ```python
# matrice_ruotata = list(zip(*matrice_originale[::1]))
# ```
#
# > ATTENZIONE: in questo modo non stiamo facendo una "vera" rotazione di 90°, perché vogliamo mantenere l'ordine degli elementi.
# > Se volessi fare una precisa rotazione di 90° in senso orario dovresti fare così:
# >
# > ```python
# > matrice_ruotata = list(zip(*matrice_originale[::-1]))
# > ```

# %%
from pprint import pprint

tabella_ruotata = list(zip(*tabella[::-1]))

pprint(tabella_ruotata, compact=True, width=150)
# Out:
# [('ORISTANO', 'CARBONIA', 'IGLESIAS', 'ALGHERO', 'OLBIA', 'NUORO', "QUARTU SANT'ELENA", 'SASSARI', 'CAGLIARI', 'COMUNE'),
#  ('ORISTANO', 'CARBONIA IGLESIAS', 'CARBONIA IGLESIAS', 'SASSARI', 'OLBIA-TEMPIO', 'NUORO', 'CAGLIARI', 'SASSARI', 'CAGLIARI', 'PROVINCIA'),
#  ('25398', '25512', '25733', '33677', '34336', '37218', '60618', '98762', '203650', "ABITANTI LOCALITA'"),
#  ('9', '111', '200', '7', '15', '549', '6', '225', '6', "QUOTA LOCALITA'")]

# %% [markdown]
# È strano ruotare tabelle di questo tipo. Abbiamo detto che di solito le righe rappresentano le entità/record e le colonne le proprietà di queste entità. Fare il contrario è un po strano e poco pratico, perché di solito abbiamo molti record e relativamente poche proprietà (di solito di meno rispetto ai record). Ruotando una tabella rischiamo creare una tabelle molto larga e con poche righe. Veramente poco prartico!
#
# Tuttavia potrebbe essere utile in caso volessimo compilare la tabella una colonna alla volta anziché una riga alla volta. In questo caso, senza la rotazione dovremmo creare un algoritmo più complesso con contatore/cursore ad-hoc. Con la rotazione potremo usare il medesimo algoritmo visto precedentemente.

# %%
tabella_ruotata = list(zip(*tabella[::1]))  # ruoto la tabella

sardegna_book = Workbook()           # creo l'oggetto per interfacciarmi col workbook
nuovo_sheet = sardegna_book.active   # seleziono il worksheet attivo

for col_id, col in enumerate(tabella_ruotata):   # per ciascuna colonna
    for row_id, cell in enumerate(col):          # per ciascuna riga
        
        # scrivo la cella
        nuovo_sheet.cell(row=row_id+1, column=col_id+1).value = cell

sardegna_book.save('./files_esercizi/outputs/comuni_sardi_da_matrice_ruotata.xlsx')

# %% [markdown]
# ### Scrittura di una lista di dizionari

# %%
data = [
    {
        "COMUNE": "CAGLIARI",
        "PROVINCIA": "CAGLIARI",
        "ABITANTI LOCALITA'": 203650,
        "QUOTA LOCALITA'": 6,
    },
    {
        "COMUNE": "SASSARI",
        "PROVINCIA": "SASSARI",
        "ABITANTI LOCALITA'": 98762,
        "QUOTA LOCALITA'": 225,
    },
    {
        "COMUNE": "QUARTU SANT'ELENA",
        "PROVINCIA": "CAGLIARI",
        "ABITANTI LOCALITA'": 60618,
        "QUOTA LOCALITA'": 6,
    },
    {
        "COMUNE": "NUORO",
        "PROVINCIA": "NUORO",
        "ABITANTI LOCALITA'": 37218,
        "QUOTA LOCALITA'": 549,
    },
    {
        "COMUNE": "OLBIA",
        "PROVINCIA": "OLBIA-TEMPIO",
        "ABITANTI LOCALITA'": 34336,
        "QUOTA LOCALITA'": 15,
    }
]

intestazioni = [ "COMUNE", "PROVINCIA", "ABITANTI LOCALITA'", "QUOTA LOCALITA'"]

sardegna_book = Workbook()           # creo l'oggetto per interfacciarmi col workbook
nuovo_sheet = sardegna_book.active   # seleziono il worksheet attivo

# inizializzo il contatore di riga
row_cursor = 1

# scrivo la riga di intestazione delle colonne
for col_id, head in enumerate(intestazioni):
    nuovo_sheet.cell(row=row_cursor, column=col_id+1).value = head
row_cursor += 1  # incremento il contatore di riga

# scrivo un dizionario alla volta
for row_dict in data:
    for col_id, head in enumerate(intestazioni):
        nuovo_sheet.cell(row=row_cursor, column=col_id+1).value = row_dict[head]
    row_cursor += 1  # alla fine passo alla riga successiva


sardegna_book.save('./files_esercizi/outputs/comuni_sardi_da_dict.xlsx')

# %% [markdown]
# ### Leggere un file esistente
#
# Vediamo ora come leggere che già esiste.
#
# Tu e un guppo di amici fate parte del circolo di taglio e cucito, e vi ritrovate ogni mercoledì. Dato che servono un numero minimo di partecipanti per ogni incontro, hai deciso di tenere traccia delle vacanze estive e invernali di tutti i membri del circolo in modo da decidere quando sospendere le attività. Abbiamo registrato tutto in una tabella. Le vacanze estive sono descritte nel primo foglio e quelle invernali nel secondo. Il file Excel contiene le seguenti informazioni: nome, cognome, città, data di partenza, giorni di soggiorno.
#
# Prima di tutto, dobbiamo utilizzare la funzione `openpyxl.load_workbook()` per aprire il nostro file. Dopodiché, dobbiamo specificare il foglio da trattare. `"Estate"` è il nome del foglio che ci interessa.

# %%
import openpyxl

workbook = openpyxl.load_workbook('./files_esercizi/Vacanze.xlsx')

foglio_estate = workbook['Estate']

# %% [markdown]
# In caso ci fossimo dimenticati il nome del foglio, ma per esempio ci ricordiamo che è il primo, la seguente istruzione ci permette di aprire il foglio `Vacanze estive`, che ha indice `0`:

# %%
import openpyxl

workbook = openpyxl.load_workbook('./files_esercizi/Vacanze.xlsx')

lista_nomi_fogli = workbook.sheetnames
foglio_estate = workbook[lista_nomi_fogli[0]]

# proviamo a stampare la lista dei nomi degli sheet
print(lista_nomi_fogli)
# Out:
# ['Estate', 'Inverno']

# %% [markdown]
# `Workbook.sheetnames` restituisce tutti i nomi dei fogli di un file Excel in una lista. In seguito, sarà possibile accedervi facilmente utilizzando l'indice corrispondente.
#
# Ora stampiamo il nome, il cognome e la città del primo amico. Possiamo accedervi con l'la proprietà `Cell.value`.

# %%
print(foglio_estate['A2'].value)
print(foglio_estate['B2'].value)
print(foglio_estate['C2'].value)
# Out:
# Luca
# Rossi
# Dubai

# %% [markdown]
# Se è necessario stampare alcune informazioni dal secondo foglio, è possibile accedervi allo stesso modo specificandone il nome. Questa volta però facciamo una cosa più utile: piuttosto che leggere dei valori qua e là, leggiamo tutta la tabella. La tecnica è la medesima di quando l'abbiamo compilata.
#
# Per sapere il numero totale di righe e colonne abbiamo i metodi `Worksheet.max_row` e `Worksheet.max_column`.

# %%
foglio_inverno = workbook['Inverno']
# foglio_inverno = workbook[workbook.sheetnames[1]]

for row_id in range(foglio_inverno.max_row):
    row = []
    for col_id in range(foglio_inverno.max_column):
        cell = foglio_inverno.cell(row=row_id+1, column=col_id+1).value
        row.append(cell)
    
    print(*row, sep=',')
# Out:
# NOME,COGNOME,CITTA',DATA PARTENZA,GG DURATA
# Luca,Rossi,Francoforte,2023-12-20 00:00:00,5
# Gianna,Bianchi,Il Cairo,2023-12-24 00:00:00,7
# Turi,Neri,Londra,2023-12-23 00:00:00,8
# Ada,Verdi,Miami,2023-12-31 00:00:00,10
# Micaela,Marrone,Amsterdam,2024-01-04 00:00:00,10
# Roby,Porporati,New York,2023-12-28 00:00:00,5
# Marco,Rosa,Tokyo,2023-12-23 00:00:00,6

# %% [markdown]
# ### Scrivere su un file
# Continuiamo a lavorare con il nostro file. Vogliamo tracciare le vacanze dei nostri amici anche per la prossima primavera.
#
# Parliamo di Luca. Conosce la città che desidera visitare, ma non è sicuro della data. Possiamo creare un nuovo foglio e scrivere le informazioni su di lui:

# %%
workbook.create_sheet(title='Primavera')
foglio_primavera = workbook['Primavera']

# Copio la riga di intestazione dal foglio "Inverno"
foglio_primavera['A1'] = foglio_inverno['A1'].value
foglio_primavera['B1'] = foglio_inverno['B1'].value
foglio_primavera['C1'] = foglio_inverno['C1'].value
foglio_primavera['D1'] = foglio_inverno['D1'].value
foglio_primavera['E1'] = foglio_inverno['E1'].value

# Inserisco i nuovi dati
foglio_primavera['A2'] = 'Luca'
foglio_primavera['B2'] = 'Rossi'
foglio_primavera['C2'] = 'Praga'
foglio_primavera['D2'] = 'Da confermare'
foglio_primavera['E2'] = 7

# Salvo il file su disco
workbook.save("./files_esercizi/outputs/Vacanze_new.xlsx")

# %% [markdown]
# `Workbook.create_sheet()` viene utilizzato per aggiungere un nuovo foglio. È possibile specificare il nome tra le parentesi. Dopodiché, possiamo aprire il foglio e scriverci le informazioni. Non dimenticate di salvare il file!

# %% [markdown]
# ### Filtrare le voci
#
# Gli esempi precedenti sono abbastanza facili da gestire. Ma cosa succede se un file Excel contiene migliaia di voci e dobbiamo mostrarne solo alcune? In questo caso, possiamo utilizzare le dichiarazioni `if` e i cicli `for`.
#
# Analizziamo un file che contiene informazioni sulle strutture ricettive della Bsilicata: comune, provincia, denominazione, tipologia, numero di stelle e così via.
#
# Dato che è poco pratico contare manualmente le righe e le colonne, si può usare `sheet.max_row` e `sheet.max_column` per sapere quante righe e colonne ci sono nel file:

# %%
import openpyxl

workbook = openpyxl.load_workbook('./files_esercizi/basilicata-strutture-ricettive-2017.xlsx')

sheet = workbook['Foglio1']

rows = sheet.max_row
cols = sheet.max_column

print(rows)
print(cols)
# Out:
# 1309
# 15

# %% [markdown]
# Se vogliamo stampare tutte le entry, possiamo farlo così:

# %%
for row_num in range(1, rows+1):
    row_cells = []
    for col_num in range(1, cols+1):
        value = sheet.cell(row=row_num, column=col_num).value
        row_cells.append(str(value))
    print(', '.join(row_cells))
# Out:
# Comune, Provincia, Regione, Denominazione, Tipologia, Class., Indirizzo, CAP, Sigla provincia, FAX, Sito internet, Apertura, Posti letto, Nota, Tipo di nota
# ABRIOLA, POTENZA, Basilicata, Az. Agr. La Dolce Vita, Agriturismo, ittiturismo, pescaturismo, None, C.da Valloni, 85010, PZ, None, www.ladolcevitadiabriola.it, annuale, 10, 42832, Nuovo inserimento
# ABRIOLA, POTENZA, Basilicata, Hotel Pierfaone, Albergo, 3 stelle ***, C.da Pierfaone, s.n., 85010, PZ, 0971 722973, None, annuale, 43, None, None
# ABRIOLA, POTENZA, Basilicata, Hotel Sellata, Albergo, 3 stelle ***, Via Sellata, 1 - Loc. Sellata, 85010, PZ, None, www.hotelsellata.it, annuale, 26, None, None
# ABRIOLA, POTENZA, Basilicata, Villaggio Eos di Dapoto Valentina, Agriturismo, ittiturismo, pescaturismo, None, C.da Murge - Loc. Sellata, 85010, PZ, None, None, annuale, 12, None, None
# ACERENZA, POTENZA, Basilicata, Affittacamere Il Duomo, Affittacamere, None, Via Alessandro Volta, 6, 85011, PZ, None, www.ristorantealduomoacerenza.it, annuale, 1, None, None
# ACERENZA, POTENZA, Basilicata, Affittacamere La Suite di Arnaldo, Affittacamere, None, Via Vittorio Veneto, 54, 85011, PZ, None, www.lasuitediarnaldo.it, annuale, 3, 42979, Nuovo inserimento
# ACERENZA, POTENZA, Basilicata, B&B Villa NI.BE., Bed and breakfast - standard, None, Via Pietro Stoppelli, s.n. - C.da Piani San Nicola, 85011, PZ, 0971 741390, None, annuale, 8, None, None
# ACERENZA, POTENZA, Basilicata, Hotel Il Casone, Albergo, 3 stelle ***, Via Bosco San Giuliano, 85011, PZ, 0971 741141, www.hotelilcasone.net, annuale, 53, None, None
# ALBANO DI LUCANIA, POTENZA, Basilicata, B&B Il Patriarca, Bed and breakfast - standard, None, Via Gioberti, 4, 85011, PZ, None, www.ilpatriarca.com, stagionale, 7, None, None
# ALBANO DI LUCANIA, POTENZA, Basilicata, B&B San Lorenzo, Bed and breakfast - standard, None, C.da San Lorenzo, s.n.c., 85010, PZ, None, None, annuale, 8, 42913, Nuovo inserimento
# ARMENTO, POTENZA, Basilicata, Az. Agr. Da Zia Elena, Agriturismo, ittiturismo, pescaturismo, None, S.S. 598 km. 64,900 - Loc. Scarnata, 85010, PZ, 0971 751381, www.agriturismodaziaelena.it, annuale, 15, None, None
# ARMENTO, POTENZA, Basilicata, Il Borgo delle Arti, Affittacamere, None, C.da Itlei, 85010, PZ, 0971 26794, www.borgodellearti.com, annuale, 11, None, None
# ATELLA, POTENZA, Basilicata, B&B Villa delle Rose, Bed and breakfast - standard, None, C.da Villa delle Rose - Loc. Monticchio Laghi, 85020, PZ, 0972 715161, www.villadellerose.basilicata.it, annuale, 12, None, None
# ATELLA, POTENZA, Basilicata, RTA Residence Villa Rosa, Residenza turistico-alberghiera, 1 stella *, Vico Storto S. Antonio, S.n.c. - Loc. S. Ilario, 85020, PZ, None, None, annuale, 17, 42884, Cancellazione
# AVIGLIANO, POTENZA, Basilicata, Affittacamere Portacastello, Affittacamere, None, Viale A. Doria, 56 - Fraz. Lagopesole, 85020, PZ, None, www.portacastello.com, annuale, 12, None, None
# AVIGLIANO, POTENZA, Basilicata, B&B Lacus Pensilis, Bed and breakfast - Comfort, None, Via G. Leopardi, s.n.c. - Loc. Lagopesole, 85021, PZ, None, www.lacuspensilis.it, stagionale, 9, None, None
# AVIGLIANO, POTENZA, Basilicata, B&B La Masseria del Marchese, Bed and breakfast - standard, None, Via Lago del Monaco, 1 - Loc. Lagopesole, 85020, PZ, None, www.masseriadelmarchese.it, annuale, 6, None, None
# AVIGLIANO, POTENZA, Basilicata, B&B Le Gemme, Bed and breakfast - standard, None, Via Lucania, 2 - Loc. Lagopesole, 85021, PZ, 0971 86167, www.legemmelagopesole.it, annuale, 11, None, None
# AVIGLIANO, POTENZA, Basilicata, Borgo Lamurese, Affittacamere, None, C.da Cefalo, 19, 85021, PZ, 0971 1830464, www.borgolamurese.it, annuale, 3, None, None
# AVIGLIANO, POTENZA, Basilicata, Hotel Ristorante Summa, Albergo, 3 stelle ***, Viale delle Ginestre, 6, 85021, PZ, 0971 82449, None, annuale, 26, None, None
# AVIGLIANO, POTENZA, Basilicata, La Dimora di Federico, Locanda rurale, None, Via Dante Alighieri, 19 - Fraz. Lagopesole, 85021, PZ, None, www.ladimoradifederico.com, annuale, 10, None, None
# BALVANO, POTENZA, Basilicata, Affittacamere Teta Antonio, Affittacamere, None, Via S. Sebastiano, 45, 85050, PZ, None, None, annuale, 12, None, None
# BANZI, POTENZA, Basilicata, Az. Agr. Carrera della Regina, Agriturismo, ittiturismo, pescaturismo, None, Ex S.S. 169 km. 48+800 - Loc. Cerasola, 85010, PZ, 0971 774470, www.carreradellaregina.it, annuale, 26, None, None
# BANZI, POTENZA, Basilicata, B&B Dinamic, Bed and breakfast - standard, None, Loc. Marascione S.P. 79, 85010, PZ, 0972 45163, www.bebdinamic.it, annuale, 7, None, None
# BANZI, POTENZA, Basilicata, B&B La Badia, Bed and breakfast - standard, None, Largo Urbano II, 7, 85010, PZ, None, www.labadiabanzi.com, annuale, 6, None, None
# BARILE, POTENZA, Basilicata, B&B La Falchera, Bed and breakfast - standard, None, Via Piave, 1, 85022, PZ, 0972 770517, www.beblafalchera.com, stagionale, 5, None, None
# BARILE, POTENZA, Basilicata, Grand Hotel Garden, Albergo, 3 stelle ***, S.S. 93 km. 75 - Loc. Giardino, 85022, PZ, 0972 761560, www.grandhotelgarden.com, annuale, 85, None, None
# BELLA, POTENZA, Basilicata, Az. Agr. Valle dell'Oro, Agriturismo, ittiturismo, pescaturismo, None, C.da Valle dell'Oro - Loc. Sant'Antonio Casalini, 85051, PZ, None, None, annuale, 12, None, None
# BELLA, POTENZA, Basilicata, Bio-Agr. La Taverna del Pastore, Agriturismo, ittiturismo, pescaturismo, None, C.da Toppa Castelluccio, 85051, PZ, 0976 3840, www.tavernadelpastore.it, annuale, 9, None, None
# BRIENZA, POTENZA, Basilicata, Hotel Imperial, Albergo, 3 stelle ***, Via Nazionale, 85050, PZ, 0975 384977, www.hotelimperial.net, annuale, 72, None, None
# BRIENZA, POTENZA, Basilicata, Hotel Ristorante Eden, Albergo, 3 stelle ***, C.da Pozzi-Taverne, 30, 85050, PZ, 0975 381681, www.edenhotelbrienza.it, annuale, 87, None, None
# BRIENZA, POTENZA, Basilicata, La Casa del Borgo, Casa e appartamento per vacanze, None, Corso Umberto I, 35, 85050, PZ, 0971 443798, None, annuale, 7, None, None
# BRIENZA, POTENZA, Basilicata, La Giara, Affittacamere, None, Via Mario Pagano, 31, 85050, PZ, 0975 381263, www.lagiara.org, annuale, 12, None, None
# BRIENZA, POTENZA, Basilicata, La Voce del Fiume B&B, Bed and breakfast - Comfort, None, Vico del Carmine, 5, 85050, PZ, 0975 381644, www.lavocedelfiume.it, annuale, 11, None, None
# BRINDISI MONTAGNA, POTENZA, Basilicata, Affittacamere Addesio Donato, Affittacamere, None, Via Montesanto, 11-15, 85010, PZ, 0971 985119, None, annuale, 3, None, None
# BRINDISI MONTAGNA, POTENZA, Basilicata, B&B Rago, Bed and breakfast - standard, None, Corso dei Lavoratori, 102, 85010, PZ, None, None, annuale, 3, None, None
# BRINDISI MONTAGNA, POTENZA, Basilicata, B&B Villa Damiani, Bed and breakfast - standard, None, C.da Molinello, 1, 85010, PZ, None, None, annuale, 4, None, None
# BRINDISI MONTAGNA, POTENZA, Basilicata, Hostell Basilicata al Volo, Ostello per la gioventÔøΩ, None, Largo San Giacomo, 1, 85010, PZ, None, None, annuale, 22, None, None
# BRINDISI MONTAGNA, POTENZA, Basilicata, Hotel Arcobaleno, Albergo, 3 stelle ***, Via Ruota, 9, 85010, PZ, 0971 985065, www.villarcobaleno.it, annuale, 36, None, None
# CALVELLO, POTENZA, Basilicata, Agriturismo Postiglione Anna Amelia, Agriturismo, ittiturismo, pescaturismo, None, C.da Isca Soprana - S. Lucia, 85010, PZ, 0971 921246, None, stagionale, 16, None, None
# CALVELLO, POTENZA, Basilicata, B&B LucantÔøΩ, Bed and breakfast - standard, None, Via Marsicovetere, 2, 85010, PZ, None, www.lucanto.it, stagionale, 7, None, None
# CALVELLO, POTENZA, Basilicata, Bioagriturismo Sant'Elia, Agriturismo, ittiturismo, pescaturismo, None, C.da Sant'Elia, S.n.c., 85010, PZ, 0971 1964356, www.bioagriturismosantelia.it, stagionale, 18, None, None
# CALVELLO, POTENZA, Basilicata, Hotel Il Volturino, Albergo, 2 stelle **, Via S. Milito, 85010, PZ, 0971 921227, None, annuale, 28, None, None
# CALVELLO, POTENZA, Basilicata, Hotel Pietrapanna, Albergo, 3 stelle ***, C.da Potentissima, s.n.c., 85010, PZ, 0971 920900, www.pietrapanna.it, annuale, 72, None, None
# CAMPOMAGGIORE, POTENZA, Basilicata, B&B da Rosario, Bed and breakfast - standard, None, Via della Pineta, 4, 85010, PZ, None, www.bbdarosario.it, stagionale, 8, None, None
# CAMPOMAGGIORE, POTENZA, Basilicata, B&B Villa Testa, Bed and breakfast - standard, None, Via Martiri del Lavoro, 11, 85010, PZ, None, None, stagionale, 10, None, None
# CAMPOMAGGIORE, POTENZA, Basilicata, La Gregna, Locanda rurale, None, Corso Umberto I, s.n.c., 85010, PZ, None, www.lagregna.it, annuale, 4, None, None
# CANCELLARA, POTENZA, Basilicata, B&B La Rosa del Barone, Bed and breakfast - standard, None, Via Vittorio Emanuele III, 29, 85010, PZ, 0971 942379, None, annuale, 8, None, None
# CASTELGRANDE, POTENZA, Basilicata, Albergo Mizar, Albergo, 2 stelle **, Via Gaetano Federici, 85050, PZ, None, None, annuale, 23, None, None
# CASTELGRANDE, POTENZA, Basilicata, Casa Naturando, Casa e appartamento per vacanze, None, Loc. Luffarana, s.n.c., 85050, PZ, 0976 2455, None, annuale, 21, None, None
# CASTELLUCCIO INFERIORE, POTENZA, Basilicata, Hotel Il Beccaccino, Albergo, 2 stelle **, Via Roma, 87, 85040, PZ, 0973 663173, None, annuale, 15, None, None
# CASTELLUCCIO INFERIORE, POTENZA, Basilicata, Hotel Mercure, Albergo, 3 stelle ***, Via Roma, 34, 85040, PZ, 0973 663054, http://web.tiscalinet.it/hotelmercure, annuale, 58, None, None
# CASTELLUCCIO INFERIORE, POTENZA, Basilicata, Hotel Ristorante Pino Loricato, Albergo, 2 stelle **, Via Nazionale, 11, 85040, PZ, 0973 662075, None, annuale, 86, None, None
# CASTELLUCCIO SUPERIORE, POTENZA, Basilicata, Hotel San Raffaele, Albergo, 3 stelle ***, C.da Pastani, 83, 85040, PZ, 0973 662129, www.hotelsanraffaele.it, annuale, 33, None, None
# CASTELLUCCIO SUPERIORE, POTENZA, Basilicata, Hotel Sette e Mezzo, Albergo, 2 stelle **, Via Aldo Moro, 30/32, 85040, PZ, 0973 663913, www.hotelsetteemezzo.it, annuale, 61, None, None
# CASTELMEZZANO, POTENZA, Basilicata, Az. Agr. Grotta dell'Eremita, Agriturismo, ittiturismo, pescaturismo, None, C.da Calcescia, 1, 85010, PZ, 0971 986030, www.grottadelleremita.com, annuale, 19, None, None
# CASTELMEZZANO, POTENZA, Basilicata, Az. Agr. Il Molino della Contessa, Agriturismo, ittiturismo, pescaturismo, None, C.da Fiumara, 85010, PZ, None, www.molinodellacontessa.it, annuale, 13, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B Al Balcone delle Dolomiti, Bed and breakfast - standard, None, Via Regina Margherita, 73, 85010, PZ, None, www.bedandbreakfastcastelmezzano.it, annuale, 4, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B Al Castello, Bed and breakfast - standard, None, Via Largo Castello, 34, 85010, PZ, None, None, annuale, 2, 42908, Variazione dati
# CASTELMEZZANO, POTENZA, Basilicata, B&B Al Cuore del Borgo, Bed and breakfast - standard, None, Via Michele Trivigno, 5, 85010, PZ, None, www.alcuoredelborgo.it, annuale, 4, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B Dal Duca, Bed and breakfast - standard, None, Vico de Lerma, 8, 85010, PZ, None, www.dalduca.net, annuale, 3, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B Emozioni Lucane, Bed and breakfast - standard, None, Vico Supportico 1ÔøΩ della Piazza, 15, 85010, PZ, None, None, annuale, 5, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B I Cinque Petali di Rosa, Bed and breakfast - standard, None, Via Guglielmo Marconi, 44, 85010, PZ, None, None, annuale, 3, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B La Bella Vista, Bed and breakfast - standard, None, Via San Marco, 44, 85010, PZ, None, None, annuale, 4, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B L'Angolo Antico delle Dolomiti, Bed and breakfast - standard, None, Via Guglielmo Marconi, 99, 85010, PZ, None, None, annuale, 4, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B La Panoramica, Bed and breakfast - standard, None, Via Michele Trivigno, 19, 85010, PZ, None, www.bblapanoramica.it, annuale, 6, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B La Perla nelle Dolomiti, Bed and breakfast - standard, None, Vico Castello, 2, 85010, PZ, None, www.dolomitilucanebb.it, annuale, 3, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B Regina Margherita, Bed and breakfast - standard, None, Via Regina Margherita, 96, 85010, PZ, None, None, annuale, 4, None, None
# CASTELMEZZANO, POTENZA, Basilicata, B&B Seraton, Bed and breakfast - standard, None, Vico III Spinalva, 5, 85010, PZ, None, www.seraton.it, annuale, 5, None, None
# CASTELMEZZANO, POTENZA, Basilicata, Il Borgo Ducale - Al Palazzo Ducale, Casa e appartamento per vacanze, None, Via Domenico Volini, 7, 85010, PZ, None, www.castelmezzanobb.it, annuale, 5, None, None
# CASTELMEZZANO, POTENZA, Basilicata, Il Borgo Ducale - Paschiere, Affittacamere, None, Via Paschiere, 14-16-18, 85010, PZ, None, None, annuale, 8, 42943, Cancellazione
# CASTELMEZZANO, POTENZA, Basilicata, Il Borgo Ducale - Paschiere, Affittacamere, None, Via Paschiere, 14-16-18, 85010, PZ, None, www.castelmezzanobb.it, annuale, 12, 42943, Nuovo inserimento
# CASTELMEZZANO, POTENZA, Basilicata, Il Borgo Ducale - Vico Giacoia, Affittacamere, None, Vico Giacoia, 1, 85010, PZ, None, www.castelmezzanobb.it, annuale, 3, None, None
# CASTELMEZZANO, POTENZA, Basilicata, La Casa di Giulietta, Affittacamere, None, Via Garibaldi, 16, 17, 18, 85010, PZ, None, www.lacasadigiulietta.net, annuale, 13, None, None
# CASTELMEZZANO, POTENZA, Basilicata, La Gradinata B&B, Bed and breakfast - standard, None, Via Michele Trivigno, 10, 85010, PZ, None, www.lagradinata.it, stagionale, 6, None, None
# CASTELMEZZANO, POTENZA, Basilicata, La Locanda di Castromediano, Albergo, 3 stelle ***, Via Michele Volini, 50/A, 85010, PZ, 0971 986249, www.beccodellacivetta.it, annuale, 49, None, None
# CHIAROMONTE, POTENZA, Basilicata, Agriturismo Arcomano Giovannino, Agriturismo, ittiturismo, pescaturismo, None, C.da Fiego, 15, 85032, PZ, 0973 571313, www.agriturismoarcomano.com, stagionale, 23, None, None
# CHIAROMONTE, POTENZA, Basilicata, Az. Agr. Costa Casale, Agriturismo, ittiturismo, pescaturismo, None, C.da Vito, 85032, PZ, 0973 642346, None, annuale, 22, None, None
# CHIAROMONTE, POTENZA, Basilicata, Bed & Breakfast Casa Miraglia, Bed and breakfast - standard, None, Via Giovanni di Giura, 20/C, 85032, PZ, None, None, stagionale, 6, None, None
# CHIAROMONTE, POTENZA, Basilicata, Ostello Chiaromonte, Ostello per la gioventÔøΩ, None, C.da San Rocco, s.n., 85032, PZ, 080 5612322, None, annuale, 76, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, Agriturismo Il Repole, Agriturismo, ittiturismo, pescaturismo, None, C.da Tempa Demma, 17, 85012, PZ, 0971 963690, www.agriturismoilrepole.it, annuale, 6, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, Agriturismo La Bradia di Spagna Teresa, Agriturismo, ittiturismo, pescaturismo, None, Loc. Bradia, 85012, PZ, None, www.agriturismolabradia.it, annuale, 10, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, Albergo Le Rose, Albergo, 3 stelle ***, Piazza Plebiscito, 15, 85012, PZ, 0971 963911, None, annuale, 11, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, Albergo Ristorante Priore, Albergo, 1 stella *, Via Zanardelli, 2, 85012, PZ, 0971 963032, None, annuale, 17, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, B&B Al Centro, Bed and breakfast - standard, None, Vico Plebiscito, 7, 85012, PZ, None, None, annuale, 5, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, B&B La Foresteria, Bed and breakfast - standard, None, C.da Bradia, s.n.c., 85012, PZ, None, None, stagionale, 6, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, B&B Le Arcate, Bed and breakfast - standard, None, Via Luigi Einaudi, 15, 85012, PZ, None, None, stagionale, 9, None, None
# CORLETO PERTICARA, POTENZA, Basilicata, Convil Hotel, Albergo, 3 stelle ***, Loc. Conche, 85012, PZ, None, None, annuale, 36, 42857, Cancellazione
# CORLETO PERTICARA, POTENZA, Basilicata, Convil Hotel, Albergo, 3 stelle ***, Loc. Conche, 85012, PZ, 0971 963376, www.convilhotel.it, annuale, 63, 42857, Nuovo inserimento
# CORLETO PERTICARA, POTENZA, Basilicata, Hotel Bellavista, Albergo, 2 stelle **, C.da Tempa Guardiana, s.n.c., 85012, PZ, 0971 963879, www.hotelbellavistacorleto.it, annuale, 19, None, None
# EPISCOPIA, POTENZA, Basilicata, Az. Agr. San Nicola, Agriturismo, ittiturismo, pescaturismo, None, C.da Demanio S.S. Sinnica, 85033, PZ, 0973 782309, www.agriturismonuovosannicola.com, annuale, 10, None, None
# EPISCOPIA, POTENZA, Basilicata, B&B da Geppino, Bed and breakfast - standard, None, Via Felicione, 85033, PZ, None, http://digilander.libero.it//B.B.episcopia/, annuale, 4, None, None
# EPISCOPIA, POTENZA, Basilicata, B&B La Calanga, Bed and breakfast - standard, None, C.da Cucone, 2, 85033, PZ, 0973 655072, http://lapiccolafattoria.blogspot.it/, annuale, 4, None, None
# FILIANO, POTENZA, Basilicata, Resort Pace Sports Village, Albergo, 4 stelle ****, Via Monsignor A. Pace, s.n.c., 85020, PZ, 0971 836977, www.resortpace.com, annuale, 116, None, None
# FORENZA, POTENZA, Basilicata, Az. Agr. Masseria dell'Armenia, Agriturismo, ittiturismo, pescaturismo, None, C.da Monte Madonna dell'Armenia, 85023, PZ, 0971 773390, None, stagionale, 12, None, None
# FORENZA, POTENZA, Basilicata, Le Masserie del Falco, Albergo Rurale, 4 stelle ****, C.da Reddito degli Angeli, 85023, PZ, None, www.masseriedelfalco.it, annuale, 18, None, None
# FRANCAVILLA IN SINNI, POTENZA, Basilicata, Albergo Mango, Albergo, 2 stelle **, Via A. De Gasperi, 46, 85034, PZ, None, None, annuale, 24, None, None
# FRANCAVILLA IN SINNI, POTENZA, Basilicata, Al Giardinetto, Affittacamere, None, C.da Passeggeri, 18, 85034, PZ, 0973 577736, www.dalgiardinetto.it, annuale, 9, None, None
# FRANCAVILLA IN SINNI, POTENZA, Basilicata, Az. Agr. Acqua Bianca, Agriturismo, ittiturismo, pescaturismo, None, C.da Bruscata, 85034, PZ, None, www.agriturismoacquabianca.com, annuale, 15, None, None
# FRANCAVILLA IN SINNI, POTENZA, Basilicata, Az. Agr. Il Crepuscolo, Agriturismo, ittiturismo, pescaturismo, None, C.da Piano Rivitale, 85034, PZ, 0973 256527, www.ilcrepuscolo.com, annuale, 15, None, None
# FRANCAVILLA IN SINNI, POTENZA, Basilicata, Az. Agr. La Fontana del Tasso, Agriturismo, ittiturismo, pescaturismo, None, C.da Scaldaferri, 40, 85034, PZ, 0973 644566, None, annuale, 15, None, None
# FRANCAVILLA IN SINNI, POTENZA, Basilicata, B&B Caramola, Bed and breakfast - standard, None, C.da Scaldaferri, 39 b, 85034, PZ, None, None, stagionale, 6, None, None
# GALLICCHIO, POTENZA, Basilicata, Affittacamere Bella Vista, Affittacamere, None, Via San Rocco, 77, 85010, PZ, None, None, annuale, 4, None, None
# GALLICCHIO, POTENZA, Basilicata, Affittacamere Eldorado, Affittacamere, None, Via Papa Giovanni XXIII, 32, 85010, PZ, None, None, annuale, 4, None, None
# GALLICCHIO, POTENZA, Basilicata, Affittacamere Ida, Affittacamere, None, Via Noce Tordigno, 27, 85010, PZ, None, None, annuale, 4, None, None
# GALLICCHIO, POTENZA, Basilicata, Affittacamere Il Nibbio Reale, Affittacamere, None, Via San Rocco, 70, 85010, PZ, None, None, annuale, 6, None, None
# GALLICCHIO, POTENZA, Basilicata, Affittacamere Salerno Maddalena, Affittacamere, None, Via Roma, 36, 85010, PZ, None, None, annuale, 2, None, None
# GALLICCHIO, POTENZA, Basilicata, Affittacamere Soleluna, Affittacamere, None, Via Papa Giovanni XXIII, 85010, PZ, None, None, annuale, 2, None, None
# GALLICCHIO, POTENZA, Basilicata, Al Bosco delle Api, Affittacamere, None, C.da Parriello, s.n.c., 85010, PZ, None, None, annuale, 5, None, None
# GALLICCHIO, POTENZA, Basilicata, B&B Il Capanno di Giulia, Bed and breakfast - standard, None, Via Nazionale, S.n.c., 85010, PZ, 0971 752126, None, stagionale, 9, None, None
# GALLICCHIO, POTENZA, Basilicata, Casa Via Dora, Affittacamere, None, Via Dora, 21, 85010, PZ, None, None, annuale, 2, None, None
# GENZANO DI LUCANIA, POTENZA, Basilicata, B&B Da Mary, Bed and breakfast - standard, None, Viale XXIV Maggio, 60, 85013, PZ, None, None, annuale, 5, None, None
# GENZANO DI LUCANIA, POTENZA, Basilicata, B&B Il Gattocarlo, Bed and breakfast - standard, None, Corso Vittorio Emanuele, 178, 85013, PZ, 06 3340799, www.ilgattocarlo.it, stagionale, 8, None, None
# GENZANO DI LUCANIA, POTENZA, Basilicata, B&B Palazzo Garibaldi, Bed and breakfast - standard, None, Corso Garibaldi, 42, 85013, PZ, 0971 775967, www.palazzogaribaldi.it, annuale, 8, None, None
# GENZANO DI LUCANIA, POTENZA, Basilicata, Hotel Kristall, Albergo, 3 stelle ***, Piazza Municipio, 8, 85013, PZ, 0971 775284, None, annuale, 47, None, None
# GENZANO DI LUCANIA, POTENZA, Basilicata, I Colli Lucani B&B, Bed and breakfast - Comfort, None, Via Diaz, 46, 85013, PZ, None, None, annuale, 5, None, None
# GRUMENTO NOVA, POTENZA, Basilicata, Agriturismo Parco Verde, Agriturismo, ittiturismo, pescaturismo, None, C.da Spineta, 85050, PZ, 0975 201695, www.agriturismoparcoverde.it, stagionale, 9, None, None
# GRUMENTO NOVA, POTENZA, Basilicata, Albergo Ristorante Grumentum, Albergo, 1 stella *, Corso Vittorio Emanuele, 11, 85050, PZ, 0975 65029, None, annuale, 19, None, None
# GRUMENTO NOVA, POTENZA, Basilicata, Hotel Park Grumentum, Albergo, 3 stelle ***, Loc. Traversiti, 85050, PZ, 0975 65129, www.hotelparkgrumentum.com, annuale, 174, None, None
# GRUMENTO NOVA, POTENZA, Basilicata, Lykos Hotel, Albergo, 3 stelle ***, C.da Mattina, s.n., 85050, PZ, 0975 350769, www.hotel-likos.it, annuale, 108, None, None
# GRUMENTO NOVA, POTENZA, Basilicata, Villa Carmela, Agriturismo, ittiturismo, pescaturismo, None, C.da Torricelle, 2, 85050, PZ, None, None, annuale, 33, None, None
# GUARDIA PERTICARA, POTENZA, Basilicata, Az. Agr. Difesa D'Ischia, Agriturismo, ittiturismo, pescaturismo, None, C.da Difesa D'Ischia, 85010, PZ, 0971 965248, www.agriturismodifesadischia.it, annuale, 31, None, None
# GUARDIA PERTICARA, POTENZA, Basilicata, Az. Agr. Masseria Pinto, Agriturismo, ittiturismo, pescaturismo, None, Strada Provinciale 103 km. 86 - C.da Scalella, 85010, PZ, None, www.masseriapinto.altervista.org, annuale, 25, 42795, Nuovo inserimento
# GUARDIA PERTICARA, POTENZA, Basilicata, Guardia Belvedere, Affittacamere, None, Via San Vito, 4, 85010, PZ, None, www.guardiabelvedere.it, annuale, 14, None, None
# LAGONEGRO, POTENZA, Basilicata, Albergo La Casina Rossa, Albergo, 1 stella *, Via Valle del Noce, 2 - C.da Vurgo, 85042, PZ, None, www.la-casina-rossa.webnode.it, annuale, 11, None, None
# LAGONEGRO, POTENZA, Basilicata, Az. Agr. Ai Carconi, Agriturismo, ittiturismo, pescaturismo, None, C.da Carconi - Svincolo A3 Lagonegro Nord - Potenza, 85042, PZ, None, None, annuale, 12, None, None
# LAGONEGRO, POTENZA, Basilicata, Az. Agr. Il Bucaneve, Agriturismo, ittiturismo, pescaturismo, None, C.da Petina Chiana, 85042, PZ, 0973 21021, www.agriturismoilbucaneve.it, annuale, 13, None, None
# LAGONEGRO, POTENZA, Basilicata, Hotel Caimo Bed-Breakfast, Albergo, 2 stelle **, Via dei Gladioli, 3, 85042, PZ, 0973 21621, www.hotelcaimo.com, annuale, 37, None, None
# LAGONEGRO, POTENZA, Basilicata, Hotel San Nicola, Albergo, 3 stelle ***, Piazza della Repubblica, 27, 85042, PZ, None, None, annuale, 28, None, None
# LAGONEGRO, POTENZA, Basilicata, Locanda da Federico, Affittacamere, None, Via Carmine, 15, 85042, PZ, 0973 21742, www.locandadafederico.com, annuale, 18, None, None
# LAGONEGRO, POTENZA, Basilicata, Midi Hotel, Albergo, 3 stelle ***, Viale Colombo, 76, 85042, PZ, None, None, annuale, 90, 42892, Cancellazione
# LAGONEGRO, POTENZA, Basilicata, Midi Hotel, Albergo, 3 stelle ***, Viale Colombo, 76, 85042, PZ, 0973 41186, www.midihotel.it, annuale, 151, 42892, Nuovo inserimento
# LAGONEGRO, POTENZA, Basilicata, Pensione Oliva Giselda, Albergo, 1 stella *, Via San Vito, 2, 85042, PZ, None, None, annuale, 16, None, None
# LATRONICO, POTENZA, Basilicata, B&B Delcimarotto, Bed and breakfast - standard, None, Vico Bovio, 25, 85043, PZ, None, www.bbdelcimarotto.com, annuale, 10, None, None
# LATRONICO, POTENZA, Basilicata, B&B Delle Grotte, Bed and breakfast - standard, None, Via Cremonesi, 34 - LOc. Calda Terme, 85043, PZ, None, www.bbdellegrotte.it, annuale, 6, None, None
# LATRONICO, POTENZA, Basilicata, B&B Delle Terme, Bed and breakfast - standard, None, Via Serrone, 8, 85043, PZ, 0973 859408, None, annuale, 3, None, None
# LATRONICO, POTENZA, Basilicata, B&B di Via Pindaro, Bed and breakfast - standard, None, Via Pindaro, 1, 85043, PZ, None, None, annuale, 4, None, None
# LATRONICO, POTENZA, Basilicata, B&B Il Casaletto, Bed and breakfast - standard, None, Via Nicotera, 7/A, 85043, PZ, None, www.contiriccardo.it/casalettob&b, annuale, 7, None, None
# LATRONICO, POTENZA, Basilicata, Hotel Terme, Albergo, 3 stelle ***, C.da Calda, 85043, PZ, None, www.htlterme.it, annuale, 48, 42926, Nuovo inserimento
# LATRONICO, POTENZA, Basilicata, Rifugio La Faggeta, Rifugio di montagna, None, Via Malboschetto, s.n.c., 85043, PZ, None, facebook.com/rifugiolafaggeta, annuale, 12, None, None
# LAURENZANA, POTENZA, Basilicata, Az. Agr. L'Abetina, Agriturismo, ittiturismo, pescaturismo, None, Loc. Abetina, 85014, PZ, None, None, annuale, 13, None, None
# LAURENZANA, POTENZA, Basilicata, B&B Il Borgo, Bed and breakfast - standard, None, Piazza Domenico Asselta, 6, 85014, PZ, 0971 960900, www.borgolaurenzana.it, annuale, 8, None, None
# LAURENZANA, POTENZA, Basilicata, B&B Le Sette Torri, Bed and breakfast - standard, None, Via Carlo Pisacane, 4, 85014, PZ, None, www.lesettetorri.it, stagionale, 5, None, None
# LAURENZANA, POTENZA, Basilicata, L'Antico Palazzo, Affittacamere, None, Via Carlo Pisacane, 13, 85014, PZ, None, None, annuale, 6, None, None
# LAURIA, POTENZA, Basilicata, Az. Agr. Miele, Agriturismo, ittiturismo, pescaturismo, None, C.da Montagnola, 25 - Fraz. Seluci, 85044, PZ, 0973 827046, www.agriturismomiele.com, annuale, 18, None, None
# LAURIA, POTENZA, Basilicata, B&B Masseria Cozzi, Bed and breakfast - standard, None, C.da Starsia - Fraz. Galdo, 85044, PZ, None, None, annuale, 8, 42948, Nuovo inserimento
# LAURIA, POTENZA, Basilicata, Guest House GeMar, Affittacamere, None, C.da Cavallo, 85044, PZ, None, www.guesthousegemar.it, annuale, 13, None, None
# LAURIA, POTENZA, Basilicata, Happy Moments Resort Hotel, Albergo, 3 stelle ***, C.da Mosella - Loc. Galdo, 85044, PZ, 0973 624907, www.happymomentshotel.com, annuale, 30, None, None
# LAURIA, POTENZA, Basilicata, Hotel Isola di Lauria, Albergo, 3 stelle ***, Via Insorti d'Ungheria, 6, 85044, PZ, 0973 823962, www.hotelisoladilauria.it, annuale, 99, None, None
# LAURIA, POTENZA, Basilicata, Hotel San Domenico, Albergo, 3 stelle ***, C.da S. Alfonso, 305, 85044, PZ, 0973 825793, www.sandomenicohotel.com, annuale, 18, None, None
# LAURIA, POTENZA, Basilicata, Pensione Vittoria, Albergo, 1 stella *, Piazza Plebiscito, 31, 85044, PZ, None, None, annuale, 11, None, None
# LAURIA, POTENZA, Basilicata, Rifugio Conserva, Rifugio di montagna, None, Contrada Conserva, 85044, PZ, 0973 22408, None, annuale, 13, None, None
# LAVELLO, POTENZA, Basilicata, Affittacamere Mozart, Affittacamere, None, Corso G. Fortunato, 136, 85024, PZ, None, None, annuale, 11, None, None
# LAVELLO, POTENZA, Basilicata, Albergo Italia, Albergo, 2 stelle **, Via Giovanni Robbe, 21, 85024, PZ, 0972 88745, www.albergoitalialavello.it, annuale, 22, None, None
# LAVELLO, POTENZA, Basilicata, Forentum Suite, Affittacamere, None, Via Cavour, 3, 85024, PZ, 0972 85147, www.anticacantinaforentum.com, annuale, 3, None, None
# LAVELLO, POTENZA, Basilicata, Hotel Dante, Albergo, 3 stelle ***, Vico II Dante, 6/8, 85024, PZ, None, www.dantehotel.it, annuale, 23, None, None
# LAVELLO, POTENZA, Basilicata, Hotel in Fiore, Albergo, 2 stelle **, Via Torino, 14/A, 85024, PZ, None, www.hotelinfiore.it, annuale, 14, 42765, Nuovo inserimento
# LAVELLO, POTENZA, Basilicata, Hotel La Coccinella, Albergo, 3 stelle ***, Via Pescara, 35, 85024, PZ, 0972 85337, www.albergococcinella.com, annuale, 24, None, None
# LAVELLO, POTENZA, Basilicata, Locanda Largo Casale, Affittacamere, None, Largo Casale, 24/26, 85024, PZ, 0972 86090, www.largocasale.it, annuale, 4, None, None
# MARATEA, POTENZA, Basilicata, Affittacamere Da Zio Pino, Affittacamere, None, Via Santa Venere, 17 - Fraz. Fiumicello, 85046, PZ, 0973 877293, www.ziopinomaratea.com, annuale, 12, None, None
# MARATEA, POTENZA, Basilicata, Affittacamere Fiorella, Affittacamere, None, Via Santavenere, snc - Fraz. Fiumicello, 85046, PZ, None, None, stagionale, 21, 42900, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, Agriturismo Mararanch, Agriturismo, ittiturismo, pescaturismo, None, Via del Mare, 1 - Fraz. Castrocucco, 85046, PZ, 0973 871716, www.mararanch.it, stagionale, 60, None, None
# MARATEA, POTENZA, Basilicata, Albergo Cala del Citro, Albergo, 3 stelle ***, Via Rovina - Fraz. Marina, 85046, PZ, None, www.caladelcitro.it, annuale, 14, None, None
# MARATEA, POTENZA, Basilicata, B&B 'A Suata, Bed and breakfast - standard, None, Via Santavenere, s.n.c. - Fraz. Fiumicello, 85046, PZ, None, None, annuale, 6, 42956, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B BABI, Bed and breakfast - standard, None, Via della Torre, 5 (Zona Porticello) - Loc. Acquafredda, 85046, PZ, None, www.babimaratea.it, stagionale, 7, None, None
# MARATEA, POTENZA, Basilicata, B&B Blanda bed & breakfast, Bed and breakfast - standard, None, Via dell'Amicizia, 12 - Fraz. Castrocucco, 85046, PZ, None, www.blandabed.it, stagionale, 6, None, None
# MARATEA, POTENZA, Basilicata, B&B Calandrella, Bed and breakfast - standard, None, Via delle Querce, 1 - Fraz. Cersuta, 85046, PZ, None, None, stagionale, 7, None, None
# MARATEA, POTENZA, Basilicata, B&B Il Vecchio e il Mare, Bed and breakfast - standard, None, Via Santavenere, 21 - Fraz. Fiumicello, 85046, PZ, None, None, annuale, 12, None, None
# MARATEA, POTENZA, Basilicata, B&B La Casa del Gelso, Bed and breakfast - standard, None, Via Timpone, 47 - Fraz. Acquafredda, 85046, PZ, 0973 878108, www.lacasadelgelso.it, stagionale, 5, None, None
# MARATEA, POTENZA, Basilicata, B&B La Giancarla, Bed and breakfast - comfort, None, Via Prazza Inferiore, 16, 85046, PZ, None, www.lagiancarla.it, annuale, 6, None, None
# MARATEA, POTENZA, Basilicata, B&B La Giara, Bed and breakfast - standard, None, Via Garottoli, 32 - Fraz. Acquafredda, 85046, PZ, None, www.lagiaramaratea.it, annuale, 9, None, None
# MARATEA, POTENZA, Basilicata, B&B Laino, Bed and breakfast - standard, None, Via Rasi, 4/c - Fraz. Fiumicello, 85046, PZ, 0973 876506, www.beblaino.it, annuale, 9, None, None
# MARATEA, POTENZA, Basilicata, B&B La Residenza, Bed and breakfast - standard, None, Via Vallone Arenara, 6 - Fraz. Marina di Maratea, 85046, PZ, None, None, stagionale, 6, None, None
# MARATEA, POTENZA, Basilicata, B&B La Rotondella, Bed and breakfast - Comfort, None, Via Timponi, 20 - Fraz. Acquafredda, 85046, PZ, 0973 878078, www.bblarotondellamaratea.it, annuale, 2, None, None
# MARATEA, POTENZA, Basilicata, B&B La Torretta, Bed and breakfast - standard, None, Via Cersuta, 61, 85046, PZ, None, www.beblatorretta.it, annuale, 4, None, None
# MARATEA, POTENZA, Basilicata, B&B Le Chiane, Bed and breakfast - standard, None, Via delle Querce, 3 - C.da Cersuta, 85046, PZ, 0973 871864, None, stagionale, 6, None, None
# MARATEA, POTENZA, Basilicata, B&B Le Tre Casette, Bed and breakfast - Comfort, None, Via Porto, 48, 85046, PZ, None, None, annuale, 5, 42845, Cancellazione
# MARATEA, POTENZA, Basilicata, B&B Le Tre Casette, Bed and breakfast - Comfort, None, Via Porto, 48, 85046, PZ, 0973 876125, www.letrecasette.wordpress.com, stagionale, 6, 42845, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B Marabea, Bed and breakfast - standard, None, Via La Rosa, 17, 85046, PZ, 0973 877638, www.marabea.it, stagionale, 5, None, None
# MARATEA, POTENZA, Basilicata, B&B Maratea - Casa Grimaldi, Bed and breakfast - standard, None, Via San Nicola, 19, 85046, PZ, None, None, stagionale, 3, 42795, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B Maratea Garden House, Bed and breakfast - standard, None, Via Canalelli, 2 - Fraz. Acquafredda, 85046, PZ, 0973 878203, www.bbmarateagardenhouse.com, annuale, 4, None, None
# MARATEA, POTENZA, Basilicata, B&B Maratea Vacanze, Bed and breakfast - standard, None, Via Acquafredda-Nitti, 2/A - Fraz. Acquafredda, 85046, PZ, None, None, annuale, 10, 42894, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B Mariposa, Bed and breakfast - standard, None, Via Cersuta, 23, 85046, PZ, None, None, annuale, 5, None, None
# MARATEA, POTENZA, Basilicata, B&B Nefer, Bed and breakfast - standard, None, Via Cersuta, 27, 85046, PZ, 0973 871828, www.bbnefer.it, annuale, 8, 42795, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B Nonna Vincenza, Bed and breakfast - standard, None, Via Nitti, 16 - Loc. Acquafredda, 85046, PZ, None, http://.itbebnonnavincenzamaratea.com, annuale, 12, None, None
# MARATEA, POTENZA, Basilicata, B&B Sabrina, Bed and breakfast - standard, None, Via Nazionale, 14 - Fraz. Cersuta, 85046, PZ, None, None, annuale, 4, 42857, Cancellazione
# MARATEA, POTENZA, Basilicata, B&B Sabrina, Bed and breakfast - standard, None, Via Nazionale, 14 - Fraz. Cersuta, 85046, PZ, 0973 871812, None, annuale, 6, 42857, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B Silvana, Bed and breakfast - Comfort, None, Via dell'amicizia, 20 - ÔøΩ, 85046, PZ, None, www.bebsilvanamaratea.com, annuale, 7, None, None
# MARATEA, POTENZA, Basilicata, B&B Tatiana, Bed and breakfast - standard, None, Via Ondano, 11/A, 85046, PZ, None, www.ilovebandb.com, stagionale, 8, None, None
# MARATEA, POTENZA, Basilicata, B&B Tenuta Palmieri, Bed and breakfast - standard, None, Via Cersuta, 29/A - Fraz. Cersuta, 85046, PZ, 0973 878102, www.tenutapalmieri.com, stagionale, 3, None, None
# MARATEA, POTENZA, Basilicata, B&B Vista Mare, Bed and breakfast - standard, None, Via Citrosello, 28/I - Fraz. Marina di Maratea, 85046, PZ, None, www.facebook.com/bedandbreakfatvistamaremaratea/, annuale, 6, 42816, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, B&B Zia Yaya, Bed and breakfast - standard, None, Via Cersuta, 9 - Fraz. Cersuta, 85046, PZ, None, None, stagionale, 4, 42898, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, Casa Vacanze Licasale, Casa e appartamento per vacanze, None, Via Grotte, 23 - Fraz. Porto di Maratea, 85046, PZ, None, None, stagionale, 4, None, None
# MARATEA, POTENZA, Basilicata, Club Residence Pianetamaratea, Casa e appartamento per vacanze, None, C.da S. Caterina, 233, 85046, PZ, 0973 871969, www.pianetamaratea.com, stagionale, 1255, 42857, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, D'Orlando Concetta, Casa e appartamento per vacanze, None, Via Fiumicello, 58 - Fraz. Fiumicello, 85046, PZ, 0973 876939, www.villaglauca.it, stagionale, 6, None, None
# MARATEA, POTENZA, Basilicata, Grand Hotel Pianetamaratea, Albergo, 4 stelle ****, C.da Santa Caterina, 50, 85046, PZ, 0973 871948, www.grandhotelpianetamaratea.it, annuale, 480, 42795, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, HF Fiorella B&B, Bed and breakfast - standard, None, Via Santavenere, 21, 85046, PZ, 0973 876514, None, stagionale, 12, None, None
# MARATEA, POTENZA, Basilicata, Hotel Capo Casale, Albergo, 3 stelle ***, Via Capo Casale, 85046, PZ, 0973 871049, www.capocasale.it, annuale, 35, None, None
# MARATEA, POTENZA, Basilicata, Hotel Gabbiano, Albergo, 3 stelle ***, Via Luppa, 24 - Fraz. Acquafredda, 85046, PZ, 0973 878076, www.hotelgabbianomaratea.it, stagionale, 84, None, None
# MARATEA, POTENZA, Basilicata, Hotel La Dimora del Cardinale, Albergo, 3 stelle ***, Via Cardinale Ginnari, 1, 85046, PZ, 0973 877712, www.ladimoradelcardinale.it, annuale, 38, None, None
# MARATEA, POTENZA, Basilicata, Hotel Martino, Albergo, 3 stelle ***, Via Citrosello, 16 - Fraz. Marina di Maratea, 85046, PZ, 0973 879323, None, annuale, 90, None, None
# MARATEA, POTENZA, Basilicata, Hotel Murmann, Albergo, 4 stelle ****, Via Fiumicello, 2, 85046, PZ, 0973 873185, www.hotelmurmann.it, stagionale, 64, None, None
# MARATEA, POTENZA, Basilicata, Hotel Ristorante Borgo La Tana, Albergo, 3 stelle ***, Via dell'Amicizia, 22 - Fraz. Castrocucco, 85046, PZ, 0973 871671, www.latanahotelmaratea.it, annuale, 110, None, None
# MARATEA, POTENZA, Basilicata, Hotel San Diego, Albergo, 3 stelle ***, S.S. 18 - Via Nazionale, 59 - Fraz. Acquafredda, 85046, PZ, 0973 878227, www.hotelsandiego.it, annuale, 144, None, None
# MARATEA, POTENZA, Basilicata, Hotel Santavenere, Albergo, 5 stelle lusso *****, Via Conte Stefano Rivetti, 1 - Fraz. Fiumicello, 85046, PZ, 0973 877654, www.santavenere.it, annuale, 52, None, None
# MARATEA, POTENZA, Basilicata, Hotel Santavenere - Dipendenza, Albergo, 5 stelle lusso *****, Via Conte Stefano Rivetti, 1 - Fraz. Fiumicello, 85046, PZ, 0973 877654, www.santavenere.it, annuale, 18, None, None
# MARATEA, POTENZA, Basilicata, Hotel Settebello, Albergo, 3 stelle ***, Via Fiumicello, 52 - Fraz. Fiumicello, 85046, PZ, 0973 877204, www.hotelsettebellomaratea.com, stagionale, 78, None, None
# MARATEA, POTENZA, Basilicata, Hotel Spa Villa del Mare, Albergo, 4 stelle ****, Via Nazionale, 18 - Fraz. Acquafredda, 85046, PZ, 0973 878102, www.hotelvilladelmare.com, stagionale, 168, None, None
# MARATEA, POTENZA, Basilicata, Hotel Villa Cheta Restaurant, Albergo, 4 stelle ****, Via Timpone, 46 - Fraz. Acquafredda, 85046, PZ, 0973 878135, www.villacheta.it, stagionale, 69, None, None
# MARATEA, POTENZA, Basilicata, Hotel Villa degli Aranci, Albergo, 3 stelle ***, Via Profiti, 8 - Fraz. Porto di Maratea, 85046, PZ, 0973 876344, None, stagionale, 57, None, None
# MARATEA, POTENZA, Basilicata, Hotel Villa delle Meraviglie, Albergo, 3 stelle ***, C.da Ogliastro, 85046, PZ, 0973 877949, www.hotelvilladellemeraviglie.com, stagionale, 35, None, None
# MARATEA, POTENZA, Basilicata, Illicini, Albergo, 3 stelle ***, Loc. Illicini - Fraz. Marina di Maratea, 85046, PZ, None, www.illicini.it, stagionale, 25, 42857, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, La Dimora di Alfonso, Affittacamere, None, Via Santavenere, 151 - Fraz. Fiumicello, 85046, PZ, 0973 877386, www.ladimoradialfonsomaratea.com, annuale, 11, None, None
# MARATEA, POTENZA, Basilicata, La Locanda delle Donne Monache, Albergo, 4 stelle ****, Via Carlo Mazzei, 4, 85046, PZ, 0973 876203, www.locandamonache.com, stagionale, 60, None, None
# MARATEA, POTENZA, Basilicata, La Secca, Affittacamere, None, Via Secca, 4 - Fraz. Secca di Castrocucco, 85046, PZ, None, www.lasecca.com, annuale, 12, None, None
# MARATEA, POTENZA, Basilicata, Le Stanze di Laura, Casa e appartamento per vacanze, None, Via Dietro l'Annunziata, 31, 85046, PZ, None, www.lestanzedilaura.it, annuale, 5, None, None
# MARATEA, POTENZA, Basilicata, Olivo Filomena, Casa e appartamento per vacanze, None, Via Santa Teresa, s.n. - Fraz. Marina di Maratea, 85046, PZ, None, None, stagionale, 6, None, None
# MARATEA, POTENZA, Basilicata, ReginElena B&B, Bed and breakfast - comfort, None, Via Alessandro Mandarini, 28, 85046, PZ, None, None, annuale, 6, 42779, Nuovo inserimento
# MARATEA, POTENZA, Basilicata, Villacarolina, Casa e appartamento per vacanze, None, Via Largo Cappuccini, 2, 85046, PZ, 0973 877721, www.costadimaratea.com/villacarolina, stagionale, 10, None, None
# MARATEA, POTENZA, Basilicata, Villa Caterina, Affittacamere, None, Via Nazionale S.S. 18 n. 35 - C.da Cersuta, 85046, PZ, None, www.villacaterinamaratea.it, annuale, 8, None, None
# MARATEA, POTENZA, Basilicata, Villaggio - Camping Maratea, Villaggio-camping, None, Via del Mare, 1/2 - Loc. Castrocucco, 85046, PZ, 0973 871699, www.campingmaratea.it, stagionale, 600, 42857, Nuovo inserimento
# MARSICO NUOVO, POTENZA, Basilicata, Affittacamere Agrivacanze, Affittacamere, None, Via Vitt. Emanuele Vico III, 4, 85052, PZ, 0975 1960346, www.agrivacanze.eu, annuale, 3, None, None
# MARSICO NUOVO, POTENZA, Basilicata, Agriturismo Vignola, Agriturismo, ittiturismo, pescaturismo, None, C.da Capo D'Acqua, 11, 85052, PZ, 0975 342511, www.agriturismovignola.com, annuale, 19, None, None
# MARSICO NUOVO, POTENZA, Basilicata, Al Pergolato, Casa e appartamento per vacanze, None, C.da Calabritto, 3, 85052, PZ, 0975 342108, None, annuale, 9, None, None
# MARSICO NUOVO, POTENZA, Basilicata, Az. Agr. Casaletto, Agriturismo, ittiturismo, pescaturismo, None, Via Acqua Solfata - Fraz. Galaino, 85052, PZ, None, None, annuale, 12, None, None
# MARSICO NUOVO, POTENZA, Basilicata, B&B Parisi, Bed and breakfast - standard, None, C.da Valle Casale, 6 - Fraz. Galaino, 85052, PZ, None, None, stagionale, 3, None, None
# MARSICO NUOVO, POTENZA, Basilicata, Fontana delle Brecce, Affittacamere, None, Loc. Fontana delle Brecce, 85052, PZ, None, www.fontanadellebrecce.it, annuale, 6, 42846, Nuovo inserimento
# MARSICO NUOVO, POTENZA, Basilicata, Il Canneto Masseria Blasi, Agriturismo, ittiturismo, pescaturismo, None, C.da Canneto - Fontana Capano - Galaino, 85052, PZ, None, www.agriturismoilcanneto.net, annuale, 9, None, None
# MARSICOVETERE, POTENZA, Basilicata, B&B AddÔøΩ Mast Giuann, Bed and breakfast - standard, None, Via Guglielmo Marconi, 37 - Fraz. Villa D'Agri, 85050, PZ, None, www.bedebreakfast-mastgiuann.it, annuale, 4, None, None
# MARSICOVETERE, POTENZA, Basilicata, DM Service, Affittacamere, None, Corso Garibaldi, 34, 85050, PZ, None, None, annuale, 2, None, None
# MARSICOVETERE, POTENZA, Basilicata, Hotel Sirio, Albergo, 3 stelle ***, Via Nazionale, 27 - Fraz. Villa D'Agri, 85050, PZ, 0975 354984, www.hotelsirio.info, annuale, 88, None, None
# MARSICOVETERE, POTENZA, Basilicata, Il Querceto Az. Bioecologica, Agriturismo, ittiturismo, pescaturismo, None, Podere Querceto - Loc. Barricelle, 85050, PZ, 0975 69339, www.ilquerceto.it, annuale, 23, None, None
# MELFI, POTENZA, Basilicata, Albergo Il Tetto, Albergo, 1 stella *, Piazza IV Novembre, 1, 85025, PZ, 0972 252555, www.hosteliltetto.com, annuale, 66, None, None
# MELFI, POTENZA, Basilicata, B&B Alla Corte Blu, Bed and breakfast - standard, None, Via Monteverde, s.n.c. - C.da Bicocca, 85025, PZ, 0971 440999, www.allacorteblu.it, annuale, 8, None, None
# MELFI, POTENZA, Basilicata, B&B Capricci di Miria, Bed and breakfast - standard, None, Via Ischia, s.n.c. - C.da Ferrara, 85025, PZ, 0972 24531, www.capriccidimiria.it, stagionale, 3, None, None
# MELFI, POTENZA, Basilicata, B&B Dolce Risveglio, Bed and breakfast - Comfort, None, Via Cristoforo Colombo, 11, 85025, PZ, 0972 23465, www.bebdolcerisveglio.it, annuale, 3, None, None
# MELFI, POTENZA, Basilicata, B&B Donna Ida 1900, Bed and breakfast - standard, None, Vico Bellini, 19, 85025, PZ, None, None, stagionale, 4, None, None
# MELFI, POTENZA, Basilicata, B&B Il Fiore della Vita, Bed and breakfast - standard, None, Via A. Di Napoli, 1/a, 85025, PZ, None, www.ilfioredellavita.it, stagionale, 4, None, None
# MELFI, POTENZA, Basilicata, Casa Isabela Luxury Rooms, Affittacamere, None, Viale G. D'Annunzio, 31, 85025, PZ, None, None, annuale, 6, 42989, Nuovo inserimento
# MELFI, POTENZA, Basilicata, Casa Laviano, Bed and breakfast - Comfort, None, Via F. Nitti, 43, 85025, PZ, None, www.casalaviano.it, annuale, 8, None, None
# MELFI, POTENZA, Basilicata, Federico II, Albergo, 3 stelle ***, Z. Ind. San Nicola - Fraz. San Nicola di Melfi, 85025, PZ, 0972 78174, www.hotelfederico.it, annuale, 90, None, None
# MELFI, POTENZA, Basilicata, Hotel Due Pini, Albergo, 4 stelle ****, Piazzale Stazione, s.n., 85025, PZ, 0972 21031, www.hotelduepini.com, annuale, 84, None, None
# MELFI, POTENZA, Basilicata, Hotel Farese, Albergo, 3 stelle ***, Fraz. Foggianello, 1, 85025, PZ, 0972 236478, www.hotelfarese.it, annuale, 31, None, None
# MELFI, POTENZA, Basilicata, Hotel Il Castagneto, Albergo, 4 stelle ****, Via Monticchio ex S.S. 401 km. 3+100, 85025, PZ, 0972 670018, www.hotelcastagnetomelfi.it, annuale, 83, None, None
# MELFI, POTENZA, Basilicata, Hotel Novecento, Albergo, 3 stelle ***, C.da Incoronata, s.n.c., 85025, PZ, 0972 237470, www.novecentomelfi.it, annuale, 24, None, None
# MELFI, POTENZA, Basilicata, Le Stanze dell'Imperatore B&B, Bed and breakfast - standard, None, Vico Neve (Piazza Umberto I), 4-6, 85025, PZ, 0972 21614, www.lestanzedellimperatore.it, annuale, 8, None, None
# MELFI, POTENZA, Basilicata, R&B Nonna Ninetta, Affittacamere, None, Via San Teodoro, 31, 85025, PZ, None, www.nonnaninettamelfi.com, annuale, 4, None, None
# MELFI, POTENZA, Basilicata, Relais La Fattoria, Albergo, 4 stelle ****, S.S. 303 - Uscita Melfi Nord, 85025, PZ, 0972 239121, www.relaislafattoria.it, annuale, 254, None, None
# MISSANELLO, POTENZA, Basilicata, La Rosa, Affittacamere, None, Piazza Mercato, 3, 85010, PZ, None, None, annuale, 2, None, None
# MOLITERNO, POTENZA, Basilicata, Agriturismo Il Giglio del Cavaliere, Agriturismo, ittiturismo, pescaturismo, None, C.da Fontana Debole, 85047, PZ, None, None, annuale, 18, None, None
# MOLITERNO, POTENZA, Basilicata, Albergo Vecchio Ponte, Albergo, 2 stelle **, C.da Piano di Maglie, 1, 85047, PZ, None, www.albergovecchioponte.it, annuale, 39, None, None
# MOLITERNO, POTENZA, Basilicata, Az. Agr. Vecchia Fattoria, Agriturismo, ittiturismo, pescaturismo, None, C.da Piano di Vertola, 85047, PZ, 0975 67327, www.agriturismolavecchiafattoriabasilicata.com, annuale, 28, None, None
# MOLITERNO, POTENZA, Basilicata, B&B Fronte al Museo, Bed and breakfast - standard, None, Via Mazzini, 24, 85047, PZ, None, None, annuale, 6, 42795, Nuovo inserimento
# MOLITERNO, POTENZA, Basilicata, Casa Camelia, Casa e appartamento per vacanze, None, Viale Domenico Galante, 39, 85047, PZ, 0975 67150, www.casa-camelia.it, annuale, 3, None, None
# MOLITERNO, POTENZA, Basilicata, L'Antico Ritrovo, Affittacamere, None, Via Ortone, 93, 85047, PZ, 0975 567084, www.anticoritrovo.eu, annuale, 9, None, None
# MOLITERNO, POTENZA, Basilicata, Pensione Santo Martino, Albergo, 1 stella *, C.da Santo Martino, 21, 85047, PZ, 0975 67124, www.locsantomartino.191.it, annuale, 18, None, None
# MONTEMURRO, POTENZA, Basilicata, Affittacamere Il Castelluccio, Affittacamere, None, C.da Castelluccio, 85053, PZ, 0971 753411, None, stagionale, 24, None, None
# MURO LUCANO, POTENZA, Basilicata, Az. Agr. Nonna Maria, Agriturismo, ittiturismo, pescaturismo, None, C.da Cerrito, S.n.c., 85054, PZ, 0976 2288, None, annuale, 6, None, None
# MURO LUCANO, POTENZA, Basilicata, B&B Il Querceto, Bed and breakfast - standard, None, Via Fontanile, 85054, PZ, 0976 71067, www.ilquerceto.eu, annuale, 9, None, None
# MURO LUCANO, POTENZA, Basilicata, Hotel delle Colline, Albergo, 2 stelle **, Via Belvedere, 85054, PZ, 0976 2192, www.hoteldellecolline.com, annuale, 41, None, None
# MURO LUCANO, POTENZA, Basilicata, Hotel Miramonti, Albergo, 3 stelle ***, S.S. 7 - K.m. 411 - C.da Fontanelle, 85054, PZ, 0976 723028, www.albergomiramonti.it, annuale, 30, None, None
# MURO LUCANO, POTENZA, Basilicata, Il Terrazzo delle Stelle, Bed and breakfast - standard, None, Via Piazza di Mezzo, 5/B, 85054, PZ, None, None, annuale, 7, None, None
# NEMOLI, POTENZA, Basilicata, Albergo-Ristorante Da MimÔøΩ, Albergo, 3 stelle ***, Via Domenico Di Lascio, 7 - Loc. Lago Sirino, 85040, PZ, 0973 40586, www.montesirino.it, annuale, 18, None, None
# NEMOLI, POTENZA, Basilicata, Az. Agr. Agribosco, Agriturismo, ittiturismo, pescaturismo, None, C.da Fiumara, s.n., 85040, PZ, 0973 40348, www.agribosco.eu, annuale, 23, None, None
# NEMOLI, POTENZA, Basilicata, B&B Al Boschetto, Bed and breakfast - standard, None, Via Domenico Di Lascio, 1 - Lago Sirino, 85040, PZ, None, www.boschetto.net, annuale, 9, 42900, Nuovo inserimento
# NEMOLI, POTENZA, Basilicata, B&B Nemus Olim, Bed and breakfast - standard, None, Via Regina Margherita, 27, 85040, PZ, None, None, stagionale, 4, 43026, Cancellazione
# NOEPOLI, POTENZA, Basilicata, Agriturismo Al Patio, Agriturismo, ittiturismo, pescaturismo, None, C.da Pantano, s.n., 85035, PZ, 0973 92020, www.agriturismoalpatio.it, annuale, 18, None, None
# NOEPOLI, POTENZA, Basilicata, B&B La Primula Rossa, Bed and breakfast - standard, None, Via Roma, 35, 85035, PZ, None, www.bblaprimularossa.it, stagionale, 6, None, None
# OPPIDO LUCANO, POTENZA, Basilicata, Hotel Lo Zodiaco, Albergo, 2 stelle **, Via Appia, s.n., 85015, PZ, 0971 748142, www.ristorantelozodiaco.net, annuale, 56, None, None
# PALAZZO SAN GERVASIO, POTENZA, Basilicata, Hotel Villa Ester, Albergo, 3 stelle ***, S.S. 168 km. 30,500, 85026, PZ, 0972 44192, www.hotelvillaester.it, annuale, 25, None, None
# PALAZZO SAN GERVASIO, POTENZA, Basilicata, Palatium S.G., Affittacamere, None, Via Roma, 3, 85026, PZ, None, www.palatiumsg.it, annuale, 7, None, None
# ...
# PISTICCI, MATERA, Basilicata, Agriturismo Casapanetta, Agriturismo, ittiturismo, pescaturismo, None, C.da San Basilio, s.n.c. - Fraz. Marconia, 75015, MT, None, www.casapanetta.com, annuale, 30, None, None
# PISTICCI, MATERA, Basilicata, Agriturismo da Dino, Agriturismo, ittiturismo, pescaturismo, None, S.S. 106 - C.da Casinello Pod. 27 - Fraz. Marconia, 75015, MT, None, www.agriturismodadino.it, annuale, 8, None, None
# PISTICCI, MATERA, Basilicata, Agriturismo Terranova, Agriturismo, ittiturismo, pescaturismo, None, C.da Terranova, s.n.c., 75020, MT, 0835 191367, None, annuale, 6, None, None
# PISTICCI, MATERA, Basilicata, Az. Agr. Il Calanco, Agriturismo, ittiturismo, pescaturismo, None, Strada per Craco-Peschiera - C.da Santa Lucia, 75015, MT, 0835 462118, www.ilcalanco.it, annuale, 18, None, None
# PISTICCI, MATERA, Basilicata, B&B Le Terrazze del Casale, Bed and breakfast - standard, None, C.da Vetrano, S.n.c., 75015, MT, 0835 583530, www.leterrazzedelcasale.it, annuale, 8, None, None
# PISTICCI, MATERA, Basilicata, Casa di Soggiorno Villaugusta, Casa e appartamento per vacanze, None, C.da Terranova, 75015, MT, None, None, annuale, 2, 42948, Nuovo inserimento
# PISTICCI, MATERA, Basilicata, Case in Vacanza, Casa e appartamento per vacanze, None, Lido di Macchia - Fraz. Marina di Pisticci, 75020, MT, 080 3051749, www.caseinvacanza.com, stagionale, 52, None, None
# PISTICCI, MATERA, Basilicata, Hotel degli Argonauti, Albergo, 4 stelle ****, C.da Lido di Macchia - Fraz. Marina di Pisticci, 75020, MT, 0835 470140, www.edenviaggi.it, stagionale, 268, None, None
# PISTICCI, MATERA, Basilicata, Hotel Torre Fiore, Albergo, 4 stelle ****, C.da Terranova, s.n.c., 75015, MT, 0835 580915, www.hoteltorrefiore.com, stagionale, 53, None, None
# PISTICCI, MATERA, Basilicata, Masseria Macchia & Relais San Pio, Agriturismo, ittiturismo, pescaturismo, None, C.da Macchia - S.S. 106 km. 444 - Fraz. Marina di Pisticci, 75015, MT, None, www.masseriamacchia.it, stagionale, 50, None, None
# PISTICCI, MATERA, Basilicata, Porto degli Argonauti Apartments, Casa e appartamento per vacanze, None, Piazzetta Porto degli Argonauti - Lido di Macchia - Fraz. Marina di Pisticci, 75020, MT, 080 3051749, www.caseinvacanza.com, stagionale, 24, None, None
# PISTICCI, MATERA, Basilicata, Scannaturco SocietÔøΩ Agricola, Agriturismo, ittiturismo, pescaturismo, None, C.da Scannaturco - Fraz. Marconia - San Basilio Mare, 75020, MT, None, None, stagionale, 15, None, None
# PISTICCI, MATERA, Basilicata, Tenuta Visconti  San Teodoro Nuovo, Agriturismo, ittiturismo, pescaturismo, None, C.da San Teodoro Nuovo - Fraz. Marconia, 75015, MT, 0835 470042, www.tenutavisconti.com, stagionale, 33, None, None
# PISTICCI, MATERA, Basilicata, Ti Blu Village Club, Albergo, 4 stelle ****, C.da Scannaturco - Fraz. Marina di Pisticci, 75015, MT, 0835 472407, www.th-resorts.com, stagionale, 1209, None, None
# POLICORO, MATERA, Basilicata, Agriturismo BioMele, Agriturismo, ittiturismo, pescaturismo, None, Via Monte Grappa, 1 - Loc. Torre Mozza, 75025, MT, 0835 1761040, None, annuale, 6, None, None
# POLICORO, MATERA, Basilicata, Albergo Hostaria Al Buco, Albergo, 1 stella *, Via Napoli, 16, 75025, MT, 0835 972373, None, annuale, 31, None, None
# POLICORO, MATERA, Basilicata, Albergo Stella Marina, Albergo, 1 stella *, Piazza Polieion, 1 - Fraz. Lido di Policoro, 75025, MT, 0835 910069, None, annuale, 41, None, None
# POLICORO, MATERA, Basilicata, Aquarius, Villaggio-camping, None, Via San Giusto - Loc. Torre Mozza, 75025, MT, 0835 910273, www.acquariuspolicoro.com, stagionale, 180, None, None
# POLICORO, MATERA, Basilicata, Az. Agr. di Ricciardulli Antonio, Agriturismo, ittiturismo, pescaturismo, None, Via Montegrappa, 21 - Loc. Torre Mozza, 75025, MT, 0835 910256, www.agriturismoricciardulli.it, annuale, 44, None, None
# POLICORO, MATERA, Basilicata, Az. Agr. Podere 348, Agriturismo, ittiturismo, pescaturismo, None, Via Cristoforo Colombo, 14, 75025, MT, 0835 980851, None, stagionale, 16, None, None
# POLICORO, MATERA, Basilicata, B&B Apricot, Bed and breakfast - standard, None, Via Ricciardulli, 5, 75025, MT, 0835 972472, www.apricotlucania.com, annuale, 4, None, None
# POLICORO, MATERA, Basilicata, B&B BasiliCasa, Bed and breakfast - standard, None, Via Siris, 126 B/3, 75025, MT, 0835 1820442, www.basilicasa.it, stagionale, 6, None, None
# POLICORO, MATERA, Basilicata, Casa Vacanza Arcobaleno, Casa e appartamento per vacanze, None, Via Lido, 75025, MT, None, None, annuale, 4, None, None
# POLICORO, MATERA, Basilicata, Centro Giovanile P. Minozzi, Casa per ferie, None, Piazza P. Minozzi, 1, 75025, MT, 0835 985517, www.centrodonminozzi.it, annuale, 108, None, None
# POLICORO, MATERA, Basilicata, Giglio di Mare, Casa e appartamento per vacanze, None, Via Agamennone, 56 - Fraz. Lido di Policoro, 75025, MT, None, www.appartamenti-gigliodimare.it, annuale, 10, None, None
# POLICORO, MATERA, Basilicata, Hotel CallÔøΩ 2, Albergo, 3 stelle ***, Via Lazio, 75025, MT, 0835 972415, www.hotelcalla.it, annuale, 64, None, None
# POLICORO, MATERA, Basilicata, Hotel Heraclea, Albergo, 4 stelle ****, Viale Lido - Fraz. Marina di Policoro, 75025, MT, None, None, annuale, 210, 42943, Cancellazione
# POLICORO, MATERA, Basilicata, Hotel Heraclea, Albergo, 4 stelle ****, Viale Lido - Fraz. Marina di Policoro, 75025, MT, 0835 910145, www.hotelheraclea.com, annuale, 210, 42943, Nuovo inserimento
# POLICORO, MATERA, Basilicata, Hotel Hermes, Albergo, 3 stelle ***, S.S. 106 km. 427+150 destra complanare, 75025, MT, 0835 980887, www.hermeshotel.it, annuale, 59, None, None
# POLICORO, MATERA, Basilicata, Hotel Marinagri, Albergo, 5 stelle *****, Via San Giusto - Loc. Torre Mozza, 75025, MT, 0835 960200, www.hotelmarinagri.it, annuale, 284, None, None
# POLICORO, MATERA, Basilicata, Istituto Figlie dell'Oratorio, Casa per ferie, None, Via Catone, 218, 75025, MT, 0835 910970, www.figliedelloratorio.it/policoro.htm, stagionale, 40, None, None
# POLICORO, MATERA, Basilicata, Oasi D'Oriente, Ostello per la gioventÔøΩ, None, Via Lido, 33 - Fraz. Lido di Policoro, 75025, MT, 0835 910498, www.oasidoriente.org, annuale, 78, None, None
# POLICORO, MATERA, Basilicata, Open Village Circolo Velico Lucano, Villaggio-camping, None, Via Lido, s.n.c. - Fraz. Lido di Policoro, 75025, MT, 0835 910921, www.circolovelicolucano.it, annuale, 103, None, None
# POLICORO, MATERA, Basilicata, Orohotel, Albergo, 4 stelle ****, Via Lido, s.n., 75025, MT, 0835 910140, www.orohotel.it, annuale, 207, None, None
# POLICORO, MATERA, Basilicata, Policoro Village, Villaggio-camping, None, Via Aristarco, 1 - Loc. Policoro Lido, 75025, MT, 0835 910484, www.policorovillage.it, annuale, 396, None, None
# POLICORO, MATERA, Basilicata, Relais Marinagri, Albergo, 4 stelle ****, Via San Giusto - Loc. Torre Mozza, 75025, MT, 0835 960200, www.hotelmarinagri.it, annuale, 18, None, None
# POMARICO, MATERA, Basilicata, Az. Agr. Lama di Palio, Agriturismo, ittiturismo, pescaturismo, None, Loc. Lama di Palio, 75016, MT, 080 5010627, None, annuale, 36, None, None
# POMARICO, MATERA, Basilicata, B&B Antonio Vivaldi, Bed and breakfast - standard, None, Via T. Tasso, 15, 75016, MT, None, www.bbantoniovivaldi.it, annuale, 5, None, None
# ROTONDELLA, MATERA, Basilicata, Agriturismo Il Pago, Agriturismo, ittiturismo, pescaturismo, None, C.da Trisaia Pantanello, 7, 75026, MT, None, www.ilpago.eu, annuale, 18, None, None
# ROTONDELLA, MATERA, Basilicata, Agriturismo La Tavernetta, Agriturismo, ittiturismo, pescaturismo, None, C.da Trisaia "A", 24/A, 75026, MT, 0835 848271, www.agriturlatavernetta.it, annuale, 6, None, None
# ROTONDELLA, MATERA, Basilicata, Agriturismo Macchia di Riso, Agriturismo, ittiturismo, pescaturismo, None, C.da Trisaia/Pantanello, 13, 75026, MT, None, www.macchiadiriso.it, annuale, 25, None, None
# ROTONDELLA, MATERA, Basilicata, Agriturismo Santa Laura, Agriturismo, ittiturismo, pescaturismo, None, C.da Santa Laura, 75026, MT, None, None, stagionale, 9, None, None
# ROTONDELLA, MATERA, Basilicata, Az. Agr. Germano di Pitrelli Giuseppina, Agriturismo, ittiturismo, pescaturismo, None, C.da Caramola-Ercole, 2, 75026, MT, None, None, stagionale, 4, None, None
# ROTONDELLA, MATERA, Basilicata, Az. Agr. Manolio, Agriturismo, ittiturismo, pescaturismo, None, C.da Mortella, 6, 75026, MT, 0835 504185, www.agriturismomanolio.it, annuale, 6, None, None
# ROTONDELLA, MATERA, Basilicata, Az. Agr. Villa Lagaria, Agriturismo, ittiturismo, pescaturismo, None, C.da Pianoro, 38, 75026, MT, None, www.villalagaria.it, annuale, 27, None, None
# ROTONDELLA, MATERA, Basilicata, Camping Rivolta dei Mitemi, Campeggio, None, Via Lido - Zona Rivolta, 75026, MT, None, www.residenzedeimitemi.it, stagionale, 320, None, None
# ROTONDELLA, MATERA, Basilicata, Il Giglio B&B, Bed and breakfast - standard, None, Via Cirillo, 19, 75026, MT, None, None, annuale, 5, None, None
# ROTONDELLA, MATERA, Basilicata, Il Terrazzo sul Sinni, Agriturismo, ittiturismo, pescaturismo, None, C.da Caramola, 3, 75026, MT, 0835 504234, www.terrazzosulsinni.com, annuale, 8, None, None
# ROTONDELLA, MATERA, Basilicata, Masseria Aurata, Agriturismo, ittiturismo, pescaturismo, None, Via Pianoro, 19, 75026, MT, None, www.masseriaaurata.com, annuale, 8, None, None
# ROTONDELLA, MATERA, Basilicata, Silenti Dimore di Rotondella, Casa e appartamento per vacanze, None, Via Nazario Sauro, 47, 75026, MT, 0835 504283, www.ferachiusa.com, annuale, 35, None, None
# SALANDRA, MATERA, Basilicata, Hotel La Salitella, Albergo, 3 stelle ***, S.S. Basentana km. 45,500, 75017, MT, 0835 671085, www.hotelasalitella.com, annuale, 39, None, None
# SALANDRA, MATERA, Basilicata, M. B. Basentum, Albergo, 3 stelle ***, Loc. Pantano - Scalo Ferroviario, 75017, MT, 0835 670039, None, annuale, 25, None, None
# SAN GIORGIO LUCANO, MATERA, Basilicata, Hotel San Giorgio, Albergo, 3 stelle ***, Via Tripoli, 2, 75027, MT, 0835 846935, www.htlsangiorgio.it, annuale, 33, None, None
# STIGLIANO, MATERA, Basilicata, B&B Magariello, Bed and breakfast - standard, None, Corso Umberto, 55, 75018, MT, None, None, annuale, 7, None, None
# STIGLIANO, MATERA, Basilicata, B&B Tenuta Pomponio, Bed and breakfast - standard, None, Loc. Pomponio, 75018, MT, None, www.tenutapomponio.com, annuale, 4, None, None
# STIGLIANO, MATERA, Basilicata, Hotel Antico Pastificio Sarubbi, Albergo, 4 stelle ****, Via Roma, 107, 75018, MT, 0835 566979, www.anticopastificiosarubbi.it, annuale, 17, None, None
# STIGLIANO, MATERA, Basilicata, Hotel Mariano, Albergo, 3 stelle ***, Via Principe di Napoli, 65, 75018, MT, None, www.hotelristorantemariano.it, annuale, 20, None, None
# TRICARICO, MATERA, Basilicata, B&B Vecchio Palazzo, Bed and breakfast - standard, None, C.da Calle, 2, 75019, MT, 0835 725007, www.vecchiopalazzo.com, annuale, 6, None, None
# TRICARICO, MATERA, Basilicata, B&B Villino Francesca, Bed and breakfast - standard, None, C.da Serra delle Vigne, s.n.c., 75019, MT, 0835 724935, villinofrancesca.wixsite.com, annuale, 5, None, None
# TRICARICO, MATERA, Basilicata, Dimora Tre Cancelli, Affittacamere, None, C.da Tre Cancelli, 75019, MT, None, www.dimoratrecancelli.com, annuale, 14, 42857, Nuovo inserimento
# TRICARICO, MATERA, Basilicata, Gianmaria B&B, Bed and breakfast - comfort, None, Via F.lli Cervi, 1, 75019, MT, None, www.gianmariabb.com, annuale, 8, 42907, Nuovo inserimento
# TRICARICO, MATERA, Basilicata, Ostello Fonti, Ostello per la gioventÔøΩ, None, C.da Fonti, 75019, MT, None, www.ostellofonti.it, annuale, 72, None, None
# TURSI, MATERA, Basilicata, Az. Agr. Cardosa e Corvo, Agriturismo, ittiturismo, pescaturismo, None, Via Caprarico, 134 - Diga Gannano, 75028, MT, 0835 819097, None, annuale, 30, None, None
# TURSI, MATERA, Basilicata, B&B La Collina degli Ulivi, Bed and breakfast - standard, None, Via Ponte Masone, s.n.c., 75028, MT, None, None, annuale, 5, None, None
# TURSI, MATERA, Basilicata, Belvedere sui Calanchi, Casa e appartamento per vacanze, None, Via Pandosia, 84, 75028, MT, None, None, annuale, 3, 42894, Nuovo inserimento
# TURSI, MATERA, Basilicata, Da Ciccio e Concy, Casa e appartamento per vacanze, None, Via Toselli, 29, 75028, MT, None, None, annuale, 8, 42894, Nuovo inserimento
# TURSI, MATERA, Basilicata, Hotel Villa Cirigliano, Albergo, 4 stelle ****, Borgo Panevino, 19, 75028, MT, 0835 810095, www.hotelvillacirigliano.it, stagionale, 131, None, None
# TURSI, MATERA, Basilicata, Palazzo dei Poeti, Albergo, 3 stelle ***, Via Manzoni - Loc. Rabatana, 75028, MT, 0835 532325, www.palazzodeipoeti.it, annuale, 44, None, None
# TURSI, MATERA, Basilicata, XI Novembre, Casa e appartamento per vacanze, None, Via G. Mazzini, 37, 75028, MT, None, None, annuale, 3, 42894, Nuovo inserimento
# VALSINNI, MATERA, Basilicata, B&B San Francesco, Bed and breakfast - standard, None, C.da Terzo, 15, 75029, MT, None, www.bbsanfrancesco.it, annuale, 15, None, None
# SCANZANO JONICO, MATERA, Basilicata, Agricola Agata, Agriturismo, ittiturismo, pescaturismo, None, Via Roma, 10 - Loc. III Cavone, 75020, MT, None, www.agriturismoagata.it, annuale, 20, None, None
# SCANZANO JONICO, MATERA, Basilicata, Agriturismo di Di Tursi Michele, Agriturismo, ittiturismo, pescaturismo, None, Via Liguria, 3 - Loc. III Marzocco, 75020, MT, 0835 930267, www.agriturismoditursi.it, stagionale, 8, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. Bufaleria, Agriturismo, ittiturismo, pescaturismo, None, Via Monviso, 61 - Loc. III Madonna, 75020, MT, 0835 954287, www.agriturismobasilicata.it, stagionale, 10, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. di Merlo Francesco, Agriturismo, ittiturismo, pescaturismo, None, Via Marche, 15 - Loc. Bufaloria, 75020, MT, None, None, stagionale, 16, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. di Vitale Vincenzo, Agriturismo, ittiturismo, pescaturismo, None, Via Adige, 27 - Loc. Parisi, 75020, MT, None, None, stagionale, 12, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. Il Gazebo, Agriturismo, ittiturismo, pescaturismo, None, Via Monte Bianco, 34 - Loc. III Madonna, 75020, MT, None, www.agriturismoilgazebo.it, annuale, 6, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. Il Girasole, Agriturismo, ittiturismo, pescaturismo, None, Via Fiume, 33, 75020, MT, None, None, annuale, 6, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. Il Merlo, Agriturismo, ittiturismo, pescaturismo, None, Via Monviso, 4 - Loc. III Madonna, 75020, MT, None, None, annuale, 20, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. La Torre, Agriturismo, ittiturismo, pescaturismo, None, Via Lombardia, 13, 75020, MT, 0835 950883, None, annuale, 17, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. Quattro Palme, Agriturismo, ittiturismo, pescaturismo, None, Via Liguria, 5 - Loc. III Marzocco, 75020, MT, None, None, stagionale, 6, None, None
# SCANZANO JONICO, MATERA, Basilicata, Az. Agr. Residence La Passiflora, Agriturismo, ittiturismo, pescaturismo, None, Via Lombardia, 26, 75020, MT, None, www.lapassiflora.net, annuale, 17, None, None
# SCANZANO JONICO, MATERA, Basilicata, Camping Le Due Barche, Campeggio, None, Via Lido Torre, 33, 75020, MT, 0835 950880, www.leduebarche.com, stagionale, 320, None, None
# SCANZANO JONICO, MATERA, Basilicata, Forastieri Hotel, Albergo, 3 stelle ***, S.S. 106 km. 431, 75020, MT, 0835 953017, www.paginegialle.it/forastierihotel, annuale, 40, None, None
# SCANZANO JONICO, MATERA, Basilicata, Hotel Portogreco, Albergo, 4 stelle ****, Viale Carlo Enrico Bernasconi, s.n.c., 75020, MT, 0835 952048, www.mondotondovillaggi.it, stagionale, 660, None, None
# SCANZANO JONICO, MATERA, Basilicata, Hotel Villaggio Torre del Faro, Albergo, 3 stelle ***, Viale C. E. Bernasconi, s.n.c., 75020, MT, None, www.mondotondovillaggi.it, stagionale, 1140, None, None
# SCANZANO JONICO, MATERA, Basilicata, Miceneo Palace Hotel, Albergo, 4 stelle ****, Via Provinciale, 2, 75020, MT, 0835 953044, www.miceneopalace.it, annuale, 148, None, None

# %% [markdown]
# Se invece volessimo stampare solo le voci che sono nel comune di `'MELFI'`, potremmo fare così:

# %%
for row_num in range(1, rows+1):
    row_cells = []
    if sheet.cell(row=row_num, column=1).value == 'MELFI':
        for col_num in range(1, cols+1):
            value = sheet.cell(row=row_num, column=col_num).value
            row_cells.append(str(value))
        print(', '.join(row_cells))
# Out:
# MELFI, POTENZA, Basilicata, Albergo Il Tetto, Albergo, 1 stella *, Piazza IV Novembre, 1, 85025, PZ, 0972 252555, www.hosteliltetto.com, annuale, 66, None, None
# MELFI, POTENZA, Basilicata, B&B Alla Corte Blu, Bed and breakfast - standard, None, Via Monteverde, s.n.c. - C.da Bicocca, 85025, PZ, 0971 440999, www.allacorteblu.it, annuale, 8, None, None
# MELFI, POTENZA, Basilicata, B&B Capricci di Miria, Bed and breakfast - standard, None, Via Ischia, s.n.c. - C.da Ferrara, 85025, PZ, 0972 24531, www.capriccidimiria.it, stagionale, 3, None, None
# MELFI, POTENZA, Basilicata, B&B Dolce Risveglio, Bed and breakfast - Comfort, None, Via Cristoforo Colombo, 11, 85025, PZ, 0972 23465, www.bebdolcerisveglio.it, annuale, 3, None, None
# MELFI, POTENZA, Basilicata, B&B Donna Ida 1900, Bed and breakfast - standard, None, Vico Bellini, 19, 85025, PZ, None, None, stagionale, 4, None, None
# MELFI, POTENZA, Basilicata, B&B Il Fiore della Vita, Bed and breakfast - standard, None, Via A. Di Napoli, 1/a, 85025, PZ, None, www.ilfioredellavita.it, stagionale, 4, None, None
# MELFI, POTENZA, Basilicata, Casa Isabela Luxury Rooms, Affittacamere, None, Viale G. D'Annunzio, 31, 85025, PZ, None, None, annuale, 6, 42989, Nuovo inserimento
# MELFI, POTENZA, Basilicata, Casa Laviano, Bed and breakfast - Comfort, None, Via F. Nitti, 43, 85025, PZ, None, www.casalaviano.it, annuale, 8, None, None
# MELFI, POTENZA, Basilicata, Federico II, Albergo, 3 stelle ***, Z. Ind. San Nicola - Fraz. San Nicola di Melfi, 85025, PZ, 0972 78174, www.hotelfederico.it, annuale, 90, None, None
# MELFI, POTENZA, Basilicata, Hotel Due Pini, Albergo, 4 stelle ****, Piazzale Stazione, s.n., 85025, PZ, 0972 21031, www.hotelduepini.com, annuale, 84, None, None
# MELFI, POTENZA, Basilicata, Hotel Farese, Albergo, 3 stelle ***, Fraz. Foggianello, 1, 85025, PZ, 0972 236478, www.hotelfarese.it, annuale, 31, None, None
# MELFI, POTENZA, Basilicata, Hotel Il Castagneto, Albergo, 4 stelle ****, Via Monticchio ex S.S. 401 km. 3+100, 85025, PZ, 0972 670018, www.hotelcastagnetomelfi.it, annuale, 83, None, None
# MELFI, POTENZA, Basilicata, Hotel Novecento, Albergo, 3 stelle ***, C.da Incoronata, s.n.c., 85025, PZ, 0972 237470, www.novecentomelfi.it, annuale, 24, None, None
# MELFI, POTENZA, Basilicata, Le Stanze dell'Imperatore B&B, Bed and breakfast - standard, None, Vico Neve (Piazza Umberto I), 4-6, 85025, PZ, 0972 21614, www.lestanzedellimperatore.it, annuale, 8, None, None
# MELFI, POTENZA, Basilicata, R&B Nonna Ninetta, Affittacamere, None, Via San Teodoro, 31, 85025, PZ, None, www.nonnaninettamelfi.com, annuale, 4, None, None
# MELFI, POTENZA, Basilicata, Relais La Fattoria, Albergo, 4 stelle ****, S.S. 303 - Uscita Melfi Nord, 85025, PZ, 0972 239121, www.relaislafattoria.it, annuale, 254, None, None

# %% [markdown]
# Praticamente abbiamo iterato ogni riga e abbiamo preso in considerazione la prima colonna. Se il contenuto è `'MELFI'`, allora registriamo l'intera riga, altrimenti saltiamo la voce.
#
# È possibile fare lo stesso con altri valori nei file.

# %% [markdown]
# ### Ricapitolando
#
# Sulla libreria `openpyxl`, abbiamo visto:
#
# - come creare, leggere e scrivere un file Excel;
# - come selezionare il foglio "attivo" con `Workbook.active` oppure un determinato foglio;
# - come ottenere l'elenco dei nomi dei fogli con `Workbook.sheetnames`;
# - come conoscere il numero di righe e colonne con `Worksheet.max_row` e `Worksheet.max_column`;
# - come ottenere l'oggetto cella tramite la notazione a subscription `[ ]` applicata al `Worksheet` e scrivendo le calssiche coordinate, oppure con il metodo `Worksheet.cell()` e indicando numero di riga e colonna.
# - come accedere al o scrivere il contenuto di una cella tramite la proprietà `Cell.value`.
# - come creare un semplice filtro con i cicli `for` e il costrutto `if`.
#
# Se siete interessati ad approfondire le caratteristiche di questa libreria, potete dare un'occhiata alla sua [documentazione ufficiale](https://openpyxl.readthedocs.io/en/stable/).

# %% [markdown]
# ## Modulo `xlsxwriter`

# %% [markdown]
# Provate a cercare, leggere la documentazione e poi ad usarlo con gli esempi precedenti.
