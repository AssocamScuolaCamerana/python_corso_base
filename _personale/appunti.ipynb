# %%
from random import randint
print(randint(5,20))
# Out:
# 17

# %%
import requests #faare le richieste
from flask import Flask, request #capire cosa c'è dentro la richiesta

# %%
result = requests.get("https://meteo.lastampa.it/")
if result.ok:
    print(result.text) #stampa il codice html
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Previsioni meteo  - La Stampa</title>
# <meta charset="utf-8">
# <meta name="description" content="Le previsioni meteo orarie sempre aggiornate per tutte le località in Italia e nel mondo, con il dettaglio per le località sciistiche e marittime.">
# <meta name="author" content="IlMeteo.it">
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1">
#
#     <!-- font -->
#     <link href="https://meteo.lastampa.it/assets/font/droidsans/stylesheet.css" rel="stylesheet">
#     <!-- font -->
#
#     <!-- jQuery -->
#     <script src="https://code.jquery.com/jquery-3.6.0.min.js" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" crossorigin="anonymous"></script>
#     <!-- // jQuery -->
#
#     <!-- bootstrap -->
# ...
