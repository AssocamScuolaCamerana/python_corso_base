# %% [markdown]
# # Subito scraper

# %% [markdown]
# ## Versione base

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup

# Lista di URL da esaminare
url_list = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

# Effettua una richiesta GET al primo URL nella lista
result = requests.get(url_list[0])

# Controlla se la richiesta ha avuto successo (status code 200)
if result.status_code == 200:
    # Parsing del contenuto HTML della pagina utilizzando BeautifulSoup
    soup = BeautifulSoup(result.content, 'html.parser')

    # Seleziona gli elementi HTML corrispondenti ai prodotti desiderati
    products = soup.select('div.items__item.item-card')
    # pprint(products)  # Stampa la lista di prodotti (opzionale)

    # Lista per memorizzare gli oggetti di interesse
    items = []

    # Itera sui prodotti trovati
    for adv in products:
        # Estrae i dati di interesse dal prodotto corrente
        data = {
            'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),  # Nome del prodotto
            'price': adv.select("p.price"),  # Prezzo del prodotto
            'town': adv.select('span[class*=index-module_town__]'),  # Città del venditore
        }

        # Elabora i dati estratti
        for key, value in data.items():
            if value:
                # Se l'elemento è presente, estrai il testo
                data[key] = value[0].get_text()
            else:
                # Se l'elemento non è presente, imposta il valore a None
                data[key] = None
        
        items.append(data)

    # Stampa i dati estratti
    pprint(items)
# Out:
# [{'name': 'Sinclair ZX Spectrum 48k personal computer',
#   'price': '750\xa0€Spedizione disponibile',
#   'town': 'Nogarole Rocca '},
#  {'name': 'Zx spectrum+2 128k sinclair',
#   'price': '300\xa0€Spedizione disponibile',
#   'town': 'Pavia '},
#  {'name': 'ZX Spectrum SINCLAIR',
#   'price': '220\xa0€Spedizione disponibile',
#   'town': 'Noventa di Piave '},
#  {'name': 'Sinclair ZX Spectrum 16kb',
#   'price': '550\xa0€Spedizione disponibile',
#   'town': 'Torino '},
#  {'name': 'Disco 2tb Batocera v36',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Pagani '},
#  {'name': 'Disco 2tb Batocera',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Pagani '},
#  {'name': 'Sinclair ZX Spectrum 48k',
#   'price': '280\xa0€',
#   'town': 'Villafranca Padovana '},
#  {'name': 'Computer sinclair zx spectrum 48k - testato 100%',
#   'price': '150\xa0€Spedizione disponibile',
#   'town': 'Salerno '},
#  {'name': 'Zx spectrum plus Sinclair',
#   'price': '200\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Zx Spectrum 48 K Sinclair',
#   'price': '99\xa0€Spedizione disponibile',
#   'town': 'Milano '},
#  {'name': 'SINCLAIR ZX SPECTRUM 48 K originale con scatola',
#   'price': '220\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Giochi per Sinclair ZX Spectrum',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Verona '},
#  {'name': 'Libri / Manuali Retrocomputer Spectrum Commodore',
#   'price': '50\xa0€Spedizione disponibile',
#   'town': 'Trapani '},
#  {'name': 'Sinclair ZX Spectrum + 48K',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Monterotondo '},
#  {'name': 'Sinclair ZX Spectrum Plus +2 Computer 128K Vintage',
#   'price': '130\xa0€Venduto',
#   'town': None},
#  {'name': 'ZX SPECTRUM Personal Computer',
#   'price': '180\xa0€',
#   'town': 'Chiaravalle '},
#  {'name': 'Copertina "Zub" per Sinclair Zx Spectrum 128k',
#   'price': '2\xa0€Spedizione disponibile',
#   'town': 'Sovico '},
#  {'name': 'Sinclair zx spectrum 48k +',
#   'price': '60\xa0€Spedizione disponibile',
#   'town': 'Velletri '},
#  {'name': 'Sinclair zx spectrum 48k',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Velletri '},
#  {'name': 'Sinclair ZX Interface 1',
#   'price': '90\xa0€Spedizione disponibile',
#   'town': 'Bologna '},
#  {'name': 'SINCLAIR ZX Spectrum', 'price': '70\xa0€Venduto', 'town': None},
#  {'name': 'ZX Spectrum + Sinclair 48k',
#   'price': '250\xa0€Spedizione disponibile',
#   'town': 'Viterbo '},
#  {'name': 'Cassetta Sinclair per ZX Spectrum - User Guide',
#   'price': '4\xa0€Spedizione disponibile',
#   'town': 'Trieste '},
#  {'name': 'Sinclair Spectrum',
#   'price': '150\xa0€Spedizione disponibile',
#   'town': 'Bologna '},
#  {'name': 'Sinclair ZX Spectrum No Commodore',
#   'price': '11\xa0€Spedizione disponibile',
#   'town': 'Grumello del Monte '},
#  {'name': 'Zx spectrum',
#   'price': '110\xa0€Spedizione disponibile',
#   'town': 'Prascorsano '},
#  {'name': 'Spectrum Graphic pen penna grafica pc Sinclair',
#   'price': '65\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Sinclair ZX Spectrum 48K',
#   'price': '130\xa0€Spedizione disponibile',
#   'town': 'Genova '},
#  {'name': 'Cavo scart rgb per zx spectrum 128k +2a +2b +3',
#   'price': '21\xa0€',
#   'town': 'Milano '},
#  {'name': 'Zx spectrum 48k', 'price': '120\xa0€', 'town': 'Firenze '}]

# %% [markdown]
# ## Esercizio svolto in classe (base)

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup

url_list = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

result = requests.get(url_list[0])

if result.status_code == 200:
    soup = BeautifulSoup(result.content, 'html.parser')

    products = soup.select('div.items__item.item-card')

    items = []

    for adv in products:
        data = {
            'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),
            # 'name': adv.select('h2[class*=ItemTitle-module_item-title__]')[0] \
            #     .get_text() if adv.select('h2[class*=ItemTitle-module_item-title__]') else None,
            'price': adv.select('p.price'),
            'town': adv.select('span[class*=index-module_town__]'),
            'city': adv.select('span.city'),
            'shipping': adv.select('span.shipping-badge'),
            'sold': adv.select('span.item-sold-badge'),  
            'date': adv.select('span[class*=index-module_date__]'),
        }

        for key, value in data.items():
            if value:
                # data[key] = value[0].string
                data[key] = value[0].get_text()
                # data[key] = value[0].find(string=True, recursive=False) 
            else:
                data[key] = None

            # data[key] = value[0].get_text() if value else None

        data.update({
            'price': data['price']
                    .replace('Spedizione disponibile', '')
                    .replace('\xa0€', '')
                    .replace('Venduto', ''),
            'url': adv.select('a.link')[0]['href'],
            'url': adv.a['href'],
        })

        items.append(data)
    
    pprint(items)
# Out:
# [{'city': '(FI)',
#   'date': 'Oggi alle 07:15',
#   'name': 'Grow Light',
#   'price': '22',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Firenze ',
#   'url': 'https://www.subito.it/giardino-fai-da-te/grow-light-firenze-495202928.htm'},
#  {'city': '(SR)',
#   'date': 'Oggi alle 07:08',
#   'name': 'Motoscafo rc',
#   'price': '200',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Siracusa ',
#   'url': 'https://www.subito.it/hobby-collezionismo/motoscafo-rc-siracusa-495202400.htm'},
#  {'city': '(SR)',
#   'date': 'Oggi alle 06:53',
#   'name': 'Scaler crawler',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Siracusa ',
#   'url': 'https://www.subito.it/hobby-collezionismo/scaler-crawler-siracusa-495201693.htm'},
#  {'city': '(PN)',
#   'date': 'Ieri alle 23:00',
#   'name': 'Modifica Full Spectrum fotografia Infrarossi',
#   'price': '',
#   'shipping': None,
#   'sold': None,
#   'town': 'Zoppola ',
#   'url': 'https://www.subito.it/fotografia/modifica-full-spectrum-fotografia-infrarossi-pordenone-495184013.htm'},
#  {'city': '(NA)',
#   'date': 'Ieri alle 17:57',
#   'name': '(FRETTA DI VENDERE) Pc assemblato + periferiche',
#   'price': '479',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Napoli ',
#   'url': 'https://www.subito.it/informatica/fretta-di-vendere-pc-assemblato-periferiche-napoli-494546679.htm'},
#  {'city': '(NA)',
#   'date': None,
#   'name': '(FRETTA DI VENDERE) Pc assemblato + periferiche',
#   'price': '479',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Napoli ',
#   'url': 'https://www.subito.it/informatica/fretta-di-vendere-pc-assemblato-periferiche-napoli-494546679.htm'},
#  {'city': '(TO)',
#   'date': None,
#   'name': 'Olio CBD full spectrum',
#   'price': '',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/hobby-collezionismo/olio-cbd-full-spectrum-torino-459012555.htm'},
#  {'city': '(CH)',
#   'date': None,
#   'name': 'Canon 6D mod. x ASTROFOTOGRAFIA.+ filtro OPTOLONG',
#   'price': '620',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lanciano ',
#   'url': 'https://www.subito.it/fotografia/canon-6d-mod-x-astrofotografia-filtro-optolong-chieti-488094841.htm'},
#  {'city': '(BS)',
#   'date': 'Ieri alle 16:53',
#   'name': 'Brunner ALL INCLUSIVE Spectrum Lunch Box antislip',
#   'price': '149',
#   'shipping': None,
#   'sold': None,
#   'town': 'Sale Marasino ',
#   'url': 'https://www.subito.it/arredamento-casalinghi/brunner-all-inclusive-spectrum-lunch-box-antislip-brescia-355792931.htm'},
#  {'city': '(VR)',
#   'date': 'Ieri alle 16:25',
#   'name': 'Sinclair ZX Spectrum 48k personal computer',
#   'price': '750',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Nogarole Rocca ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-verona-495121453.htm'},
#  {'city': '(PA)',
#   'date': None,
#   'name': 'Pc gaming assemblato fisso completo',
#   'price': '1.500',
#   'shipping': None,
#   'sold': None,
#   'town': 'Palermo ',
#   'url': 'https://www.subito.it/informatica/pc-gaming-assemblato-fisso-completo-palermo-493990627.htm'},
#  {'city': '(RM)',
#   'date': 'Ieri alle 14:26',
#   'name': 'Collezione zippo vintage',
#   'price': '350',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/hobby-collezionismo/collezione-zippo-vintage-roma-490225823.htm'},
#  {'city': '(FI)',
#   'date': 'Ieri alle 04:06',
#   'name': 'Alimentatore Spectrum Grow 400W',
#   'price': '59',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/elettrodomestici/alimentatore-spectrum-grow-400w-firenze-440246314.htm'},
#  {'city': '(FI)',
#   'date': 'Ieri alle 04:06',
#   'name': 'Alimentatore Spectrum Grow 250W',
#   'price': '49',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/elettrodomestici/alimentatore-spectrum-grow-250w-firenze-440246075.htm'},
#  {'city': '(PG)',
#   'date': '29 mag alle 18:05',
#   'name': 'Scheda CPU sostitutiva bally e gttb system80',
#   'price': '180',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Bastia Umbra ',
#   'url': 'https://www.subito.it/videogiochi/scheda-cpu-sostitutiva-bally-e-gttb-system80-perugia-477828359.htm'},
#  {'city': '(GE)',
#   'date': '29 mag alle 16:23',
#   'name': 'Elicottero T-Rex 450 plus DFC BTF flybarless',
#   'price': '350',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lavagna ',
#   'url': 'https://www.subito.it/hobby-collezionismo/elicottero-t-rex-450-plus-dfc-btf-flybarless-genova-494943757.htm'},
#  {'city': '(PV)',
#   'date': '29 mag alle 15:15',
#   'name': 'Zx spectrum+2 128k sinclair',
#   'price': '300',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pavia ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-2-128k-sinclair-pavia-494925569.htm'},
#  {'city': '(FI)',
#   'date': '29 mag alle 15:04',
#   'name': 'Alimentatore Spectrum Grow 600W',
#   'price': '74',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/elettrodomestici/alimentatore-spectrum-grow-600w-firenze-440246536.htm'},
#  {'city': '(SV)',
#   'date': '29 mag alle 13:49',
#   'name': 'Humminbird Helix 7 G4N Chirp',
#   'price': '1.069',
#   'shipping': None,
#   'sold': None,
#   'town': 'Vado Ligure ',
#   'url': 'https://www.subito.it/nautica/humminbird-helix-7-g4n-chirp-savona-494910278.htm'},
#  {'city': '(SV)',
#   'date': '29 mag alle 13:49',
#   'name': 'Humminbird Helix 5 G3 Chirp',
#   'price': '479',
#   'shipping': None,
#   'sold': None,
#   'town': 'Vado Ligure ',
#   'url': 'https://www.subito.it/nautica/humminbird-helix-5-g3-chirp-savona-494910032.htm'},
#  {'city': '(FG)',
#   'date': '28 mag alle 23:10',
#   'name': 'ZX Spectrum',
#   'price': '90',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Foggia ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-foggia-494830452.htm'},
#  {'city': '(VE)',
#   'date': '28 mag alle 19:46',
#   'name': 'ZX Spectrum SINCLAIR',
#   'price': '220',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Noventa di Piave ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-venezia-494813174.htm'},
#  {'city': '(VR)',
#   'date': '28 mag alle 17:17',
#   'name': 'Eve spectrum 4k 144 hz',
#   'price': '480',
#   'shipping': None,
#   'sold': None,
#   'town': 'San Bonifacio ',
#   'url': 'https://www.subito.it/informatica/eve-spectrum-4k-144-hz-verona-494794918.htm'},
#  {'city': '(MC)',
#   'date': '28 mag alle 11:44',
#   'name': 'ZX spectrum computer anni 80',
#   'price': '500',
#   'shipping': None,
#   'sold': None,
#   'town': 'Porto Recanati ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-computer-anni-80-macerata-494757526.htm'},
#  {'city': '(GO)',
#   'date': '28 mag alle 11:44',
#   'name': 'Monitor Philips PCT 1201',
#   'price': '120',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': "Gradisca d'Isonzo ",
#   'url': 'https://www.subito.it/informatica/monitor-philips-pct-1201-gorizia-494757256.htm'},
#  {'city': '(CT)',
#   'date': '28 mag alle 10:51',
#   'name': 'Oneplus 11 5G- 16GB Ram/256 GB Storage',
#   'price': '695',
#   'shipping': None,
#   'sold': None,
#   'town': 'Catania ',
#   'url': 'https://www.subito.it/telefonia/oneplus-11-5g-16gb-ram-256-gb-storage-catania-494751086.htm'},
#  {'city': '(TO)',
#   'date': '28 mag alle 10:42',
#   'name': 'Sinclair ZX Spectrum 16kb',
#   'price': '550',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-16kb-torino-494749976.htm'},
#  {'city': '(TO)',
#   'date': '28 mag alle 10:33',
#   'name': 'Videogiochi vari PC (e 2 MAC)',
#   'price': '5',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/videogiochi/videogiochi-vari-pc-e-2-mac-torino-494749530.htm'},
#  {'city': '(AR)',
#   'date': '27 mag alle 19:09',
#   'name': 'Trabucco spectrum xts Feeder 12ft',
#   'price': '70',
#   'shipping': None,
#   'sold': None,
#   'town': 'Cortona ',
#   'url': 'https://www.subito.it/sport/trabucco-spectrum-xts-feeder-12ft-arezzo-494706797.htm'},
#  {'city': '(VB)',
#   'date': '27 mag alle 16:12',
#   'name': 'REEL Console Giochi TV',
#   'price': '50',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Verbania ',
#   'url': 'https://www.subito.it/videogiochi/reel-console-giochi-tv-verbano-cusio-ossola-494684771.htm'},
#  {'city': '(CT)',
#   'date': '27 mag alle 15:10',
#   'name': 'Fiat Doblo MAXI FURGONE FRIGO - FNAX- ATP VALIDA -',
#   'price': '16.990',
#   'shipping': None,
#   'sold': None,
#   'town': 'Caltagirone ',
#   'url': 'https://www.subito.it/veicoli-commerciali/fiat-doblo-maxi-furgone-frigo-fnax-atp-valida-catania-494675074.htm'},
#  {'city': '(CO)',
#   'date': '27 mag alle 12:55',
#   'name': 'XX spectrum plus con box',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Como ',
#   'url': 'https://www.subito.it/videogiochi/xx-spectrum-plus-con-box-como-494657805.htm'},
#  {'city': '(PN)',
#   'date': '27 mag alle 12:38',
#   'name': 'OnePlus 11 8/128 GB Eternal Green (NUOVO)',
#   'price': '670',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Fiume Veneto ',
#   'url': 'https://www.subito.it/telefonia/oneplus-11-8-128-gb-eternal-green-nuovo-pordenone-494655337.htm'}]

# %% [markdown]
# ## Versione con Cache

# %%
from pprint import pprint
from time import sleep
from collections import defaultdict
import requests
from bs4 import BeautifulSoup

online = False

list_of_urls = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

scraped_data = []

if online or not 'res_cache' in globals():
    # res_cache = defaultdict(type(None))
    res_cache = defaultdict(lambda: None)


## Loop Through List of URLs
for url in list_of_urls:
    
    ## Send Request
    if online or not res_cache[url]:
        res_cache[url] = requests.get(url)
    
    if res_cache[url].status_code == 200:
        ## Parse Data
        soup = BeautifulSoup(res_cache[url].content, 'html.parser')
        products = soup.select('div.items__item.item-card')

        items = []

        for product in products:
            data = {
                'name': product.select('h2[class*=ItemTitle-module_item-title__]'),
                'town': product.select('span[class*=index-module_town__]'),
                'city': product.select('span[class*=index-module_token-caption__].city'),
                'date': product.select('span[class*=index-module_date__]'),
                'price': product.select('p[class*=index-module_price__].price'),
                'shipping': product.select('span.shipping-badge'),
                'sold': product.select('span.item-sold-badge')
            }
            
            for key, val in data.items():
                if val:
                    data[key] = val[0].get_text()
                else:
                    data[key] = None

                # data[key] = val[0].find(text=True, recursive=False) if val else None
                # data[key] = val[0].contents[0] if val else None
        

            data.update({
                'price': data['price']
                    .replace('\xa0', ' ')
                    .replace('Spedizione disponibile', ''),
                'url': product.select('a.link')[0]['href'],  
            })

            items.append(data)
        
        scraped_data += items

    sleep(0.5)


pprint(scraped_data)
# Out:
# [{'city': '(PN)',
#   'date': 'Ieri alle 23:00',
#   'name': 'Modifica Full Spectrum fotografia Infrarossi',
#   'price': '',
#   'shipping': None,
#   'sold': None,
#   'town': 'Zoppola ',
#   'url': 'https://www.subito.it/fotografia/modifica-full-spectrum-fotografia-infrarossi-pordenone-495184013.htm'},
#  {'city': '(NA)',
#   'date': 'Ieri alle 17:57',
#   'name': '(FRETTA DI VENDERE) Pc assemblato + periferiche',
#   'price': '479 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Napoli ',
#   'url': 'https://www.subito.it/informatica/fretta-di-vendere-pc-assemblato-periferiche-napoli-494546679.htm'},
#  {'city': '(BS)',
#   'date': 'Ieri alle 16:53',
#   'name': 'Brunner ALL INCLUSIVE Spectrum Lunch Box antislip',
#   'price': '149 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Sale Marasino ',
#   'url': 'https://www.subito.it/arredamento-casalinghi/brunner-all-inclusive-spectrum-lunch-box-antislip-brescia-355792931.htm'},
#  {'city': '(VR)',
#   'date': 'Ieri alle 16:25',
#   'name': 'Sinclair ZX Spectrum 48k personal computer',
#   'price': '750 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Nogarole Rocca ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-verona-495121453.htm'},
#  {'city': '(PA)',
#   'date': None,
#   'name': 'Pc gaming assemblato fisso completo',
#   'price': '1.500 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Palermo ',
#   'url': 'https://www.subito.it/informatica/pc-gaming-assemblato-fisso-completo-palermo-493990627.htm'},
#  {'city': '(TO)',
#   'date': None,
#   'name': 'Olio CBD full spectrum',
#   'price': '',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/hobby-collezionismo/olio-cbd-full-spectrum-torino-459012555.htm'},
#  {'city': '(CH)',
#   'date': None,
#   'name': 'Canon 6D mod. x ASTROFOTOGRAFIA.+ filtro OPTOLONG',
#   'price': '620 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lanciano ',
#   'url': 'https://www.subito.it/fotografia/canon-6d-mod-x-astrofotografia-filtro-optolong-chieti-488094841.htm'},
#  {'city': '(FI)',
#   'date': None,
#   'name': 'Modifica full spectrum per reflex e mirrorless',
#   'price': '50 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lastra a Signa ',
#   'url': 'https://www.subito.it/fotografia/modifica-full-spectrum-per-reflex-e-mirrorless-firenze-419226715.htm'},
#  {'city': '(RM)',
#   'date': 'Ieri alle 14:26',
#   'name': 'Collezione zippo vintage',
#   'price': '350 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/hobby-collezionismo/collezione-zippo-vintage-roma-490225823.htm'},
#  {'city': '(FI)',
#   'date': 'Ieri alle 04:06',
#   'name': 'Alimentatore Spectrum Grow 400W',
#   'price': '59 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/elettrodomestici/alimentatore-spectrum-grow-400w-firenze-440246314.htm'},
#  {'city': '(FI)',
#   'date': 'Ieri alle 04:06',
#   'name': 'Alimentatore Spectrum Grow 250W',
#   'price': '49 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/elettrodomestici/alimentatore-spectrum-grow-250w-firenze-440246075.htm'},
#  {'city': '(PG)',
#   'date': '29 mag alle 18:05',
#   'name': 'Scheda CPU sostitutiva bally e gttb system80',
#   'price': '180 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Bastia Umbra ',
#   'url': 'https://www.subito.it/videogiochi/scheda-cpu-sostitutiva-bally-e-gttb-system80-perugia-477828359.htm'},
#  {'city': '(GE)',
#   'date': '29 mag alle 16:23',
#   'name': 'Elicottero T-Rex 450 plus DFC BTF flybarless',
#   'price': '350 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lavagna ',
#   'url': 'https://www.subito.it/hobby-collezionismo/elicottero-t-rex-450-plus-dfc-btf-flybarless-genova-494943757.htm'},
#  {'city': '(PV)',
#   'date': '29 mag alle 15:15',
#   'name': 'Zx spectrum+2 128k sinclair',
#   'price': '300 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pavia ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-2-128k-sinclair-pavia-494925569.htm'},
#  {'city': '(FI)',
#   'date': '29 mag alle 15:04',
#   'name': 'Alimentatore Spectrum Grow 600W',
#   'price': '74 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/elettrodomestici/alimentatore-spectrum-grow-600w-firenze-440246536.htm'},
#  {'city': '(SV)',
#   'date': '29 mag alle 13:49',
#   'name': 'Humminbird Helix 7 G4N Chirp',
#   'price': '1.069 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Vado Ligure ',
#   'url': 'https://www.subito.it/nautica/humminbird-helix-7-g4n-chirp-savona-494910278.htm'},
#  {'city': '(SV)',
#   'date': '29 mag alle 13:49',
#   'name': 'Humminbird Helix 5 G3 Chirp',
#   'price': '479 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Vado Ligure ',
#   'url': 'https://www.subito.it/nautica/humminbird-helix-5-g3-chirp-savona-494910032.htm'},
#  {'city': '(FG)',
#   'date': '28 mag alle 23:10',
#   'name': 'ZX Spectrum',
#   'price': '90 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Foggia ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-foggia-494830452.htm'},
#  {'city': '(VE)',
#   'date': '28 mag alle 19:46',
#   'name': 'ZX Spectrum SINCLAIR',
#   'price': '220 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Noventa di Piave ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-venezia-494813174.htm'},
#  {'city': '(VR)',
#   'date': '28 mag alle 17:17',
#   'name': 'Eve spectrum 4k 144 hz',
#   'price': '480 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'San Bonifacio ',
#   'url': 'https://www.subito.it/informatica/eve-spectrum-4k-144-hz-verona-494794918.htm'},
#  {'city': '(MC)',
#   'date': '28 mag alle 11:44',
#   'name': 'ZX spectrum computer anni 80',
#   'price': '500 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Porto Recanati ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-computer-anni-80-macerata-494757526.htm'},
#  {'city': '(GO)',
#   'date': '28 mag alle 11:44',
#   'name': 'Monitor Philips PCT 1201',
#   'price': '120 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': "Gradisca d'Isonzo ",
#   'url': 'https://www.subito.it/informatica/monitor-philips-pct-1201-gorizia-494757256.htm'},
#  {'city': '(CT)',
#   'date': '28 mag alle 10:51',
#   'name': 'Oneplus 11 5G- 16GB Ram/256 GB Storage',
#   'price': '695 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Catania ',
#   'url': 'https://www.subito.it/telefonia/oneplus-11-5g-16gb-ram-256-gb-storage-catania-494751086.htm'},
#  {'city': '(TO)',
#   'date': '28 mag alle 10:42',
#   'name': 'Sinclair ZX Spectrum 16kb',
#   'price': '550 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-16kb-torino-494749976.htm'},
#  {'city': '(TO)',
#   'date': '28 mag alle 10:33',
#   'name': 'Videogiochi vari PC (e 2 MAC)',
#   'price': '5 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/videogiochi/videogiochi-vari-pc-e-2-mac-torino-494749530.htm'},
#  {'city': '(AR)',
#   'date': '27 mag alle 19:09',
#   'name': 'Trabucco spectrum xts Feeder 12ft',
#   'price': '70 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Cortona ',
#   'url': 'https://www.subito.it/sport/trabucco-spectrum-xts-feeder-12ft-arezzo-494706797.htm'},
#  {'city': '(VB)',
#   'date': '27 mag alle 16:12',
#   'name': 'REEL Console Giochi TV',
#   'price': '50 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Verbania ',
#   'url': 'https://www.subito.it/videogiochi/reel-console-giochi-tv-verbano-cusio-ossola-494684771.htm'},
#  {'city': '(CT)',
#   'date': '27 mag alle 15:10',
#   'name': 'Fiat Doblo MAXI FURGONE FRIGO - FNAX- ATP VALIDA -',
#   'price': '16.990 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Caltagirone ',
#   'url': 'https://www.subito.it/veicoli-commerciali/fiat-doblo-maxi-furgone-frigo-fnax-atp-valida-catania-494675074.htm'},
#  {'city': '(CO)',
#   'date': '27 mag alle 12:55',
#   'name': 'XX spectrum plus con box',
#   'price': '150 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Como ',
#   'url': 'https://www.subito.it/videogiochi/xx-spectrum-plus-con-box-como-494657805.htm'},
#  {'city': '(PN)',
#   'date': '27 mag alle 12:38',
#   'name': 'OnePlus 11 8/128 GB Eternal Green (NUOVO)',
#   'price': '670 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Fiume Veneto ',
#   'url': 'https://www.subito.it/telefonia/oneplus-11-8-128-gb-eternal-green-nuovo-pordenone-494655337.htm'},
#  {'city': '(SA)',
#   'date': '27 mag alle 11:42',
#   'name': 'Disco 2tb Batocera v36',
#   'price': '100 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pagani ',
#   'url': 'https://www.subito.it/informatica/disco-2tb-batocera-v36-salerno-494644761.htm'},
#  {'city': '(SA)',
#   'date': '27 mag alle 11:33',
#   'name': 'Disco 2tb Batocera',
#   'price': '100 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pagani ',
#   'url': 'https://www.subito.it/informatica/disco-2tb-batocera-salerno-494643854.htm'},
#  {'city': '(TO)',
#   'date': '27 mag alle 10:10',
#   'name': 'Aereo RC',
#   'price': '35 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/sport/aereo-rc-torino-494628486.htm'},
#  {'city': '(RG)',
#   'date': '27 mag alle 00:22',
#   'name': 'Vasca cubo + Lampada Zetlight',
#   'price': '250 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Ragusa ',
#   'url': 'https://www.subito.it/animali/vasca-cubo-lampada-zetlight-ragusa-439767144.htm'},
#  {'city': '(PD)',
#   'date': '26 mag alle 23:07',
#   'name': 'Sinclair ZX Spectrum 48k',
#   'price': '280 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Villafranca Padovana ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-padova-439106844.htm'},
#  {'city': '(GE)',
#   'date': '26 mag alle 20:53',
#   'name': 'Audi A3 SPB 3.0 TDI S.LINEA MATRIX. NAVI',
#   'price': '35.400 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Genova ',
#   'url': 'https://www.subito.it/auto/audi-a3-spb-3-0-tdi-s-linea-matrix-navi-genova-494586601.htm'},
#  {'city': '(AV)',
#   'date': '26 mag alle 18:12',
#   'name': 'Cuffie Logitech G633 Artemis Spectrum',
#   'price': '30 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Avellino ',
#   'url': 'https://www.subito.it/informatica/cuffie-logitech-g633-artemis-spectrum-avellino-494564250.htm'},
#  {'city': '(TO)',
#   'date': '26 mag alle 12:50',
#   'name': 'Olio CBD full spectrum',
#   'price': '',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/hobby-collezionismo/olio-cbd-full-spectrum-torino-459012555.htm'},
#  {'city': '(RC)',
#   'date': None,
#   'name': 'Radiocomando Spectrum DX6i',
#   'price': '129 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Reggio di Calabria ',
#   'url': 'https://www.subito.it/hobby-collezionismo/radiocomando-spectrum-dx6i-reggio-calabria-491091781.htm'},
#  {'city': '(NA)',
#   'date': None,
#   'name': '(FRETTA DI VENDERE) Pc assemblato + periferiche',
#   'price': '479 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Napoli ',
#   'url': 'https://www.subito.it/informatica/fretta-di-vendere-pc-assemblato-periferiche-napoli-494546679.htm'},
#  {'city': '(TO)',
#   'date': None,
#   'name': 'Olio CBD full spectrum',
#   'price': '',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/hobby-collezionismo/olio-cbd-full-spectrum-torino-459012555.htm'},
#  {'city': '(TO)',
#   'date': '26 mag alle 12:21',
#   'name': 'Tastiera LG G910 Orion Spectrum gaming',
#   'price': '70 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/informatica/tastiera-lg-g910-orion-spectrum-gaming-torino-494495857.htm'},
#  {'city': '(RM)',
#   'date': '26 mag alle 11:01',
#   'name': 'Lilliput T5 (5" Touch OnCamera Monitor) COME NUOVO',
#   'price': '164 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/fotografia/lilliput-t5-5-touch-oncamera-monitor-come-nuovo-roma-490809252.htm'},
#  {'city': '(PO)',
#   'date': '26 mag alle 10:09',
#   'name': 'Casco system 7 bmw',
#   'price': '290 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Prato ',
#   'url': 'https://www.subito.it/accessori-moto/casco-system-7-bmw-prato-494464294.htm'},
#  {'city': '(FI)',
#   'date': '26 mag alle 10:06',
#   'name': 'Peavey Spectrum Organ Classic Organ Sound Module ',
#   'price': '',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Bagno a Ripoli ',
#   'url': 'https://www.subito.it/strumenti-musicali/peavey-spectrum-organ-classic-organ-sound-module-firenze-494462878.htm'},
#  {'city': '(BG)',
#   'date': '26 mag alle 09:38',
#   'name': 'PC FISSO GAMING professionale',
#   'price': '640 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Bergamo ',
#   'url': 'https://www.subito.it/informatica/pc-fisso-gaming-professionale-bergamo-434537682.htm'},
#  {'city': '(FC)',
#   'date': '25 mag alle 16:55',
#   'name': 'Mini Pc console arcade 500Gb Arcade +Windows 10',
#   'price': '290 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Cesena ',
#   'url': 'https://www.subito.it/videogiochi/mini-pc-console-arcade-500gb-arcade-windows-10-forli-cesena-494364660.htm'},
#  {'city': '(FI)',
#   'date': '25 mag alle 15:49',
#   'name': 'Logitech G910 Orion Spectrum Tastiera Gaming Mecca',
#   'price': '50 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Empoli ',
#   'url': 'https://www.subito.it/informatica/logitech-g910-orion-spectrum-tastiera-gaming-mecca-firenze-364367756.htm'},
#  {'city': '(NA)',
#   'date': '25 mag alle 14:29',
#   'name': 'Zx spectrum.solo giochi rimasti',
#   'price': '99 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Napoli ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-solo-giochi-rimasti-napoli-424560831.htm'},
#  {'city': '(TE)',
#   'date': '25 mag alle 13:29',
#   'name': 'Behringer Spectrum Enhancer [Pedale]',
#   'price': '15 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Teramo ',
#   'url': 'https://www.subito.it/strumenti-musicali/behringer-spectrum-enhancer-pedale-teramo-494324205.htm'},
#  {'city': '(PD)',
#   'date': '25 mag alle 12:57',
#   'name': 'PERSONAL SOFTWARE, PAPER SOFT, SUPER VIC',
#   'price': '40 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Selvazzano Dentro ',
#   'url': 'https://www.subito.it/libri-riviste/personal-software-paper-soft-super-vic-padova-494318906.htm'},
#  {'city': '(SA)',
#   'date': '25 mag alle 11:54',
#   'name': 'Computer sinclair zx spectrum 48k - testato 100%',
#   'price': '150 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Salerno ',
#   'url': 'https://www.subito.it/informatica/computer-sinclair-zx-spectrum-48k-testato-100-salerno-494306297.htm'},
#  {'city': '(RM)',
#   'date': '25 mag alle 08:12',
#   'name': 'Zx spectrum plus Sinclair',
#   'price': '200 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/hobby-collezionismo/zx-spectrum-plus-sinclair-roma-368244153.htm'},
#  {'city': '(MO)',
#   'date': '25 mag alle 01:38',
#   'name': 'Gioco',
#   'price': '50 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Fiorano Modenese ',
#   'url': 'https://www.subito.it/videogiochi/gioco-modena-494250980.htm'},
#  {'city': '(MI)',
#   'date': '24 mag alle 21:25',
#   'name': 'Zx Spectrum 48 K Sinclair',
#   'price': '99 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48-k-sinclair-milano-494232621.htm'},
#  {'city': '(RM)',
#   'date': '24 mag alle 19:12',
#   'name': 'Logitech g502 proteus spectrum',
#   'price': '20 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/informatica/logitech-g502-proteus-spectrum-roma-494149163.htm'},
#  {'city': '(UD)',
#   'date': '24 mag alle 13:22',
#   'name': '9780194706001 new grammar spectrum',
#   'price': '6 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Talmassons ',
#   'url': 'https://www.subito.it/libri-riviste/9780194706001-new-grammar-spectrum-udine-348814581.htm'},
#  {'city': '(CH)',
#   'date': '24 mag alle 12:06',
#   'name': 'Canon 6D mod. x ASTROFOTOGRAFIA.+ filtro OPTOLONG',
#   'price': '620 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lanciano ',
#   'url': 'https://www.subito.it/fotografia/canon-6d-mod-x-astrofotografia-filtro-optolong-chieti-488094841.htm'},
#  {'city': '(TO)',
#   'date': '24 mag alle 09:26',
#   'name': 'Hedy Lamarr - Le sette vite di una diva scienziata',
#   'price': '9 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/libri-riviste/hedy-lamarr-le-sette-vite-di-una-diva-scienziata-torino-493984507.htm'},
#  {'city': '(BA)',
#   'date': '24 mag alle 09:08',
#   'name': 'PDP Spectrum Ultraviolet NUOVO ',
#   'price': '550 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Molfetta ',
#   'url': 'https://www.subito.it/strumenti-musicali/pdp-spectrum-ultraviolet-nuovo-bari-493994615.htm'},
#  {'city': '(BG)',
#   'date': '23 mag alle 21:37',
#   'name': 'Joystick nuovo 9pin, commodore, amiga, spectrum',
#   'price': '30 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': "Fara Gera d'Adda ",
#   'url': 'https://www.subito.it/videogiochi/joystick-nuovo-9pin-commodore-amiga-spectrum-bergamo-493961877.htm'},
#  {'city': '(RI)',
#   'date': '23 mag alle 19:38',
#   'name': 'Cuffie Wireless Logitech G933 Artemis Spectrum',
#   'price': '78 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Selci ',
#   'url': 'https://www.subito.it/informatica/cuffie-wireless-logitech-g933-artemis-spectrum-rieti-493946161.htm'},
#  {'city': '(GE)',
#   'date': '23 mag alle 18:31',
#   'name': 'Telefono Oppo Reno8 lite 5G NUOVO',
#   'price': '190 €',
#   'shipping': None,
#   'sold': None,
#   'town': 'Genova ',
#   'url': 'https://www.subito.it/telefonia/telefono-oppo-reno8-lite-5g-nuovo-genova-493934774.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Nikon D5100 full-spectrum astrofotografia e IR',
#   'price': '190 €Venduto',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/fotografia/nikon-d5100-full-spectrum-astrofotografia-e-ir-siena-493897831.htm'},
#  {'city': '(RG)',
#   'date': '23 mag alle 13:00',
#   'name': 'Videogiochi PC, selezione strategia',
#   'price': '65 €',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Modica ',
#   'url': 'https://www.subito.it/videogiochi/videogiochi-pc-selezione-strategia-ragusa-492772307.htm'},
#  {'city': '(LE)',
#   'date': '23 mag alle 10:57',
#   'name': 'Giochi Ps2 originali retrogames (terza parte)',
#   'price': '',
#   'shipping': None,
#   'sold': None,
#   'town': 'Lecce ',
#   'url': 'https://www.subito.it/videogiochi/giochi-ps2-originali-retrogames-terza-parte-lecce-182339026.htm'}]
