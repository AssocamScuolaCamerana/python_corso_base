# %% [markdown]
# # Subito scraper

# %% [markdown]
# ## Versione base

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup

# Lista di URL da esaminare
url_list = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

# Effettua una richiesta GET al primo URL nella lista
result = requests.get(url_list[0])

# Controlla se la richiesta ha avuto successo (status code 200)
if result.status_code == 200:
    # Parsing del contenuto HTML della pagina utilizzando BeautifulSoup
    soup = BeautifulSoup(result.content, 'html.parser')

    # Seleziona gli elementi HTML corrispondenti ai prodotti desiderati
    products = soup.select('div.items__item.item-card')
    # pprint(products)  # Stampa la lista di prodotti (opzionale)

    # Lista per memorizzare gli oggetti di interesse
    items = []

    # Itera sui prodotti trovati
    for adv in products:
        # Estrae i dati di interesse dal prodotto corrente
        data = {
            'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),  # Nome del prodotto
            'price': adv.select("p[class*=index-module_price__]"),  # Prezzo del prodotto
            'town': adv.select('span[class*=index-module_town__]'),  # Città del venditore
        }

        # Elabora i dati estratti
        for key, value in data.items():
            if value:
                # Se l'elemento è presente, estrai il testo
                data[key] = value[0].get_text()
            else:
                # Se l'elemento non è presente, imposta il valore a None
                data[key] = None
        
        items.append(data)

    # Stampa i dati estratti
    pprint(items)
# Out:
# [{'name': 'Sinclair ZX Spectrum 48K - (Da Testare)',
#   'price': '99\xa0€Spedizione disponibile',
#   'town': 'Firenze '},
#  {'name': 'Sinclair ZX Spectrum 48K Personal Computer 1982',
#   'price': '269\xa0€Spedizione disponibile',
#   'town': 'Gazoldo degli Ippoliti '},
#  {'name': 'Cartuccia ZX Spectrum per C64',
#   'price': '25\xa0€Spedizione disponibile',
#   'town': 'Trapani '},
#  {'name': 'computer anni 80 vintage',
#   'price': '1.000\xa0€',
#   'town': 'Brescia '},
#  {'name': 'ZX SPECTRUM 48K PLUS - SERIALE 0 - TESTATO - RARO',
#   'price': '129\xa0€Spedizione disponibile',
#   'town': 'Salerno '},
#  {'name': 'Giochi originali Sinclair Zx Spectrum',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Ancona '},
#  {'name': 'Collezione UNICA retroconsolle Commodore - Atari',
#   'price': '2.850\xa0€',
#   'town': 'Villa di Briano '},
#  {'name': 'Sinclair ZX Spectrum +2 128k',
#   'price': '145\xa0€Spedizione disponibile',
#   'town': 'Cavarzere '},
#  {'name': 'Sinclair ZX Spectrum +2 128k',
#   'price': '170\xa0€Spedizione disponibile',
#   'town': 'Lucca '},
#  {'name': 'Collezione Retro Consolle',
#   'price': '1.450\xa0€Spedizione disponibile',
#   'town': 'Venosa '},
#  {'name': 'ZX Spectrum 48k Mascherina tastiera Sinclair orig',
#   'price': '9\xa0€Spedizione disponibile',
#   'town': 'Milano '},
#  {'name': 'PC Home Computer Sinclair ZX Spectrum 128k + 2',
#   'price': '450\xa0€Spedizione disponibile',
#   'town': 'Campobasso '},
#  {'name': 'alimentatore Sinclair ',
#   'price': '10\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Sinclair Zx Spectrum 16k completo computer PC game',
#   'price': '130\xa0€Venduto',
#   'town': None},
#  {'name': 'Giochi originali Sinclair Zx Spectrum',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Ancona '},
#  {'name': 'SINCLAIR ZX SPECTRUM MANUALE INGLESE (#146)',
#   'price': '20\xa0€Spedizione disponibile',
#   'town': 'Barberino Tavarnelle '},
#  {'name': 'SPECTRUM ZX +2 sinclair',
#   'price': '250\xa0€Spedizione disponibile',
#   'town': 'Ceva '},
#  {'name': 'SINCLAIR ZX Spectrum + non funzionante',
#   'price': '50\xa0€Venduto',
#   'town': None},
#  {'name': 'Zx spectrum plus Sinclair',
#   'price': '200\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Libro ZX Sinclair spectrum.  Commodore Amiga MSX ',
#   'price': '17\xa0€Venduto',
#   'town': None},
#  {'name': 'Sinclair ZX SPECTRUM',
#   'price': '140\xa0€Spedizione disponibile',
#   'town': 'Arezzo '},
#  {'name': 'Sinclair QL. commodore Amiga MSX IBM spectrum',
#   'price': '45\xa0€Spedizione disponibile',
#   'town': "Palazzolo sull'Oglio "},
#  {'name': 'Giochi per Sinclair ZX Spectrum',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Verona '},
#  {'name': 'Zx spectrum 48K', 'price': '130\xa0€', 'town': 'Firenze '},
#  {'name': 'Sinclair ZX spectrum 16K Ram', 'price': '200\xa0€', 'town': 'Roma '},
#  {'name': 'Sinclair ZX Spectrum Copri tastiera',
#   'price': '30\xa0€Spedizione disponibile',
#   'town': 'Grumello del Monte '},
#  {'name': 'ZX SPECTRUM Personal Computer',
#   'price': '160\xa0€Spedizione disponibile',
#   'town': 'Chiaravalle '},
#  {'name': 'Sinclair ZX spectrum 16K boxed scatola',
#   'price': '140\xa0€Spedizione disponibile',
#   'town': 'Varese '},
#  {'name': 'Sinclair ZX Spectrum 48kb console',
#   'price': '130\xa0€Spedizione disponibile',
#   'town': 'Fano '},
#  {'name': 'Spectrum Sinclair loose',
#   'price': '100\xa0€',
#   'town': 'Bovisio-Masciago '},
#  {'name': 'Copertina "Zub" per Sinclair Zx Spectrum 128k',
#   'price': '2\xa0€Spedizione disponibile',
#   'town': 'Sovico '}]

# %% [markdown]
# ## Esercizio svolto in classe (base)

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup

url_list = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

result = requests.get(url_list[0])

if result.status_code == 200:
    soup = BeautifulSoup(result.content, 'html.parser')

    products = soup.select('div.items__item.item-card')

    items = []

    for adv in products:
        data = {
            'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),
            # 'name': adv.select('h2[class*=ItemTitle-module_item-title__]')[0] \
            #     .get_text() if adv.select('h2[class*=ItemTitle-module_item-title__]') else None,
            'price': adv.select("p[class*=index-module_price__]"),
            'town': adv.select('span[class*=index-module_town__]'),
            'city': adv.select('span.city'),
            'shipping': adv.select('span.shipping-badge'),
            'sold': adv.select('span.item-sold-badge'),  
            'date': adv.select('span[class*=index-module_date__]'),
        }

        for key, value in data.items():
            if value:
                # data[key] = value[0].string
                data[key] = value[0].get_text()
                # data[key] = value[0].find(string=True, recursive=False) 
            else:
                data[key] = None

            # data[key] = value[0].get_text() if value else None

        data.update({
            'price': data['price']
                    .replace('Spedizione disponibile', '')
                    .replace('\xa0€', '')
                    .replace('Venduto', ''),
            'url': adv.select('a[class*=SmallCard-module_link__]')[0]['href'],
            'url': adv.a['href'],
        })

        items.append(data)
    
    pprint(items)
# Out:
# [{'city': '(FI)',
#   'date': 'Oggi alle 15:22',
#   'name': 'Sinclair ZX Spectrum 48K - (Da Testare)',
#   'price': '99',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Firenze ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-48k-da-testare-firenze-559142253.htm'},
#  {'city': '(MN)',
#   'date': 'Oggi alle 14:10',
#   'name': 'Sinclair ZX Spectrum 48K Personal Computer 1982',
#   'price': '269',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Gazoldo degli Ippoliti ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-1982-mantova-559130064.htm'},
#  {'city': '(TP)',
#   'date': '27 giu alle 00:38',
#   'name': 'Cartuccia ZX Spectrum per C64',
#   'price': '25',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Trapani ',
#   'url': 'https://www.subito.it/informatica/cartuccia-zx-spectrum-per-c64-trapani-558364788.htm'},
#  {'city': '(BS)',
#   'date': '25 giu alle 19:31',
#   'name': 'computer anni 80 vintage',
#   'price': '1.000',
#   'shipping': None,
#   'sold': None,
#   'town': 'Brescia ',
#   'url': 'https://www.subito.it/hobby-collezionismo/computer-anni-80-vintage-brescia-558177741.htm'},
#  {'city': '(SA)',
#   'date': '23 giu alle 16:29',
#   'name': 'ZX SPECTRUM 48K PLUS - SERIALE 0 - TESTATO - RARO',
#   'price': '129',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Salerno ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48k-plus-seriale-0-testato-raro-salerno-557845448.htm'},
#  {'city': '(AN)',
#   'date': None,
#   'name': 'Giochi originali Sinclair Zx Spectrum',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Ancona ',
#   'url': 'https://www.subito.it/videogiochi/giochi-originali-sinclair-zx-spectrum-ancona-516503474.htm'},
#  {'city': '(CE)',
#   'date': '19 giu alle 17:02',
#   'name': 'Collezione UNICA retroconsolle Commodore - Atari',
#   'price': '2.850',
#   'shipping': None,
#   'sold': None,
#   'town': 'Villa di Briano ',
#   'url': 'https://www.subito.it/videogiochi/collezione-unica-retroconsolle-commodore-atari-caserta-555725730.htm'},
#  {'city': '(VE)',
#   'date': '19 giu alle 15:29',
#   'name': 'Sinclair ZX Spectrum +2 128k',
#   'price': '145',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Cavarzere ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-2-128k-venezia-557289238.htm'},
#  {'city': '(LU)',
#   'date': '16 giu alle 14:54',
#   'name': 'Sinclair ZX Spectrum +2 128k',
#   'price': '170',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Lucca ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-2-128k-lucca-556848833.htm'},
#  {'city': '(PZ)',
#   'date': '15 giu alle 03:40',
#   'name': 'Collezione Retro Consolle',
#   'price': '1.450',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Venosa ',
#   'url': 'https://www.subito.it/videogiochi/collezione-retro-consolle-potenza-556662359.htm'},
#  {'city': '(MI)',
#   'date': '11 giu alle 19:33',
#   'name': 'ZX Spectrum 48k Mascherina tastiera Sinclair orig',
#   'price': '9',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48k-mascherina-tastiera-sinclair-orig-milano-556131813.htm'},
#  {'city': '(CB)',
#   'date': '9 giu alle 11:42',
#   'name': 'PC Home Computer Sinclair ZX Spectrum 128k + 2',
#   'price': '450',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Campobasso ',
#   'url': 'https://www.subito.it/informatica/pc-home-computer-sinclair-zx-spectrum-128k-2-campobasso-555692060.htm'},
#  {'city': '(RM)',
#   'date': '8 giu alle 20:36',
#   'name': 'alimentatore Sinclair ',
#   'price': '10',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/alimentatore-sinclair-roma-555649393.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Sinclair Zx Spectrum 16k completo computer PC game',
#   'price': '130',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-16k-completo-computer-pc-game-monza-554748454.htm'},
#  {'city': '(AN)',
#   'date': '3 giu alle 15:37',
#   'name': 'Giochi originali Sinclair Zx Spectrum',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Ancona ',
#   'url': 'https://www.subito.it/videogiochi/giochi-originali-sinclair-zx-spectrum-ancona-516503474.htm'},
#  {'city': '(FI)',
#   'date': '2 giu alle 08:07',
#   'name': 'SINCLAIR ZX SPECTRUM MANUALE INGLESE (#146)',
#   'price': '20',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Barberino Tavarnelle ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-manuale-inglese-146-firenze-496863136.htm'},
#  {'city': '(CN)',
#   'date': '27 mag alle 12:20',
#   'name': 'SPECTRUM ZX +2 sinclair',
#   'price': '250',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Ceva ',
#   'url': 'https://www.subito.it/videogiochi/spectrum-zx-2-sinclair-cuneo-553486143.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'SINCLAIR ZX Spectrum + non funzionante',
#   'price': '50',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-non-funzionante-campobasso-553218838.htm'},
#  {'city': '(RM)',
#   'date': '24 mag alle 08:49',
#   'name': 'Zx spectrum plus Sinclair',
#   'price': '200',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/hobby-collezionismo/zx-spectrum-plus-sinclair-roma-368244153.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Libro ZX Sinclair spectrum.  Commodore Amiga MSX ',
#   'price': '17',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/libri-riviste/libro-zx-sinclair-spectrum-commodore-amiga-msx-brescia-552309875.htm'},
#  {'city': '(AR)',
#   'date': '20 mag alle 11:23',
#   'name': 'Sinclair ZX SPECTRUM',
#   'price': '140',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Arezzo ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-arezzo-552309812.htm'},
#  {'city': '(BS)',
#   'date': '18 mag alle 13:15',
#   'name': 'Sinclair QL. commodore Amiga MSX IBM spectrum',
#   'price': '45',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': "Palazzolo sull'Oglio ",
#   'url': 'https://www.subito.it/informatica/sinclair-ql-commodore-amiga-msx-ibm-spectrum-brescia-552061590.htm'},
#  {'city': '(VR)',
#   'date': '16 mag alle 22:28',
#   'name': 'Giochi per Sinclair ZX Spectrum',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Verona ',
#   'url': 'https://www.subito.it/videogiochi/giochi-per-sinclair-zx-spectrum-verona-418137442.htm'},
#  {'city': '(FI)',
#   'date': '9 mag alle 08:52',
#   'name': 'Zx spectrum 48K',
#   'price': '130',
#   'shipping': None,
#   'sold': None,
#   'town': 'Firenze ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-48k-firenze-550467757.htm'},
#  {'city': '(RM)',
#   'date': '5 mag alle 16:53',
#   'name': 'Sinclair ZX spectrum 16K Ram',
#   'price': '200',
#   'shipping': None,
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-16k-ram-roma-549841886.htm'},
#  {'city': '(BG)',
#   'date': '5 mag alle 10:56',
#   'name': 'Sinclair ZX Spectrum Copri tastiera',
#   'price': '30',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Grumello del Monte ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-copri-tastiera-bergamo-549796780.htm'},
#  {'city': '(AN)',
#   'date': '27 apr alle 14:46',
#   'name': 'ZX SPECTRUM Personal Computer',
#   'price': '160',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Chiaravalle ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-personal-computer-ancona-312557879.htm'},
#  {'city': '(VA)',
#   'date': '24 apr alle 22:11',
#   'name': 'Sinclair ZX spectrum 16K boxed scatola',
#   'price': '140',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Varese ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-16k-boxed-scatola-varese-548130807.htm'},
#  {'city': '(PU)',
#   'date': '21 apr alle 21:36',
#   'name': 'Sinclair ZX Spectrum 48kb console',
#   'price': '130',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Fano ',
#   'url': 'https://www.subito.it/arredamento-casalinghi/sinclair-zx-spectrum-48kb-console-pesaro-urbino-547587238.htm'},
#  {'city': '(MB)',
#   'date': '20 apr alle 21:51',
#   'name': 'Spectrum Sinclair loose',
#   'price': '100',
#   'shipping': None,
#   'sold': None,
#   'town': 'Bovisio-Masciago ',
#   'url': 'https://www.subito.it/videogiochi/spectrum-sinclair-loose-monza-547453459.htm'},
#  {'city': '(MB)',
#   'date': '20 apr alle 08:33',
#   'name': 'Copertina "Zub" per Sinclair Zx Spectrum 128k',
#   'price': '2',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Sovico ',
#   'url': 'https://www.subito.it/videogiochi/copertina-zub-per-sinclair-zx-spectrum-128k-monza-305924094.htm'}]

# %% [markdown]
# ## Versione con Cache

# %%
from pprint import pprint
from time import sleep
from collections import defaultdict
import requests
from bs4 import BeautifulSoup

online = False

list_of_urls = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

scraped_data = []

if online or not 'res_cache' in globals():
    # res_cache = defaultdict(type(None))
    res_cache = defaultdict(lambda: None)


## Loop Through List of URLs
for url in list_of_urls:
    
    ## Send Request
    if online or not res_cache[url]:
        res_cache[url] = requests.get(url)
    
    if res_cache[url].status_code == 200:
        ## Parse Data
        soup = BeautifulSoup(res_cache[url].content, 'html.parser')
        products = soup.select('div.items__item.item-card')

        items = []

        for product in products:
            data = {
                'name': product.select('h2[class*=ItemTitle-module_item-title__]'),
                'town': product.select('span[class*=index-module_town__]'),
                'city': product.select('span[class*=index-module_token-caption__].city'),
                'date': product.select('span[class*=index-module_date__]'),
                'price': product.select("p[class*=index-module_price__]"),
                'shipping': product.select('span.shipping-badge'),
                'sold': product.select('span.item-sold-badge')
            }
            
            for key, val in data.items():
                if val:
                    data[key] = val[0].get_text()
                else:
                    data[key] = None

                # data[key] = val[0].find(text=True, recursive=False) if val else None
                # data[key] = val[0].contents[0] if val else None
        

            data.update({
                'price': data['price']
                    .replace('\xa0', ' ')
                    .replace('Spedizione disponibile', ''),
                'url': product.select('a[class*=SmallCard-module_link__]')[0]['href'],  
            })

            items.append(data)
        
        scraped_data += items

    sleep(0.5)


pprint(scraped_data)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x10ef7f810>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.subito.it', port=443): Max retries exceeded with url: /annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ef7f810>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 26
#      22 for url in list_of_urls:
#      23
#      24     ## Send Request
#      25     if online or not res_cache[url]:
# ---> 26         res_cache[url] = requests.get(url)
#      28     if res_cache[url].status_code == 200:
#      29         ## Parse Data
#      30         soup = BeautifulSoup(res_cache[url].content, 'html.parser')
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Repositories/python_training/python_corso_base/.venv/lib/python3.11/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.subito.it', port=443): Max retries exceeded with url: /annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ef7f810>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
