# %% [markdown]
# # Subito scraper

# %% [markdown]
# ## Versione base

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup

# Lista di URL da esaminare
url_list = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

# Effettua una richiesta GET al primo URL nella lista
result = requests.get(url_list[0])

# Controlla se la richiesta ha avuto successo (status code 200)
if result.status_code == 200:
    # Parsing del contenuto HTML della pagina utilizzando BeautifulSoup
    soup = BeautifulSoup(result.content, 'html.parser')

    # Seleziona gli elementi HTML corrispondenti ai prodotti desiderati
    products = soup.select('div.items__item.item-card')
    # pprint(products)  # Stampa la lista di prodotti (opzionale)

    # Lista per memorizzare gli oggetti di interesse
    items = []

    # Itera sui prodotti trovati
    for adv in products:
        # Estrae i dati di interesse dal prodotto corrente
        data = {
            'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),  # Nome del prodotto
            'price': adv.select("p.price"),  # Prezzo del prodotto
            'town': adv.select('span[class*=index-module_town__]'),  # Città del venditore
        }

        # Elabora i dati estratti
        for key, value in data.items():
            if value:
                # Se l'elemento è presente, estrai il testo
                data[key] = value[0].get_text()
            else:
                # Se l'elemento non è presente, imposta il valore a None
                data[key] = None
        
        items.append(data)

    # Stampa i dati estratti
    pprint(items)
# Out:
# [{'name': 'Sinclair ZX Spectrum 48k personal computer',
#   'price': '750\xa0€Spedizione disponibile',
#   'town': 'Nogarole Rocca '},
#  {'name': 'Zx spectrum+2 128k sinclair',
#   'price': '300\xa0€Spedizione disponibile',
#   'town': 'Pavia '},
#  {'name': 'ZX Spectrum SINCLAIR',
#   'price': '220\xa0€Spedizione disponibile',
#   'town': 'Noventa di Piave '},
#  {'name': 'Sinclair ZX Spectrum 16kb',
#   'price': '550\xa0€Spedizione disponibile',
#   'town': 'Torino '},
#  {'name': 'Disco 2tb Batocera v36',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Pagani '},
#  {'name': 'Disco 2tb Batocera',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Pagani '},
#  {'name': 'Sinclair ZX Spectrum 48k',
#   'price': '280\xa0€',
#   'town': 'Villafranca Padovana '},
#  {'name': 'Computer sinclair zx spectrum 48k - testato 100%',
#   'price': '150\xa0€Spedizione disponibile',
#   'town': 'Salerno '},
#  {'name': 'Zx spectrum plus Sinclair',
#   'price': '200\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Zx Spectrum 48 K Sinclair',
#   'price': '99\xa0€Spedizione disponibile',
#   'town': 'Milano '},
#  {'name': 'SINCLAIR ZX SPECTRUM 48 K originale con scatola',
#   'price': '220\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Giochi per Sinclair ZX Spectrum',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Verona '},
#  {'name': 'Libri / Manuali Retrocomputer Spectrum Commodore',
#   'price': '50\xa0€Spedizione disponibile',
#   'town': 'Trapani '},
#  {'name': 'Sinclair ZX Spectrum + 48K',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Monterotondo '},
#  {'name': 'Sinclair ZX Spectrum Plus +2 Computer 128K Vintage',
#   'price': '130\xa0€Venduto',
#   'town': None},
#  {'name': 'ZX SPECTRUM Personal Computer',
#   'price': '180\xa0€',
#   'town': 'Chiaravalle '},
#  {'name': 'Copertina "Zub" per Sinclair Zx Spectrum 128k',
#   'price': '2\xa0€Spedizione disponibile',
#   'town': 'Sovico '},
#  {'name': 'Sinclair zx spectrum 48k +',
#   'price': '60\xa0€Spedizione disponibile',
#   'town': 'Velletri '},
#  {'name': 'Sinclair zx spectrum 48k',
#   'price': '100\xa0€Spedizione disponibile',
#   'town': 'Velletri '},
#  {'name': 'Sinclair ZX Interface 1',
#   'price': '90\xa0€Spedizione disponibile',
#   'town': 'Bologna '},
#  {'name': 'SINCLAIR ZX Spectrum', 'price': '70\xa0€Venduto', 'town': None},
#  {'name': 'ZX Spectrum + Sinclair 48k',
#   'price': '250\xa0€Spedizione disponibile',
#   'town': 'Viterbo '},
#  {'name': 'Cassetta Sinclair per ZX Spectrum - User Guide',
#   'price': '4\xa0€Spedizione disponibile',
#   'town': 'Trieste '},
#  {'name': 'Sinclair Spectrum',
#   'price': '150\xa0€Spedizione disponibile',
#   'town': 'Bologna '},
#  {'name': 'Sinclair ZX Spectrum No Commodore',
#   'price': '11\xa0€Spedizione disponibile',
#   'town': 'Grumello del Monte '},
#  {'name': 'Zx spectrum',
#   'price': '110\xa0€Spedizione disponibile',
#   'town': 'Prascorsano '},
#  {'name': 'Spectrum Graphic pen penna grafica pc Sinclair',
#   'price': '65\xa0€Spedizione disponibile',
#   'town': 'Roma '},
#  {'name': 'Sinclair ZX Spectrum 48K',
#   'price': '130\xa0€Spedizione disponibile',
#   'town': 'Genova '},
#  {'name': 'Cavo scart rgb per zx spectrum 128k +2a +2b +3',
#   'price': '21\xa0€',
#   'town': 'Milano '},
#  {'name': 'Zx spectrum 48k', 'price': '120\xa0€', 'town': 'Firenze '}]

# %% [markdown]
# ## Esercizio svolto in classe (base)

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup

url_list = [
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=1',
    'https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair&o=2'
]

result = requests.get(url_list[0])

if result.status_code == 200:
    soup = BeautifulSoup(result.content, 'html.parser')
    print(soup.prettify())

    products = soup.select('div.items__item.item-card')

    items = []

    for adv in products:
        data = {
            'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),
            # 'name': adv.select('h2[class*=ItemTitle-module_item-title__]')[0] \
            #     .get_text() if adv.select('h2[class*=ItemTitle-module_item-title__]') else None,
            'price': adv.select('p.price'),
            'town': adv.select('span[class*=index-module_town__]'),
            'city': adv.select('span.city'),
            'shipping': adv.select('span.shipping-badge'),
            'sold': adv.select('span.item-sold-badge'),  
            'date': adv.select('span[class*=index-module_date__]'),
        }

        for key, value in data.items():
            if value:
                data[key] = value[0].get_text()
                # data[key] = value[0].string
                # data[key] = value[0].find(string=True, recursive=False) 
            else:
                data[key] = None

            # data[key] = value[0].get_text() if value else None

        data.update({
            'price': data['price']
                    .replace('Spedizione disponibile', '')
                    .replace('\xa0€', '')
                    .replace('Venduto', ''),
            'url': adv.select('a.link')[0]['href'],
            'url': adv.a['href'],
        })

        items.append(data)
    
    pprint(items)
# Out:
# <!DOCTYPE html>
# <html lang="it">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <script>
#    window.gdprAppliesGlobally=true;
#   </script>
#   <script async="" fetchpriority="high" src="https://sdk.privacy-center.org/bd1597a9-9e29-4189-bc67-064d912dff5d/loader.js?target=www.subito.it">
#   </script>
#   <title>
#    Spectrum sinclair - Vendita in tutta Italia - Subito.it
#   </title>
#   <meta content="Spectrum sinclair in vendita: scopri subito migliaia di annunci di privati e aziende e trova quello che cerchi su Subito.it" name="description"/>
#   <meta content="index,follow" name="robots"/>
#   <link href="https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum+sinclair" rel="canonical"/>
#   <script>
#   </script>
#   <meta content="Subito.it" property="og:title"/>
#   <meta content="Spectrum sinclair in vendita: scopri subito migliaia di annunci di privati e aziende e trova quello che cerchi su Subito.it" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="" property="og:image"/>
#   <meta content="https://www.subito.it" property="og:url"/>
#   <meta content="Subito" property="og:site_name"/>
#   <meta content="it_IT" property="og:locale"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@Subitoit" name="twitter:site"/>
#   <script>
#    window.subitoAdvConfig={"bidders":{"ow":true,"tam":false},"includeAdSense":true}
#   </script>
#   <script async="" fetchpriority="high" src="/static/script/subito-adv.1685289075.js">
#   </script>
#   <script>
#    window.subitoAdvQueue = window.subitoAdvQueue || [];
#   </script>
#   <script async="" fetchpriority="high" id="_gpt_script" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script async="" fetchpriority="high" src="https://ads.pubmatic.com/AdServer/js/pwt/81997/8847/pwt.js">
#   </script>
#   <script>
#    (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
#   </script>
#   <script async="" fetchpriority="high" src="https://www.google.com/adsense/search/ads.js">
#   </script>
#   <meta content="25" name="next-head-count"/>
#   <link href="/static/metadata/osdd.xml" rel="search" type="application/opensearchdescription+xml"/>
#   <link href="/static/img/favicon-32.png" rel="icon" sizes="32x32"/>
#   <link href="/static/img/favicon-57.png" rel="icon" sizes="57x57"/>
#   <link href="/static/img/favicon-76.png" rel="icon" sizes="76x76"/>
#   <link href="/static/img/favicon-128.png" rel="icon" sizes="128x128"/>
#   <link href="/static/img/favicon-192.png" rel="icon" sizes="192x192"/>
#   <link href="/static/img/favicon-228.png" rel="icon" sizes="228x228"/>
#   <link href="/static/img/favicon-196.png" rel="shortcut icon" sizes="196x196"/>
#   <link href="/static/img/app-icon-192.png" rel="apple-touch-icon" sizes="192x192"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="telephone=no, address=no, email=no" name="format-detection"/>
#   <link href="/static/manifest.json" rel="manifest"/>
#   <style>
#    @font-face {
#               font-family: 'LFTEtica';
#               font-display: fallback;
#               src: url('https://assets.subito.it/static/fonts/LFTEtica-Book.woff2') format('woff2');
#               font-weight: normal;
#               font-style: normal;
#             }
#             @font-face {
#               font-family: 'LFTEtica';
#               font-display: fallback;
#               src: url('https://assets.subito.it/static/fonts/LFTEtica-Semibold.woff2') format('woff2');
#               font-weight: 600;
#               font-style: normal;
#             }
#   </style>
#   <link as="font" crossorigin="anonymous" href="https://assets.subito.it/static/fonts/LFTEtica-Book.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://assets.subito.it/static/fonts/LFTEtica-Semibold.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://images.sbito.it" rel="preconnect"/>
#   <link as="script" crossorigin="anonymous" href="https://assets.subito.it/v2/libraries/data_layer.js" rel="preload"/>
#   <link as="script" crossorigin="anonymous" href="https://assets.subito.it/v2/modulemanager.js" rel="preload"/>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TWPJW6H">
#   </script>
#   <link href="https://collector.mpianalytics.com" rel="dns-prefetch"/>
#   <link href="https://cis.mpianalytics.com" rel="dns-prefetch"/>
#   <link as="style" href="/_next/static/css/6616304730a0d7c0.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/6616304730a0d7c0.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/582d23e48f37bd4f.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/582d23e48f37bd4f.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/af140682f555e4ca.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/af140682f555e4ca.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/11574656e9443954.css" rel="preload"/>
#   <link href="/_next/static/css/11574656e9443954.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/406.44a3f2910e557f59.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/789.2de80758d15e5364.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-a80669c2d4c6f0aa.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework-a5891c46e27ba3e5.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-1294d60bc97dac46.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/_app-336a02f453a93bb5.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/523-1c84d1d7c8e61fae.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/971-e2977768fbb3fb70.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/710-df59585556c2fdde.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/listing-cc8f73df2c427a96.js">
#   </script>
#   <script defer="" src="/_next/static/7sxuJshTp4wz6Gbpcg5RJ/_buildManifest.js">
#   </script>
#   <script defer="" src="/_next/static/7sxuJshTp4wz6Gbpcg5RJ/_ssgManifest.js">
#   </script>
#  </head>
#  <body>
#   <script>
#    window.subito = {dataLayer: []};
#               window.didomiOnReady = window.didomiOnReady || [];
#   </script>
#   <div data-reactroot="" id="__next">
#    <style>
#     #skinadvtop2 ~ body #apn_skin_tag {
#               height: 0!important;
#             }
#    </style>
#    <div id="apn_skin_tag" style="max-height:122px;position:sticky;text-align:center;top:0;height:90px">
#    </div>
#    <div id="apnx_preroll_wrapper" style="position:fixed;bottom:0;right:0;z-index:1">
#     <div id="apnx_preroll" style="display:none;width:400px;margin-right:20px;margin-bottom:73px;text-align:end;background-color:#fff">
#     </div>
#     <div id="apnx_preroll_close_button" style="position:absolute;top:4px;right:25px;width:35px;height:20px;z-index:2;display:none;font-size:12px;font-weight:500;cursor:pointer">
#      Chiudi
#     </div>
#    </div>
#    <div class="layout_wrapper__A4OIT theme-redCorporate" id="layout">
#     <div data-google-interstitial="false">
#      <div>
#       <div class="index-module_visible-sticky-banner-with-popup__4FQv0" id="index-module_mobile-navigation__YyhV0">
#        <div class="index-module_header-container__lxbI8 index-module_visible__5uywn">
#         <div class="">
#          <button class="index-module_sticky-banner-wrapper__gMn4n">
#           <div class="index-module_sticky-banner__tgoId">
#            <div class="index-module_stars-container__BuVI-">
#             <div class="index-module_star-small-left__yKCTu">
#              <svg fill="none" height="6" viewbox="0 0 14 12" width="7" xmlns="http://www.w3.org/2000/svg">
#               <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#fcb3b0">
#               </path>
#              </svg>
#             </div>
#             <div class="index-module_star-big-left__RnHMD">
#              <svg fill="none" height="12" viewbox="0 0 14 12" width="14" xmlns="http://www.w3.org/2000/svg">
#               <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#a62133">
#               </path>
#              </svg>
#             </div>
#            </div>
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA index-module_text__vtUf5">
#             Scegli i punti di ritiro per le spedizioni con TuttoSubito.
#             <!-- -->
#             <strong>
#              Scopri di più.
#             </strong>
#            </span>
#            <div class="index-module_stars-container__BuVI-">
#             <div class="index-module_star-big-right__dM09H">
#              <svg fill="none" height="12" viewbox="0 0 14 12" width="14" xmlns="http://www.w3.org/2000/svg">
#               <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#a62133">
#               </path>
#              </svg>
#             </div>
#             <div class="index-module_star-small-right__Inwzy">
#              <svg fill="none" height="6" viewbox="0 0 14 12" width="7" xmlns="http://www.w3.org/2000/svg">
#               <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#fcb3b0">
#               </path>
#              </svg>
#             </div>
#             <div class="index-module_star-very-small-right__qJrum">
#              <svg fill="none" height="3" viewbox="0 0 14 12" width="3.5" xmlns="http://www.w3.org/2000/svg">
#               <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#fcb3b0">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </div>
#          </button>
#         </div>
#         <div class="index-module_fluid-container__3n68n">
#          <div class="index-module_fluid-column__xe0jo">
#           <a class="index-module_header-link__pcEnw" href="https://www.subito.it">
#            <div class="index-module_header-icon__W6am6">
#             <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <g fill-rule="nonzero">
#               <path d="M20.604 12.12l-2.244.838c-.322.12-.693-.025-.823-.324l-3.491-7.99c-.13-.3.027-.643.35-.763l2.244-.838c.322-.121.693.024.824.323l3.49 7.99c.13.3-.027.643-.35.763M14.84 13.335l-1.505 1.505a.552.552 0 0 1-.778 0L5.16 7.443a.552.552 0 0 1 0-.778L6.665 5.16a.551.551 0 0 1 .777 0l7.398 7.397a.552.552 0 0 1 0 .778M12.957 18.36l-.838 2.244c-.12.323-.463.48-.762.35l-7.99-3.491c-.3-.13-.445-.501-.325-.824l.84-2.244c.12-.322.463-.48.76-.35l7.992 3.492c.299.13.444.5.323.824">
#               </path>
#              </g>
#             </svg>
#            </div>
#            <p class="index-module_link-title__mnAgF">
#             Home
#            </p>
#           </a>
#          </div>
#          <div class="index-module_fluid-column__xe0jo">
#           <a class="index-module_header-link__pcEnw index-module_active__3IQoN" href="#">
#            <div class="index-module_header-icon__W6am6">
#             <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M15.05 16.463a7.5 7.5 0 1 1 1.414-1.414l4.243 4.244a1 1 0 0 1-1.414 1.414l-4.244-4.244zM10.5 16a5.5 5.5 0 1 0 0-11 5.5 5.5 0 0 0 0 11z" fill-rule="evenodd">
#              </path>
#             </svg>
#            </div>
#            <p class="index-module_link-title__mnAgF">
#             Cerca
#            </p>
#           </a>
#          </div>
#          <div class="index-module_fluid-column__xe0jo">
#           <a class="index-module_header-link__pcEnw" href="https://www.subito.it/vendere/">
#            <div class="index-module_header-icon__W6am6">
#             <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M8 5a3 3 0 0 0-3 3v8a3 3 0 0 0 3 3h8a3 3 0 0 0 3-3V8a3 3 0 0 0-3-3H8zm0-2h8a5 5 0 0 1 5 5v8a5 5 0 0 1-5 5H8a5 5 0 0 1-5-5V8a5 5 0 0 1 5-5zm5 8h3a1 1 0 0 1 0 2h-3v3a1 1 0 0 1-2 0v-3H8a1 1 0 0 1 0-2h3V8a1 1 0 0 1 2 0v3z" fill-rule="evenodd">
#              </path>
#             </svg>
#            </div>
#            <p class="index-module_link-title__mnAgF">
#             Vendi
#            </p>
#           </a>
#          </div>
#          <div class="index-module_fluid-column__xe0jo">
#           <a class="index-module_header-link__pcEnw" href="https://areariservata.subito.it/messaggi">
#            <div class="index-module_header-icon__W6am6">
#             <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6 19H5a3 3 0 0 1-3-3V8a3 3 0 0 1 3-3h14a3 3 0 0 1 3 3v8a3 3 0 0 1-3 3h-7.667L9.2 20.6A2 2 0 0 1 6 19zm13-2a1 1 0 0 0 1-1V8a1 1 0 0 0-1-1H5a1 1 0 0 0-1 1v8a1 1 0 0 0 1 1h3v2l2.667-2H19zM9 12a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm4 0a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm4 0a1 1 0 1 1-2 0 1 1 0 0 1 2 0z" fill-rule="evenodd">
#              </path>
#             </svg>
#            </div>
#            <p class="index-module_link-title__mnAgF">
#             Messaggi
#            </p>
#           </a>
#          </div>
#          <div class="index-module_fluid-column__xe0jo">
#           <a class="index-module_header-link__pcEnw">
#            <div class="index-module_header-icon__W6am6">
#            </div>
#            <p class="index-module_link-title__mnAgF">
#            </p>
#           </a>
#          </div>
#         </div>
#        </div>
#        <section aria-modal="true" role="dialog">
#         <div class="index-module_sidebar-container__czSgA index-module_sidebar-right__hvyPB">
#          <div class="index-module_sidebar-header__BQAvP">
#           <h6 class="index-module_sbt-text-atom__ed5J9 index-module_token-h6__FGmXw size-normal index-module_weight-semibold__MWtJJ index-module_header-text__LOM6i">
#            Accedi
#           </h6>
#           <button aria-label="Chiudi il menù" class="index-module_sbt-button__hQMUx index-module_text__nhl4i index-module_large__Zhzux index-module_close-button__1JSPd index-module_icon-only__gkRU8" type="button">
#            <svg aria-hidden="true" class="" height="16px" role="img" viewbox="0 0 18 18" width="16px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <g fill="#aeb9c6" fill-rule="evenodd" id="Close" stroke="none" stroke-width="1">
#              <path d="M7.99 9L4.21 5.22a.714.714 0 0 1 1.01-1.01L9 7.99l3.78-3.78a.714.714 0 0 1 1.01 1.01L10.01 9l3.78 3.78a.714.714 0 0 1-1.01 1.01L9 10.01l-3.78 3.78a.714.714 0 0 1-1.01-1.01L7.99 9z">
#              </path>
#             </g>
#            </svg>
#           </button>
#          </div>
#          <div class="index-module_sidebar-content__vBHsJ">
#           <menu class="index-module_menu-list__ZiPDz">
#            <li class="index-module_item__vvcgL">
#             <a class="index-module_item-link__deMmy" href="https://areariservata.subito.it/transazioni/lista">
#              <svg fill="none" height="25" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="m12.216 4.524.14.042 9 3.428.076.033.144.084.103.083.052.052.09.112.077.13.038.087.033.106.025.141.006.107v9.142a1 1 0 0 1-.532.884l-.112.05-9.04 3.444-.184.042-.152.01-.112-.01-.113-.021-.111-.035-9-3.43a1 1 0 0 1-.636-.81L2 18.07V8.88l.006-.059L2 8.93l.002-.063.027-.176.037-.117.047-.107.059-.098.079-.102.114-.11.1-.072.112-.062.103-.042 8.964-3.414a1 1 0 0 1 .457-.06l.115.018ZM20 17.38v-7.058l-.666.238-.567.21c-.263.099-.511.195-.74.288l-.362.15a17.81 17.81 0 0 0-.166.07L17.5 13.5a1 1 0 0 1-1.993.117L15.5 13.5v-1.407l-2.5.952v7.004l7-2.668ZM4 10.379v7.003l7 2.667v-7.003l-7-2.667Zm3.5-2.096-1.692.645L12 11.287l1.691-.644L7.5 8.283Zm4.499-1.714-1.691.644 6.147 2.343.388-.171c.137-.059.282-.119.434-.18l.25-.1.56-.216-6.088-2.32Z" fill="#717e8f" fill-rule="evenodd">
#               </path>
#              </svg>
#              <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P size-normal index-module_weight-book__WdOfA">
#               I tuoi ordini
#              </p>
#             </a>
#            </li>
#            <li class="index-module_item__vvcgL">
#             <a class="index-module_item-link__deMmy" href="https://areariservata.subito.it/annunci">
#              <svg fill="none" height="25" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M5 2.5h14a2 2 0 0 1 2 2v16a2 2 0 0 1-2 2H5a2 2 0 0 1-2-2v-16a2 2 0 0 1 2-2Zm0 2v16h14v-16H5Zm2 1h10a1 1 0 0 1 1 1v5a1 1 0 0 1-1 1H7a1 1 0 0 1-1-1v-5a1 1 0 0 1 1-1Zm1 2v3h8v-3H8Zm-2 7a1 1 0 0 1 1-1h10a1 1 0 1 1 0 2H7a1 1 0 0 1-1-1Zm1 2a1 1 0 1 0 0 2h8a1 1 0 1 0 0-2H7Z" fill="#717e8f" fill-rule="evenodd">
#               </path>
#              </svg>
#              <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P size-normal index-module_weight-book__WdOfA">
#               I tuoi annunci
#              </p>
#             </a>
#            </li>
#            <li class="index-module_item__vvcgL">
#             <a class="index-module_item-link__deMmy" href="https://areariservata.subito.it/preferiti">
#              <svg fill="none" height="25" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M16 3.5c3.552 0 6 2.448 6 6 0 4.098-3.212 8.024-9.479 11.853a1 1 0 0 1-1.043 0C5.213 17.523 2 13.598 2 9.5c0-3.552 2.448-6 6-6 1.397 0 2.728.682 4 1.987C13.272 4.182 14.603 3.5 16 3.5Zm4 6c0-2.448-1.552-4-4-4-.981 0-2.058.673-3.22 2.125a1 1 0 0 1-1.56 0C10.057 6.173 8.98 5.5 8 5.5c-2.448 0-4 1.552-4 4 0 3.136 2.619 6.433 8 9.823 5.381-3.39 8-6.687 8-9.823Z" fill="#717e8f" fill-rule="evenodd">
#               </path>
#              </svg>
#              <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P size-normal index-module_weight-book__WdOfA">
#               Preferiti
#              </p>
#             </a>
#            </li>
#            <li class="index-module_item__vvcgL">
#             <a class="index-module_item-link__deMmy" href="https://areariservata.subito.it/ricerche">
#              <svg fill="none" height="25" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M17.5 16.562a6.955 6.955 0 0 1-1.158.536 1 1 0 0 1-.67-1.884A4.996 4.996 0 0 0 19 10.5a5 5 0 0 0-8.727-3.334 1 1 0 0 1-1.49-1.334 7 7 0 0 1 10.823 8.86l3.101 3.1a1 1 0 0 1-1.414 1.415l-3.1-3.1c-.22.164-.452.316-.692.455ZM15 12.388c0-2.106-1.722-3.888-3.824-3.888A3.835 3.835 0 0 0 8.5 9.583 3.835 3.835 0 0 0 5.824 8.5C3.721 8.5 2 10.273 2 12.377c0 2.217 1.16 4.155 3.08 5.885.512.461 1.049.881 1.634 1.294.235.166.706.483.923.63l.113.076a1.298 1.298 0 0 0 1.5 0l.112-.076c.216-.145.689-.464.924-.63a17.491 17.491 0 0 0 1.633-1.294C13.84 16.532 15 14.598 15 12.388Zm-4.42 4.388c-.446.403-.923.775-1.447 1.146-.146.103-.408.28-.633.433-.225-.152-.487-.33-.633-.433a15.447 15.447 0 0 1-1.448-1.146C4.88 15.388 4 13.921 4 12.377c0-1.013.839-1.877 1.824-1.877.791 0 1.483.5 1.73 1.223.308.902 1.584.902 1.892 0a1.822 1.822 0 0 1 1.73-1.223c.982 0 1.824.872 1.824 1.888 0 1.536-.878 3-2.42 4.388Z" fill="#717e8f" fill-rule="evenodd">
#               </path>
#               <mask height="18" id="a" maskunits="userSpaceOnUse" width="21" x="2" y="3">
#                <path clip-rule="evenodd" d="M17.5 16.562a6.955 6.955 0 0 1-1.158.536 1 1 0 0 1-.67-1.884A4.996 4.996 0 0 0 19 10.5a5 5 0 0 0-8.727-3.334 1 1 0 0 1-1.49-1.334 7 7 0 0 1 10.823 8.86l3.101 3.1a1 1 0 0 1-1.414 1.415l-3.1-3.1c-.22.164-.452.316-.692.455ZM15 12.388c0-2.106-1.722-3.888-3.824-3.888A3.835 3.835 0 0 0 8.5 9.583 3.835 3.835 0 0 0 5.824 8.5C3.721 8.5 2 10.273 2 12.377c0 2.217 1.16 4.155 3.08 5.885.512.461 1.049.881 1.634 1.294.235.166.706.483.923.63l.113.076a1.298 1.298 0 0 0 1.5 0l.112-.076c.216-.145.689-.464.924-.63a17.491 17.491 0 0 0 1.633-1.294C13.84 16.532 15 14.598 15 12.388Zm-4.42 4.388c-.446.403-.923.775-1.447 1.146-.146.103-.408.28-.633.433-.225-.152-.487-.33-.633-.433a15.447 15.447 0 0 1-1.448-1.146C4.88 15.388 4 13.921 4 12.377c0-1.013.839-1.877 1.824-1.877.791 0 1.483.5 1.73 1.223.308.902 1.584.902 1.892 0a1.822 1.822 0 0 1 1.73-1.223c.982 0 1.824.872 1.824 1.888 0 1.536-.878 3-2.42 4.388Z" fill="#fff" fill-rule="evenodd">
#                </path>
#               </mask>
#              </svg>
#              <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P size-normal index-module_weight-book__WdOfA">
#               Ricerche salvate
#              </p>
#             </a>
#            </li>
#           </menu>
#           <div class="index-module_sidebar-bottom__1flbJ">
#            <div class="index-module_actions-container__lVLoK">
#             <a class="index-module_link__nwIkS index-module_solid__oARUV index-module_medium__4CM9m index-module_login__btn__-koW4" href="https://areariservata.subito.it/login_form">
#              <span class="index-module_sbt-text-atom__ed5J9 index-module_token-button__eMeQT size-normal index-module_weight-semibold__MWtJJ index-module_button-text__xHoM9">
#               Accedi
#              </span>
#             </a>
#             <a href="https://areariservata.subito.it/form">
#              <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA index-module_signup__copy__3Z44Y">
#               Non hai ancora un account?
#               <strong>
#                Registrati
#               </strong>
#              </p>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div aria-hidden="true" class="index-module_sidebar-overlay__LW4a0">
#         </div>
#        </section>
#       </div>
#       <header class="index-module_header-wrapper__DdDr3">
#        <div class="">
#         <button class="index-module_sticky-banner-wrapper__gMn4n">
#          <div class="index-module_sticky-banner__tgoId">
#           <div class="index-module_stars-container__BuVI-">
#            <div class="index-module_star-small-left__yKCTu">
#             <svg fill="none" height="6" viewbox="0 0 14 12" width="7" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#fcb3b0">
#              </path>
#             </svg>
#            </div>
#            <div class="index-module_star-big-left__RnHMD">
#             <svg fill="none" height="12" viewbox="0 0 14 12" width="14" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#a62133">
#              </path>
#             </svg>
#            </div>
#           </div>
#           <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA index-module_text__vtUf5">
#            Scegli i punti di ritiro per le spedizioni con TuttoSubito.
#            <!-- -->
#            <strong>
#             Scopri di più.
#            </strong>
#           </span>
#           <div class="index-module_stars-container__BuVI-">
#            <div class="index-module_star-big-right__dM09H">
#             <svg fill="none" height="12" viewbox="0 0 14 12" width="14" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#a62133">
#              </path>
#             </svg>
#            </div>
#            <div class="index-module_star-small-right__Inwzy">
#             <svg fill="none" height="6" viewbox="0 0 14 12" width="7" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#fcb3b0">
#              </path>
#             </svg>
#            </div>
#            <div class="index-module_star-very-small-right__qJrum">
#             <svg fill="none" height="3" viewbox="0 0 14 12" width="3.5" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.55.16c0 1.54.7 3.02 1.92 4.12a6.99 6.99 0 0 0 4.63 1.7c-1.74 0-3.4.62-4.63 1.7a5.52 5.52 0 0 0-1.92 4.12 5.5 5.5 0 0 0-1.92-4.11A6.99 6.99 0 0 0 0 5.99a7 7 0 0 0 4.63-1.71A5.52 5.52 0 0 0 6.55.16Z" fill="#fcb3b0">
#              </path>
#             </svg>
#            </div>
#           </div>
#          </div>
#         </button>
#        </div>
#        <nav class="index-module_top-link-container__1kIBU">
#         <ul>
#          <li>
#           <a href="https://www.subito.it/magazine/#?utm_source=sbtclassified&amp;utm_medium=listingheader">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Magazine
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="https://info.subito.it/per-i-privati.htm">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Consigli per la vendita
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="https://impresapiu.subito.it/shops?xtfrom=header_menu">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Negozi e Aziende
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="https://aziende.subito.it/">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Subito per le Aziende
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="https://assistenza.subito.it/hc/it">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Aiuto
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="https://areariservata.subito.it/ricerche">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Ricerche salvate
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="https://areariservata.subito.it/preferiti">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Preferiti
#            </span>
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <div class="index-module_header__r5EmJ">
#         <a aria-label="Torna alla pagina principale" href="https://www.subito.it" title="Subito.it">
#          <img alt="" class="corporate-logo" crossorigin="anonymous" height="36" src="https://assets.subito.it/static/logos/corporate.svg" width="230"/>
#         </a>
#         <div class="index-module_top-menu-container__IpvvE">
#         </div>
#         <div class="index-module_button-add__pXNeG">
#          <a href="https://www.subito.it/vendere/">
#           <div class="index-module_button__wrBiG index-module_btn-add-ad__56z7X">
#            <div class="index-module_header-icon-add-ad__tFQDk">
#             <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M8 5a3 3 0 0 0-3 3v8a3 3 0 0 0 3 3h8a3 3 0 0 0 3-3V8a3 3 0 0 0-3-3H8zm0-2h8a5 5 0 0 1 5 5v8a5 5 0 0 1-5 5H8a5 5 0 0 1-5-5V8a5 5 0 0 1 5-5zm5 8h3a1 1 0 0 1 0 2h-3v3a1 1 0 0 1-2 0v-3H8a1 1 0 0 1 0-2h3V8a1 1 0 0 1 2 0v3z">
#              </path>
#             </svg>
#            </div>
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-button__eMeQT size-normal index-module_weight-semibold__MWtJJ">
#             Inserisci annuncio
#            </span>
#           </div>
#          </a>
#         </div>
#        </div>
#       </header>
#      </div>
#     </div>
#     <main class="layout_main__nnqaA">
#      <div data-google-interstitial="false">
#       <div class="index-module_notificationContainer__xLNyJ">
#       </div>
#      </div>
#      <div>
#       <style>
#        @media (min-width: 980px) {
#           /* The same gradient is set so that with an ADV skin, the
#           * column still shows the gradient. When there is no skin,
#           * the gradients align because both begin at the top of the
#           * document.
#           */
#           body {
#             background-image: linear-gradient(
#               #fff,
#               #fff 120px,
#               #f7f8fb 230px,
#               #fff 230px
#             );
#           }
#
#           #apn_top_tag {
#             text-align: center;
#             min-height:250px;
#             background: url(https://assets.subito.it/static/reclame/reclame-placeholder-970x250.png) center center no-repeat;
#           }
#           #apn_top_tag div iframe {
#             text-align: center;
#             margin: 0 auto;
#           }
#           #apn_top_tag &gt; div:not(div:empty){
#             background:#fff;
#             min-height:250px;
#             display: flex;
#             width:100%!important;
#             align-items: center;
#           }
#         }
#
#         @media (max-width: 767px) {
#           #reclame-listing-top,
#           #li-gpt-msite-listing-3,
#           #reclame-listing-bottom {
#             text-align: center;
#           }
#
#           #af-smart-banner.afb-container {
#             z-index: 101;
#           }
#         }
#       </style>
#       <noscript>
#        <style>
#         #banner_container {
#           flex: 0 !important;
#         }
#        </style>
#       </noscript>
#       <div data-google-interstitial="false">
#        <div class="breadcrumbs-listing-container ListingBreadcrumbs_breadcrumbs-listing-container__vZymW">
#         <ol class="index-module_container__rA-Ps" itemscope="" itemtype="https://schema.org/BreadcrumbList">
#          <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#           <a href="https://www.subito.it/" itemprop="item">
#            <span itemprop="name">
#             Subito.it
#            </span>
#           </a>
#           <meta content="1" itemprop="position"/>
#           <img alt="" crossorigin="anonymous" height="16px" src="https://assets.subito.it/static/icons/cactus/arrow-right.svg" width="16px"/>
#          </li>
#          <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#           <a href="https://www.subito.it/annunci-italia/vendita/usato/" itemprop="item">
#            <span itemprop="name">
#             In vendita
#            </span>
#           </a>
#           <meta content="2" itemprop="position"/>
#           <img alt="" crossorigin="anonymous" height="16px" src="https://assets.subito.it/static/icons/cactus/arrow-right.svg" width="16px"/>
#          </li>
#          <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#           <a href="https://www.subito.it/annunci-italia/vendita/usato/?q=spectrum%2Bsinclair" itemprop="item">
#            <span itemprop="name">
#             spectrum sinclair
#            </span>
#           </a>
#           <meta content="3" itemprop="position"/>
#          </li>
#         </ol>
#        </div>
#        <div class="searchbar-container search-bar_searchbar-container__nzSD1">
#         <div class="search-bar_input-container__waz0t" id="search-query-container">
#          <div class="index-module_container__JaNg0">
#           <p class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv size-normal index-module_weight-semibold__MWtJJ index-module_label__xPV4V">
#            Cosa cerchi?
#           </p>
#           <div class="index-module_container__pnR5y">
#            <div aria-expanded="false" aria-haspopup="listbox" aria-owns="downshift-666208-menu" role="combobox">
#             <div class="index-module_cactus-text-field__wrapper__-YL6k index-module_lg__gNHCa">
#              <div class="index-module_input-wrapper__ICMoR">
#               <div class="index-module_input-icon__nS8q7">
#                <svg aria-hidden="true" class="" height="24px" role="img" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <g fill="#aeb9c6" fill-rule="evenodd" id="Lens" stroke="none" stroke-width="1">
#                  <path d="M15.597 14.205a.989.989 0 0 1 .098.086l5.014 5.014a.993.993 0 1 1-1.404 1.404l-5.014-5.014a1.002 1.002 0 0 1-.086-.098 7 7 0 1 1 1.392-1.392zM10 15a5 5 0 1 0 0-10 5 5 0 0 0 0 10z">
#                  </path>
#                 </g>
#                </svg>
#               </div>
#               <input autocomplete="off" class="size-normal index-module_weight-book__2ghWz" id="/query/search_text" name="/query/search_text" placeholder="Vespa, iPhone, Bilocale" type="search" value="spectrum sinclair"/>
#               <button aria-label="Svuotare il campo" class="index-module_clear-icon__O8X6R index-module_show__zFLs1" type="button">
#                <svg aria-hidden="true" class="" height="24px" role="img" viewbox="0 0 18 18" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <g fill="#aeb9c6" fill-rule="evenodd" id="Close" stroke="none" stroke-width="1">
#                  <path d="M7.99 9L4.21 5.22a.714.714 0 0 1 1.01-1.01L9 7.99l3.78-3.78a.714.714 0 0 1 1.01 1.01L10.01 9l3.78 3.78a.714.714 0 0 1-1.01 1.01L9 10.01l-3.78 3.78a.714.714 0 0 1-1.01-1.01L7.99 9z">
#                  </path>
#                 </g>
#                </svg>
#               </button>
#              </div>
#             </div>
#            </div>
#            <ul aria-labelledby="downshift-666208-label" class="index-module_dropdown__VlwX-" id="downshift-666208-menu" role="listbox">
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="search-bar_input-container__waz0t" id="search-category-container">
#          <div class="index-module_container__JaNg0">
#           <p class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv size-normal index-module_weight-semibold__MWtJJ index-module_label__xPV4V">
#            In quale categoria?
#           </p>
#           <div class="category-selector_button-category-container__JwkLD">
#            <button class="index-module_sbt-button__hQMUx index-module_outline__reo8F index-module_medium__pYkH6 category-selector_button-category__gLova index-module_icon-only__gkRU8" type="button">
#             <svg class="category-selector_btn-category-icon-left__BDlVw" height="24" viewbox="0 0 24 24" width="24">
#              <path d="M5 3h4a2 2 0 0 1 2 2v4a2 2 0 0 1-2 2H5a2 2 0 0 1-2-2V5a2 2 0 0 1 2-2zm1 2a1 1 0 0 0-1 1v2a1 1 0 0 0 1 1h2a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1H6zm9-2h4a2 2 0 0 1 2 2v4a2 2 0 0 1-2 2h-4a2 2 0 0 1-2-2V5a2 2 0 0 1 2-2zm1 2a1 1 0 0 0-1 1v2a1 1 0 0 0 1 1h2a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2zm-1 8h4a2 2 0 0 1 2 2v4a2 2 0 0 1-2 2h-4a2 2 0 0 1-2-2v-4a2 2 0 0 1 2-2zm1 2a1 1 0 0 0-1 1v2a1 1 0 0 0 1 1h2a1 1 0 0 0 1-1v-2a1 1 0 0 0-1-1h-2zM5 13h4a2 2 0 0 1 2 2v4a2 2 0 0 1-2 2H5a2 2 0 0 1-2-2v-4a2 2 0 0 1 2-2zm1 2a1 1 0 0 0-1 1v2a1 1 0 0 0 1 1h2a1 1 0 0 0 1-1v-2a1 1 0 0 0-1-1H6z" fill="#aeb9c6" fill-rule="evenodd">
#              </path>
#             </svg>
#             <span class="index-module_sbt-text-atom__ed5J9 index-module_token-button__eMeQT size-normal index-module_weight-semibold__MWtJJ category-selector_button-category-text__ReA9L">
#              Tutte le categorie
#             </span>
#             <svg class="category-selector_btn-category-icon-right__jjl6B" height="18" viewbox="0 0 18 18" width="18">
#              <path d="M5.03 6.22a.75.75 0 0 0-1.06 1.06l4.5 4.5a.75.75 0 0 0 1.06 0l4.5-4.5a.75.75 0 0 0-1.06-1.06L9 10.19 5.03 6.22z" fill="#717e8f">
#              </path>
#             </svg>
#            </button>
#           </div>
#           <button class="index-module_sbt-button__hQMUx index-module_solid__fVa0q index-module_medium__pYkH6 category-selector_filter-button__pypj3 index-module_icon-only__gkRU8" type="button">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-button__eMeQT size-normal index-module_weight-semibold__MWtJJ index-module_button-text__VZcja">
#             Filtri
#            </span>
#           </button>
#          </div>
#         </div>
#         <div class="search-bar_input-container__waz0t" id="search-location-container">
#          <div class="index-module_container__JaNg0">
#           <p class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv size-normal index-module_weight-semibold__MWtJJ index-module_label__xPV4V">
#            Dove?
#           </p>
#           <div class="index-module_container__BF3kE">
#            <div aria-expanded="false" aria-haspopup="listbox" aria-owns="downshift-666209-menu" role="combobox">
#             <div class="index-module_cactus-text-field__wrapper__-YL6k index-module_lg__gNHCa">
#              <div class="index-module_input-wrapper__ICMoR">
#               <div class="index-module_input-icon__nS8q7">
#                <svg aria-hidden="true" class="" height="24px" role="img" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <g fill="#aeb9c6" fill-rule="evenodd" id="Pin" stroke="none" stroke-width="1">
#                  <path d="M12 22c-5.333-5.054-8-9.054-8-12a8 8 0 1116 0c0 2.946-2.667 6.946-8 12zM6 10c0 2.008 1.969 5.156 6 9.207 4.031-4.051 6-7.2 6-9.207a6 6 0 10-12 0zm6 3a3 3 0 110-6 3 3 0 010 6zm0-2a1 1 0 100-2 1 1 0 000 2z">
#                  </path>
#                 </g>
#                </svg>
#               </div>
#               <input autocomplete="off" class="size-normal index-module_weight-book__2ghWz" id="/geo" name="/geo" placeholder="Comune, Provincia o Regione" type="search" value="Tutta Italia"/>
#               <button aria-label="Svuotare il campo" class="index-module_clear-icon__O8X6R index-module_show__zFLs1" type="button">
#                <svg aria-hidden="true" class="" height="24px" role="img" viewbox="0 0 18 18" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <g fill="#aeb9c6" fill-rule="evenodd" id="Close" stroke="none" stroke-width="1">
#                  <path d="M7.99 9L4.21 5.22a.714.714 0 0 1 1.01-1.01L9 7.99l3.78-3.78a.714.714 0 0 1 1.01 1.01L10.01 9l3.78 3.78a.714.714 0 0 1-1.01 1.01L9 10.01l-3.78 3.78a.714.714 0 0 1-1.01-1.01L7.99 9z">
#                  </path>
#                 </g>
#                </svg>
#               </button>
#              </div>
#             </div>
#            </div>
#            <div class="index-module_dropdown-wrapper__cw00E">
#             <ul aria-labelledby="downshift-666209-label" class="index-module_dropdown__8PFfS" id="downshift-666209-menu" role="listbox">
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div id="apn_top_tag">
#        </div>
#        <div class="top-bar top-bar_top-bar__XXP5C">
#         <div id="saved-search-button">
#          <button class="index-module_sbt-button__hQMUx index-module_text__nhl4i index-module_medium__pYkH6 index-module_icon-only__gkRU8" type="button">
#           <svg height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M17.705 8.769c-.396-1.114-1.234-1.948-2.435-2.41-1.08-.415-2.158-.408-3.116.01-1.137.498-2.064 1.538-2.607 2.954-.7 1.832-1.41 2.662-2.871 3.43-.522.276-.539.29-.602.46a.493.493 0 00.033.401.787.787 0 00.418.368l10.156 3.91a.778.778 0 00.583 0 .457.457 0 00.267-.265c.065-.172.062-.197-.14-.747-.572-1.557-.548-2.644.153-4.476.488-1.275.54-2.566.161-3.635zm-8.58 8.412l-3.337-1.286a2.84 2.84 0 01-1.5-1.342 2.55 2.55 0 01-.128-2.066c.279-.738.642-1.063 1.565-1.55 1.009-.531 1.386-.97 1.912-2.35.733-1.908 2.036-3.37 3.7-4.098a5.92 5.92 0 013.623-.354l.169-.408c.217-.55.764-.85 1.371-.678.607.172.951.872.734 1.422l-.195.474a5.917 5.917 0 012.593 3.135c.55 1.553.478 3.344-.178 5.059-.527 1.378-.54 1.952-.144 3.03.358.973.41 1.46.13 2.193a2.497 2.497 0 01-1.359 1.41 2.815 2.815 0 01-2.133.035l-1.104-.424c-.701 1.317-2.327 1.956-3.808 1.436-1.543-.54-2.367-2.141-1.91-3.638zm1.942.747a.992.992 0 00.674 1.025c.429.15.894.01 1.162-.318l-1.836-.707z" fill-rule="evenodd">
#            </path>
#           </svg>
#           <span class="index-module_sbt-text-atom__ed5J9 index-module_token-button__eMeQT size-normal index-module_weight-semibold__MWtJJ index-module_button-text__VZcja">
#            Salva ricerca
#           </span>
#          </button>
#         </div>
#         <div class="">
#          <div class="index-module_container__RVEEV index-module_small__EYtpl order-selector OrderSelector_order-selector__CwxI0">
#           <div class="index-module_container__AaVws">
#            <div aria-expanded="false" class="index-module_wrapper__Lj83L index-module_small__EYtpl index-module_default__2rXUw" role="listbox" tabindex="0">
#             <input name="sort" type="hidden" value="datedesc"/>
#             <input inputmode="none" style="background:0;border:0;caret-color:transparent;font-size:inherit;grid-area:1 / 1 / 2 / 3;outline:0;padding:0;width:1px;color:transparent;left:-100px;opacity:0;position:absolute;transform:scale(.01);z-index:-1" tabindex="-1"/>
#             <div class="index-module_current__VFkKV">
#              <p>
#               Dal più recente
#              </p>
#              <div class="index-module_arrow__uw1YM">
#               <svg height="18" viewbox="0 0 18 18" width="18">
#                <path d="M5.03 6.22a.75.75 0 0 0-1.06 1.06l4.5 4.5a.75.75 0 0 0 1.06 0l4.5-4.5a.75.75 0 0 0-1.06-1.06L9 10.19 5.03 6.22z" fill="#717e8f">
#                </path>
#               </svg>
#              </div>
#             </div>
#             <ul class="index-module_options__LcYg6" role="listbox">
#              <li aria-selected="true" class="index-module_option__jdPpm index-module_selected__x3xN7" id="sort__option--0" role="option" tabindex="-1">
#               <p>
#                Dal più recente
#               </p>
#              </li>
#              <li aria-selected="false" class="index-module_option__jdPpm" id="sort__option--1" role="option" tabindex="-1">
#               <p>
#                Dal più rilevante
#               </p>
#              </li>
#              <li aria-selected="false" class="index-module_option__jdPpm" id="sort__option--2" role="option" tabindex="-1">
#               <p>
#                Dal meno caro
#               </p>
#              </li>
#              <li aria-selected="false" class="index-module_option__jdPpm" id="sort__option--3" role="option" tabindex="-1">
#               <p>
#                Dal più caro
#               </p>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="ListingContainer_container__4DQ56 container">
#        <div class="ListingContainer_col__1TZpb ListingContainer_filters___QEsV col filters">
#         <div data-google-interstitial="false">
#         </div>
#         <div class="ListingContainer_adv__efed5" id="banner_container">
#          <div class="ListingContainer_skyscraper__hHVp2" id="apn_skyscraper_tag">
#          </div>
#         </div>
#         <div data-google-interstitial="false">
#         </div>
#        </div>
#        <div class="ListingContainer_col__1TZpb ListingContainer_items__3lMdo col items">
#         <div class="container ItemListContainer_container__SjEc1">
#          <div data-google-interstitial="false">
#           <div class="listing-heading ListingHeading_listing-heading__QSQ4k">
#            <p class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv size-normal index-module_weight-semibold__MWtJJ total-ads AdsCount_total-ads__9aTXA">
#             57 risultati
#            </p>
#            <h1 class="index-module_sbt-text-atom__ed5J9 index-module_token-h6__FGmXw size-normal index-module_weight-semibold__MWtJJ">
#             Spectrum sinclair in tutta Italia
#            </h1>
#           </div>
#           <div class="search-expansion-container ItemListContainer_search-expansion-container___6piH">
#           </div>
#          </div>
#          <div class="">
#           <div>
#            <div class="items__item item-card item-card--small">
#             <a class="SmallCard-module_link__hOkzY link" href="https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-verona-495121453.htm">
#              <div class="SmallCard-module_container__d5-ZC container small">
#               <div class="SmallCard-module_picture-group__asLo2 picture-group">
#                <div class="SmallCard-module_item-picture__b7vGi item-picture CardImage-module_container__HxAgU CardImage-module_small__1NMzM">
#                 <figure>
#                  <img alt="Sinclair ZX Spectrum 48k personal computer" class="CardImage-module_photo__WMsiO" decoding="async" height="200" loading="eager" src="https://images.sbito.it/api/v1/sbt-ads-images-pro/images/30/30cc2d04-123b-4008-86fc-39576781a90c?rule=card-desktop-new-small-1x-auto" srcset="https://images.sbito.it/api/v1/sbt-ads-images-pro/images/30/30cc2d04-123b-4008-86fc-39576781a90c?rule=card-desktop-new-small-1x-auto 1x, https://images.sbito.it/api/v1/sbt-ads-images-pro/images/30/30cc2d04-123b-4008-86fc-39576781a90c?rule=card-desktop-new-small-2x-auto 2x, https://images.sbito.it/api/v1/sbt-ads-images-pro/images/30/30cc2d04-123b-4008-86fc-39576781a90c?rule=card-desktop-new-small-3x-auto 3x" width="200"/>
#                 </figure>
#                 <div class="CardImage-module_count__HEjKn">
#                  <img alt="Questo annuncio ha 6 immagini" decoding="async" height="16" loading="lazy" src="https://assets.subito.it/static/icons/cactus/camera.svg" width="16"/>
#                  <span aria-hidden="true">
#                   6
#                  </span>
#                 </div>
#                </div>
#                <div class="SmallCard-module_upper-data-group__aRFDu upper-data-group">
#                 <div class="SmallCard-module_item-key-data__fcbjY item-key-data">
#                  <h2 class="index-module_sbt-text-atom__ed5J9 index-module_token-h6__FGmXw size-normal index-module_weight-semibold__MWtJJ ItemTitle-module_item-title__VuKDo SmallCard-module_item-title__1y5U3">
#                   Sinclair ZX Spectrum 48k personal computer
#                  </h2>
#                  <div class="item-posting-time-place">
#                   <div class="PostingTimeAndPlace-module_date-location__1Owcv index-module_container__noDE3">
#                    <span class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv index-module_size-small__XFVFl index-module_weight-semibold__MWtJJ index-module_town__2H3jy">
#                     Nogarole Rocca
#                    </span>
#                    <span class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv index-module_size-small__XFVFl index-module_weight-semibold__MWtJJ city">
#                     (VR)
#                    </span>
#                    <span class="index-module_sbt-text-atom__ed5J9 index-module_token-caption__TaQWv index-module_size-small__XFVFl index-module_weight-semibold__MWtJJ index-module_date__Fmf-4 index-module_with-spacer__UNkQz">
#                     30 mag alle 16:25
#                    </span>
#                   </div>
# ...
#           <a class="Items-module_list-link__dTOg5" href="https://www.instagram.com/subito_it/" target="_blank">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Instagram
#            </span>
#           </a>
#          </li>
#          <li class="Items-module_list-link-wrapper__ZJyvN">
#           <img alt="" class="Items-module_footer-icon__YjICl" crossorigin="anonymous" height="16" loading="lazy" src="https://assets.subito.it/static/icons/social/youtube.svg" width="16"/>
#           <a class="Items-module_list-link__dTOg5" href="https://www.youtube.it/user/subitoit" target="_blank">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             YouTube
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="Items-module_items__column__9Kbm0">
#         <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-semibold__MWtJJ Items-module_items__column__title__LvV8X">
#          Scarica gratis l’App
#         </p>
#         <ul>
#          <li class="Items-module_list-link-wrapper__ZJyvN">
#           <img alt="" class="Items-module_footer-icon__YjICl" crossorigin="anonymous" height="16" loading="lazy" src="https://assets.subito.it/static/icons/app-stores/android.svg" width="16"/>
#           <a class="Items-module_list-link__dTOg5" href="https://play.google.com/store/apps/details?id=it.subito&amp;referrer=utm_source%3Dsite%26utm_medium%3Dfooter" target="_blank">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Subito per Android
#            </span>
#           </a>
#          </li>
#          <li class="Items-module_list-link-wrapper__ZJyvN">
#           <img alt="" class="Items-module_footer-icon__YjICl" crossorigin="anonymous" height="16" loading="lazy" src="https://assets.subito.it/static/icons/app-stores/apple.svg" width="16"/>
#           <a class="Items-module_list-link__dTOg5" href="https://itunes.apple.com/it/app/subito.it/id450775137?mt=8" target="_blank">
#            <span class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA">
#             Subito per iOS
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="index-module_footer-bottom__Lg88q">
#        <img alt="" crossorigin="anonymous" height="32" loading="lazy" src="https://assets.subito.it/static/logos/grey-short.svg" width="136"/>
#        <p class="index-module_sbt-text-atom__ed5J9 index-module_token-body__GXE1P index-module_size-small__XFVFl index-module_weight-book__WdOfA index-module_footer-info__ARO6n">
#         © 2023 Subito.it - P.IVA 05526340962
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="apn_native_bottom_tag">
#    </div>
#   </div>
#   <script crossorigin="anonymous" src="https://assets.subito.it/v2/libraries/data_layer.js">
#   </script>
#   <script crossorigin="anonymous" src="https://assets.subito.it/v2/modulemanager.js">
#   </script>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"state":{"system":{"preventPopstate":false},"search":{"id":null,"query":"spectrum sinclair","category":{"id":"0","label":"Tutte le categorie","friendly":"usato","orders":["datedesc","relevance","priceasc","pricedesc"],"adTypes":["s","g","u","h","k"],"defaultAdType":"s","categories":[]},"adType":"s","geo":{"region":{"id":"0","friendlyName":"italia","label":"Regione","level":0,"uri":"/region","value":"Tutta Italia"}},"qso":false,"includeShippableOnly":false,"includeUrgent":false,"filters":{},"filtersLabels":{"lim":"","q":"spectrum sinclair","qso":"No","shp":"No","sort":"","start":"","t":"In vendita","urg":""},"page":1,"orderIndex":0,"isUpdating":false,"filtersDialogOpen":false,"radiusDialogOpen":false,"filterOrigin":"ServersideSearch","searchNearRegions":false,"radiusSearch":null},"items":{"list":[{"before":[],"item":{"kind":"AdItem","urn":"id:ad:539817600:list:495121453","type":{"key":"s","value":"In vendita","weight":0},"category":{"id":"10","label":"Informatica","parentId":"9","friendlyName":"informatica","weight":23},"subject":"Sinclair ZX Spectrum 48k personal computer","body":"Vendo personal computer vintage Sinclair ZX Spectrum 48k del 1982 usato ma in ottime condizioni e perfettamente funzionante. Completo di manuale, scatola, rivestimento in polistirolo, alimentatore, cavo per il registratore e cavo rf.","date":"2023-05-30 16:25:50","images":[{"cdnBaseUrl":"https://images.sbito.it/api/v1/sbt-ads-images-pro/images/30/30cc2d04-123b-4008-86fc-39576781a90c"},{"cdnBaseUrl":"https://images.sbito.it/api/v1/sbt-ads-images-pro/images/b6/b621a9f6-281f-4e30-9256-b9287eb1336d"},{"cdnBaseUrl":"https://images.sbito.it/api/v1/sbt-ads-images-pro/images/bb/bbc18952-0a4c-4a48-a3d9-72d87baf0e6c"},{"cdnBaseUrl":"https://images.sbito.it/api/v1/sbt-ads-images-pro/images/ba/ba01fb08-1aed-4df8-b364-3027b1db6a03"},{"cdnBaseUrl":"https://images.sbito.it/api/v1/sbt-ads-images-pro/images/ab/ab9541cf-fbd1-40e5-9ec3-9cb3e7a0145c"},{"cdnBaseUrl":"https://images.sbito.it/api/v1/sbt-ads-images-pro/images/4d/4d21edb1-2fba-41f6-8568-99f642de8777"}],"features":{"/shipping_carriers":{"type":"list","uri":"/shipping_carriers","label":"Corrieri per la spedizione","values":[{"key":"poste_italiane","value":"poste_italiane"}]},"/item_shipping_cost_tuttosubito":{"type":"number","uri":"/item_shipping_cost_tuttosubito","label":"Costo della spedizione","values":[{"key":"7,90","value":"7,90 €"}]},"/item_shipping_type":{"type":"list","uri":"/item_shipping_type","label":"Metodo di spedizione","values":[{"key":"0","value":"Spedizione con TuttoSubito","weight":1}]},"/item_condition":{"type":"list","uri":"/item_condition","label":"Condizione","values":[{"key":"20","value":"Come nuovo - perfetto o ricondizionato","weight":2}]},"/price":{"type":"number","uri":"/price","label":"Prezzo","values":[{"key":"500","value":"500 €"}]},"/computer_type":{"type":"list","uri":"/computer_type","label":"Tipologia di computer","values":[{"key":"1","value":"Computer Fissi","weight":1}]},"/item_shippable":{"type":"bool","uri":"/item_shippable","label":"Disponibile alla spedizione","values":[{"key":"1","value":"Sì"}]},"/item_shipping_package_size":{"type":"list","uri":"/item_shipping_package_size","label":"Peso del pacco","values":[{"key":"20","value":"Medio - fino a 5kg","weight":1}]}},"advertiser":{"name":"Yuri Ferrarini","type":0,"userId":"114170675","company":false},"geo":{"uri":"/geo","type":"geo","label":"Comune","region":{"id":"6","value":"Veneto","label":"Regione","level":0,"friendlyName":"veneto","neighbors":"6,4,5,7,8","uri":"/geo/region"},"city":{"id":"6","value":"Verona","label":"Provincia","level":1,"friendlyName":"verona","istat":"023","regionId":"6","shortName":"VR","uri":"/geo/city"},"town":{"id":"023054","value":"Nogarole Rocca","label":"Comune","level":2,"friendlyName":"nogarole-rocca","istat":"023054","cityId":"6","hasZone":false,"regionId":"6","uri":"/geo/town"}},"urls":{"default":"https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-ve ...
#   </script>
#  </body>
# </html>
# [{'city': '(VR)',
#   'date': '30 mag alle 16:25',
#   'name': 'Sinclair ZX Spectrum 48k personal computer',
#   'price': '500',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Nogarole Rocca ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-verona-495121453.htm'},
#  {'city': '(PV)',
#   'date': '29 mag alle 15:15',
#   'name': 'Zx spectrum+2 128k sinclair',
#   'price': '300',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pavia ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-2-128k-sinclair-pavia-494925569.htm'},
#  {'city': '(VE)',
#   'date': '28 mag alle 19:46',
#   'name': 'ZX Spectrum SINCLAIR',
#   'price': '220',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Noventa di Piave ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-venezia-494813174.htm'},
#  {'city': '(TO)',
#   'date': '28 mag alle 10:42',
#   'name': 'Sinclair ZX Spectrum 16kb',
#   'price': '550',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-16kb-torino-494749976.htm'},
#  {'city': '(SA)',
#   'date': '27 mag alle 11:42',
#   'name': 'Disco 2tb Batocera v36',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pagani ',
#   'url': 'https://www.subito.it/informatica/disco-2tb-batocera-v36-salerno-494644761.htm'},
#  {'city': '(SA)',
#   'date': '27 mag alle 11:33',
#   'name': 'Disco 2tb Batocera',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pagani ',
#   'url': 'https://www.subito.it/informatica/disco-2tb-batocera-salerno-494643854.htm'},
#  {'city': '(PD)',
#   'date': '26 mag alle 23:07',
#   'name': 'Sinclair ZX Spectrum 48k',
#   'price': '280',
#   'shipping': None,
#   'sold': None,
#   'town': 'Villafranca Padovana ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-padova-439106844.htm'},
#  {'city': '(SA)',
#   'date': '25 mag alle 11:54',
#   'name': 'Computer sinclair zx spectrum 48k - testato 100%',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Salerno ',
#   'url': 'https://www.subito.it/informatica/computer-sinclair-zx-spectrum-48k-testato-100-salerno-494306297.htm'},
#  {'city': '(RM)',
#   'date': '25 mag alle 08:12',
#   'name': 'Zx spectrum plus Sinclair',
#   'price': '200',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/hobby-collezionismo/zx-spectrum-plus-sinclair-roma-368244153.htm'},
#  {'city': '(MI)',
#   'date': '24 mag alle 21:25',
#   'name': 'Zx Spectrum 48 K Sinclair',
#   'price': '99',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48-k-sinclair-milano-494232621.htm'},
#  {'city': '(RM)',
#   'date': '19 mag alle 14:54',
#   'name': 'SINCLAIR ZX SPECTRUM 48 K originale con scatola',
#   'price': '220',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48-k-originale-con-scatola-roma-405871112.htm'},
#  {'city': '(VR)',
#   'date': '17 mag alle 06:59',
#   'name': 'Giochi per Sinclair ZX Spectrum',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Verona ',
#   'url': 'https://www.subito.it/videogiochi/giochi-per-sinclair-zx-spectrum-verona-418137442.htm'},
#  {'city': '(RM)',
#   'date': '7 mag alle 09:54',
#   'name': 'Sinclair ZX Spectrum + 48K',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Monterotondo ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-roma-491135103.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Sinclair ZX Spectrum Plus +2 Computer 128K Vintage',
#   'price': '130',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-plus-2-computer-128k-vintage-taranto-490609627.htm'},
#  {'city': '(AN)',
#   'date': '28 apr alle 08:08',
#   'name': 'ZX SPECTRUM Personal Computer',
#   'price': '180',
#   'shipping': None,
#   'sold': None,
#   'town': 'Chiaravalle ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-personal-computer-ancona-312557879.htm'},
#  {'city': '(MB)',
#   'date': '26 apr alle 07:59',
#   'name': 'Copertina "Zub" per Sinclair Zx Spectrum 128k',
#   'price': '2',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Sovico ',
#   'url': 'https://www.subito.it/videogiochi/copertina-zub-per-sinclair-zx-spectrum-128k-monza-305924094.htm'},
#  {'city': '(RM)',
#   'date': '25 apr alle 18:14',
#   'name': 'Sinclair zx spectrum 48k +',
#   'price': '60',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Velletri ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-roma-489145320.htm'},
#  {'city': '(RM)',
#   'date': '24 apr alle 23:05',
#   'name': 'Sinclair zx spectrum 48k',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Velletri ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-roma-489044421.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'SINCLAIR ZX Spectrum',
#   'price': '70',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-torino-488011457.htm'},
#  {'city': '(VT)',
#   'date': '16 apr alle 18:40',
#   'name': 'ZX Spectrum + Sinclair 48k',
#   'price': '250',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Viterbo ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-48k-viterbo-487644953.htm'},
#  {'city': '(TS)',
#   'date': '9 apr alle 18:16',
#   'name': 'Cassetta Sinclair per ZX Spectrum - User Guide',
#   'price': '4',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Trieste ',
#   'url': 'https://www.subito.it/videogiochi/cassetta-sinclair-per-zx-spectrum-user-guide-trieste-149986531.htm'},
#  {'city': '(BO)',
#   'date': '7 apr alle 06:45',
#   'name': 'Sinclair Spectrum',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Bologna ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-spectrum-bologna-431858201.htm'},
#  {'city': '(BG)',
#   'date': '3 apr alle 21:36',
#   'name': 'Sinclair ZX Spectrum No Commodore',
#   'price': '11',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Grumello del Monte ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-no-commodore-bergamo-485710561.htm'},
#  {'city': '(TO)',
#   'date': '31 mar alle 20:12',
#   'name': 'Zx spectrum',
#   'price': '110',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Prascorsano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-torino-485261771.htm'},
#  {'city': '(RM)',
#   'date': '27 mar alle 23:40',
#   'name': 'Spectrum Graphic pen penna grafica pc Sinclair',
#   'price': '65',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/spectrum-graphic-pen-penna-grafica-pc-sinclair-roma-405001759.htm'},
#  {'city': '(GE)',
#   'date': '26 mar alle 10:39',
#   'name': 'Sinclair ZX Spectrum 48K',
#   'price': '130',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Genova ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-genova-402521305.htm'},
#  {'city': '(MI)',
#   'date': '26 mar alle 00:54',
#   'name': 'Cavo scart rgb per zx spectrum 128k +2a +2b +3',
#   'price': '21',
#   'shipping': None,
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/audio-video/cavo-scart-rgb-per-zx-spectrum-128k-2a-2b-3-milano-484276857.htm'},
#  {'city': '(FI)',
#   'date': '23 mar alle 07:14',
#   'name': 'Zx spectrum 48k',
#   'price': '120',
#   'shipping': None,
#   'sold': None,
#   'town': 'Firenze ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-48k-firenze-483776709.htm'},
#  {'city': '(BO)',
#   'date': '22 mar alle 11:05',
#   'name': 'Giochi commodore spectrum c16 msx',
#   'price': '20',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Crevalcore ',
#   'url': 'https://www.subito.it/videogiochi/giochi-commodore-spectrum-c16-msx-bologna-402734509.htm'},
#  {'city': '(CN)',
#   'date': '21 mar alle 11:13',
#   'name': 'Computer ZX Spectrum+ Sinclair vintage',
#   'price': '110',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Savigliano ',
#   'url': 'https://www.subito.it/videogiochi/computer-zx-spectrum-sinclair-vintage-cuneo-483450331.htm'}]

# %% [markdown]
# ## Esercizio svolto in classe (avanzato)

# %%
from datetime import datetime, date
import locale
import sys
import platform

print(platform.version())

# locale.setlocale(locale.LC_ALL, 'C')
locale.setlocale(locale.LC_ALL, 'it_IT')

# print(datetime.now().date())
# print(datetime.today().date())

# print(date.today())

dt = datetime.strptime('1 luglio', "%d %B")    # datetime object generation
print(dt)
print(type(dt))
# Out:
# Darwin Kernel Version 21.6.0: Mon Dec 19 20:44:01 PST 2022; root:xnu-8020.240.18~2/RELEASE_X86_64
# 1900-07-01 00:00:00
# <class 'datetime.datetime'>

# %%
import sys
import locale
from pprint import pprint
from random import uniform
from time import sleep
import datetime as dt
import requests
from bs4 import BeautifulSoup
from gestione_input import leggi_numero

if sys.platform in ['win32', 'cygwin']:
    locale.setlocale(locale.LC_ALL, 'it')
else:
    locale.setlocale(locale.LC_ALL, 'it_IT.UTF-8')


BASE_URL = 'https://www.subito.it/annunci-italia/vendita/usato/'

HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36',
}


search = input('Inserisci le parole chiave che vuoi cercare: ')

max_page = leggi_numero('Quante pagine vuoi analizzare? '
    'Premi semplicemente Invio per cercare su tutte le pagine disponibili.',
    'intero')


def scrape_page(page):
    query_str = {
        'q': search,
        'o': page
    }

    result = requests.get(BASE_URL, params=query_str, headers=HEADERS)

    if result.status_code == 200:
        soup = BeautifulSoup(result.content, 'html.parser')

        # Controlla se non è una pagina vuota
        no_results = soup.select('div[class*=ErrorLayout_container__]')
        if no_results:
            if page == 1:
                err_msg = f'La ricerca non ha prodotto risultati.'
            else:
                err_msg = f'Si è raggiunta la pagina n. {page} e qui non ci sono più risultati.'
            raise requests.RequestException(err_msg)
        
        products = soup.select('div.items__item.item-card')

        items = []

        for adv in products:
            data = {
                'name': adv.select('h2[class*=ItemTitle-module_item-title__]'),
                # 'name': adv.select('h2[class*=ItemTitle-module_item-title__]')[0] \
                #     .get_text() if adv.select('h2[class*=ItemTitle-module_item-title__]') else None,
                'price': adv.find_all('p', {'class': 'price'}),
                # 'price': adv.select('p.price'),
                'town': adv.select('span[class*=index-module_town__]'),
                'city': adv.select('span.city'),
                'shipping': adv.select('span.shipping-badge'),
                'sold': adv.select('span.item-sold-badge'),
                'date': adv.select('span[class*=index-module_date__]')
                # 'url': adv.select('a.link'),
            }

            for key, value in data.items():
                if value:
                    data[key] = value[0].get_text()
                else:
                    data[key] = None

                # data[key] = value[0].get_text() if value else None

            if data['date']:
                day, time = (data['date'].split(' alle '))
                
                if day.startswith('Oggi'):
                    data['date'] = dt.date.today()
                elif day.startswith('Ieri'):
                    data['date'] = dt.date.today() + dt.timedelta(days=1)
                else:
                    date_adv = datetime.strptime(day, '%d %b')
                    this_year = date.today().year
                    if date.today().month > date_adv.month or \
                            (date.today().day > date_adv.day and \
                            date.today().month > date_adv.month):

                        data['date'] = date_adv.replace(year=this_year)
                    else:
                        data['date'] = date_adv.replace(year=this_year - 1)
            
            data.update({
                'price': data['price']
                        .replace('\xa0€', '')
                        .replace('Spedizione disponibile', '')
                        .replace('Venduto', ''),  # ) if data['price'] else None,
                'url': adv.select('a.link')[0]['href'],
            })
            
            items.append(data)
        
    return items

curr_page = 1
all_data = []

while True:
    # Se la max_page non è impostata oppure non si è ancora raggiunta la max_page
    if not max_page or curr_page <= max_page:
        try:
            items = scrape_page(curr_page)
        except requests.RequestException as err:
            print(err)
            break
        
        all_data += items
        curr_page += 1
        sleep(uniform(1, 4))
    else:
        break
    
print('N. pagine analizzate:', curr_page - 1)
pprint(all_data)
# Out:
# Si è raggiunta la pagina n. 3 e qui non ci sono più risultati.
# N. pagine analizzate: 2
# [{'city': '(VR)',
#   'date': datetime.datetime(2023, 5, 30, 0, 0),
#   'name': 'Sinclair ZX Spectrum 48k personal computer',
#   'price': '500',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Nogarole Rocca ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-48k-personal-computer-verona-495121453.htm'},
#  {'city': '(PV)',
#   'date': datetime.datetime(2023, 5, 29, 0, 0),
#   'name': 'Zx spectrum+2 128k sinclair',
#   'price': '300',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pavia ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-2-128k-sinclair-pavia-494925569.htm'},
#  {'city': '(VE)',
#   'date': datetime.datetime(2023, 5, 28, 0, 0),
#   'name': 'ZX Spectrum SINCLAIR',
#   'price': '220',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Noventa di Piave ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-venezia-494813174.htm'},
#  {'city': '(TO)',
#   'date': datetime.datetime(2023, 5, 28, 0, 0),
#   'name': 'Sinclair ZX Spectrum 16kb',
#   'price': '550',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Torino ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-16kb-torino-494749976.htm'},
#  {'city': '(SA)',
#   'date': datetime.datetime(2023, 5, 27, 0, 0),
#   'name': 'Disco 2tb Batocera v36',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pagani ',
#   'url': 'https://www.subito.it/informatica/disco-2tb-batocera-v36-salerno-494644761.htm'},
#  {'city': '(SA)',
#   'date': datetime.datetime(2023, 5, 27, 0, 0),
#   'name': 'Disco 2tb Batocera',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Pagani ',
#   'url': 'https://www.subito.it/informatica/disco-2tb-batocera-salerno-494643854.htm'},
#  {'city': '(PD)',
#   'date': datetime.datetime(2023, 5, 26, 0, 0),
#   'name': 'Sinclair ZX Spectrum 48k',
#   'price': '280',
#   'shipping': None,
#   'sold': None,
#   'town': 'Villafranca Padovana ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-padova-439106844.htm'},
#  {'city': '(SA)',
#   'date': datetime.datetime(2023, 5, 25, 0, 0),
#   'name': 'Computer sinclair zx spectrum 48k - testato 100%',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Salerno ',
#   'url': 'https://www.subito.it/informatica/computer-sinclair-zx-spectrum-48k-testato-100-salerno-494306297.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 5, 25, 0, 0),
#   'name': 'Zx spectrum plus Sinclair',
#   'price': '200',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/hobby-collezionismo/zx-spectrum-plus-sinclair-roma-368244153.htm'},
#  {'city': '(MI)',
#   'date': datetime.datetime(2023, 5, 24, 0, 0),
#   'name': 'Zx Spectrum 48 K Sinclair',
#   'price': '99',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48-k-sinclair-milano-494232621.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 5, 19, 0, 0),
#   'name': 'SINCLAIR ZX SPECTRUM 48 K originale con scatola',
#   'price': '220',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48-k-originale-con-scatola-roma-405871112.htm'},
#  {'city': '(VR)',
#   'date': datetime.datetime(2023, 5, 17, 0, 0),
#   'name': 'Giochi per Sinclair ZX Spectrum',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Verona ',
#   'url': 'https://www.subito.it/videogiochi/giochi-per-sinclair-zx-spectrum-verona-418137442.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 5, 7, 0, 0),
#   'name': 'Sinclair ZX Spectrum + 48K',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Monterotondo ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-roma-491135103.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Sinclair ZX Spectrum Plus +2 Computer 128K Vintage',
#   'price': '130',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-plus-2-computer-128k-vintage-taranto-490609627.htm'},
#  {'city': '(AN)',
#   'date': datetime.datetime(2023, 4, 28, 0, 0),
#   'name': 'ZX SPECTRUM Personal Computer',
#   'price': '180',
#   'shipping': None,
#   'sold': None,
#   'town': 'Chiaravalle ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-personal-computer-ancona-312557879.htm'},
#  {'city': '(MB)',
#   'date': datetime.datetime(2023, 4, 26, 0, 0),
#   'name': 'Copertina "Zub" per Sinclair Zx Spectrum 128k',
#   'price': '2',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Sovico ',
#   'url': 'https://www.subito.it/videogiochi/copertina-zub-per-sinclair-zx-spectrum-128k-monza-305924094.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 4, 25, 0, 0),
#   'name': 'Sinclair zx spectrum 48k +',
#   'price': '60',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Velletri ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-roma-489145320.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 4, 24, 0, 0),
#   'name': 'Sinclair zx spectrum 48k',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Velletri ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-roma-489044421.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'SINCLAIR ZX Spectrum',
#   'price': '70',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-torino-488011457.htm'},
#  {'city': '(VT)',
#   'date': datetime.datetime(2023, 4, 16, 0, 0),
#   'name': 'ZX Spectrum + Sinclair 48k',
#   'price': '250',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Viterbo ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-48k-viterbo-487644953.htm'},
#  {'city': '(TS)',
#   'date': datetime.datetime(2023, 4, 9, 0, 0),
#   'name': 'Cassetta Sinclair per ZX Spectrum - User Guide',
#   'price': '4',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Trieste ',
#   'url': 'https://www.subito.it/videogiochi/cassetta-sinclair-per-zx-spectrum-user-guide-trieste-149986531.htm'},
#  {'city': '(BO)',
#   'date': datetime.datetime(2023, 4, 7, 0, 0),
#   'name': 'Sinclair Spectrum',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Bologna ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-spectrum-bologna-431858201.htm'},
#  {'city': '(BG)',
#   'date': datetime.datetime(2023, 4, 3, 0, 0),
#   'name': 'Sinclair ZX Spectrum No Commodore',
#   'price': '11',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Grumello del Monte ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-no-commodore-bergamo-485710561.htm'},
#  {'city': '(TO)',
#   'date': datetime.datetime(2023, 3, 31, 0, 0),
#   'name': 'Zx spectrum',
#   'price': '110',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Prascorsano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-torino-485261771.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 3, 27, 0, 0),
#   'name': 'Spectrum Graphic pen penna grafica pc Sinclair',
#   'price': '65',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/spectrum-graphic-pen-penna-grafica-pc-sinclair-roma-405001759.htm'},
#  {'city': '(GE)',
#   'date': datetime.datetime(2023, 3, 26, 0, 0),
#   'name': 'Sinclair ZX Spectrum 48K',
#   'price': '130',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Genova ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-genova-402521305.htm'},
#  {'city': '(MI)',
#   'date': datetime.datetime(2023, 3, 26, 0, 0),
#   'name': 'Cavo scart rgb per zx spectrum 128k +2a +2b +3',
#   'price': '21',
#   'shipping': None,
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/audio-video/cavo-scart-rgb-per-zx-spectrum-128k-2a-2b-3-milano-484276857.htm'},
#  {'city': '(FI)',
#   'date': datetime.datetime(2023, 3, 23, 0, 0),
#   'name': 'Zx spectrum 48k',
#   'price': '120',
#   'shipping': None,
#   'sold': None,
#   'town': 'Firenze ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-48k-firenze-483776709.htm'},
#  {'city': '(BO)',
#   'date': datetime.datetime(2023, 3, 22, 0, 0),
#   'name': 'Giochi commodore spectrum c16 msx',
#   'price': '20',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Crevalcore ',
#   'url': 'https://www.subito.it/videogiochi/giochi-commodore-spectrum-c16-msx-bologna-402734509.htm'},
#  {'city': '(CN)',
#   'date': datetime.datetime(2023, 3, 21, 0, 0),
#   'name': 'Computer ZX Spectrum+ Sinclair vintage',
#   'price': '110',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Savigliano ',
#   'url': 'https://www.subito.it/videogiochi/computer-zx-spectrum-sinclair-vintage-cuneo-483450331.htm'},
#  {'city': '(MI)',
#   'date': datetime.datetime(2023, 3, 20, 0, 0),
#   'name': 'Scart sinclair zx spectrum+ 128k e spectrum +2 gre',
#   'price': '23',
#   'shipping': None,
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/audio-video/scart-sinclair-zx-spectrum-128k-e-spectrum-2-gre-milano-483389940.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 3, 17, 0, 0),
#   'name': 'Sinclair ZX Spectrum Plus',
#   'price': '250',
#   'shipping': None,
#   'sold': None,
#   'town': 'Monterotondo ',
#   'url': 'https://www.subito.it/informatica/sinclair-zx-spectrum-plus-roma-482794823.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 3, 7, 0, 0),
#   'name': 'Commodore Spectrum',
#   'price': '100',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/commodore-spectrum-roma-481241730.htm'},
#  {'city': '(VE)',
#   'date': datetime.datetime(2023, 3, 4, 0, 0),
#   'name': 'ZX Spectrum+ Sinclair',
#   'price': '145',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Mirano ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-venezia-480788972.htm'},
#  {'city': '(TO)',
#   'date': datetime.datetime(2023, 2, 23, 0, 0),
#   'name': 'Personal Computer Sincler ZX Spectrum plus',
#   'price': '180',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Villastellone ',
#   'url': 'https://www.subito.it/videogiochi/personal-computer-sincler-zx-spectrum-plus-torino-479325943.htm'},
#  {'city': '(MO)',
#   'date': datetime.datetime(2023, 2, 17, 0, 0),
#   'name': 'VideoBasic',
#   'price': '50',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Carpi ',
#   'url': 'https://www.subito.it/videogiochi/videobasic-modena-478205750.htm'},
#  {'city': '(IS)',
#   'date': datetime.datetime(2023, 2, 11, 0, 0),
#   'name': 'Spectrum Sinclair Zx+',
#   'price': '300',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Isernia ',
#   'url': 'https://www.subito.it/videogiochi/spectrum-sinclair-zx-isernia-477210891.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2023, 2, 9, 0, 0),
#   'name': 'ZX Spectrum Sinclair 48K Yellow Board + Extras',
#   'price': '349',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Roma ',
#   'url': 'https://www.subito.it/videogiochi/zx-spectrum-sinclair-48k-yellow-board-extras-roma-476883237.htm'},
#  {'city': '(CS)',
#   'date': datetime.datetime(2023, 1, 22, 0, 0),
#   'name': 'Cassette originali Special Program C64 - Sinclair',
#   'price': '9',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Cetraro ',
#   'url': 'https://www.subito.it/videogiochi/cassette-originali-special-program-c64-sinclair-cosenza-474109023.htm'},
#  {'city': '(BO)',
#   'date': datetime.datetime(2023, 1, 16, 0, 0),
#   'name': 'Spectrum Sinclair',
#   'price': '120',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': "Granarolo dell'Emilia ",
#   'url': 'https://www.subito.it/videogiochi/spectrum-sinclair-bologna-473192708.htm'},
#  {'city': '(MI)',
#   'date': datetime.datetime(2023, 1, 15, 0, 0),
#   'name': 'Arcade Box emulatore consolle',
#   'price': '119',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Rho ',
#   'url': 'https://www.subito.it/videogiochi/arcade-box-emulatore-consolle-milano-473086115.htm'},
#  {'city': '(MB)',
#   'date': datetime.datetime(2023, 1, 6, 0, 0),
#   'name': 'Adesivo Spectrum Sinclair vintage anni 80',
#   'price': '10',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Bovisio-Masciago ',
#   'url': 'https://www.subito.it/hobby-collezionismo/adesivo-spectrum-sinclair-vintage-anni-80-monza-471755508.htm'},
#  {'city': '(TO)',
#   'date': datetime.datetime(2022, 12, 31, 0, 0),
#   'name': 'Toshiba T2000SXe',
#   'price': '150',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Ivrea ',
#   'url': 'https://www.subito.it/informatica/toshiba-t2000sxe-torino-470947803.htm'},
#  {'city': '(SA)',
#   'date': datetime.datetime(2022, 12, 12, 0, 0),
#   'name': "Sinclair zx spectrum plus, pc vintage ANNI '80",
#   'price': '120',
#   'shipping': None,
#   'sold': None,
#   'town': 'Angri ',
#   'url': 'https://www.subito.it/arredamento-casalinghi/sinclair-zx-spectrum-plus-pc-vintage-anni-80-salerno-468690856.htm'},
#  {'city': '(FE)',
#   'date': datetime.datetime(2022, 12, 8, 0, 0),
#   'name': 'computerclub spectrum c64',
#   'price': '20',
#   'shipping': None,
#   'sold': None,
#   'town': 'Cento ',
#   'url': 'https://www.subito.it/libri-riviste/computerclub-spectrum-c64-ferrara-468193289.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'ZX spectrum 48 kb',
#   'price': '80',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48-kb-ancona-467908654.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2022, 12, 4, 0, 0),
#   'name': 'Sinclair spectrum',
#   'price': '500',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Fiumicino ',
#   'url': 'https://www.subito.it/informatica/sinclair-spectrum-roma-467565586.htm'},
#  {'city': '(PD)',
#   'date': datetime.datetime(2022, 11, 26, 0, 0),
#   'name': 'Joystick Albatros come nuovo',
#   'price': '99',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Brugine ',
#   'url': 'https://www.subito.it/videogiochi/joystick-albatros-come-nuovo-padova-466527291.htm'},
#  {'city': '(PD)',
#   'date': datetime.datetime(2022, 10, 29, 0, 0),
#   'name': 'Sinclair ZX Spectrum 48K come nuovo',
#   'price': '240',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Brugine ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-48k-come-nuovo-padova-462616275.htm'},
#  {'city': '(RM)',
#   'date': datetime.datetime(2022, 10, 14, 0, 0),
#   'name': 'Rom LEC80 per ZX Spectrum espanso 80KB RAM',
#   'price': '14',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Velletri ',
#   'url': 'https://www.subito.it/informatica/rom-lec80-per-zx-spectrum-espanso-80kb-ram-roma-460420802.htm'},
#  {'city': '(MI)',
#   'date': datetime.datetime(2022, 10, 9, 0, 0),
#   'name': 'ZX spectrum 48k',
#   'price': '250',
#   'shipping': 'Spedizione disponibile',
#   'sold': None,
#   'town': 'Milano ',
#   'url': 'https://www.subito.it/informatica/zx-spectrum-48k-milano-459729529.htm'},
#  {'city': '(FI)',
#   'date': datetime.datetime(2022, 9, 13, 0, 0),
#   'name': 'Sinclair zx spectrum +',
#   'price': '200',
#   'shipping': None,
#   'sold': None,
#   'town': 'Borgo San Lorenzo ',
#   'url': 'https://www.subito.it/videogiochi/sinclair-zx-spectrum-firenze-455901201.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Sinclair Spectrum +2a/+3 Cavo Scart RGB Cable',
#   'price': '30',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/informatica/sinclair-spectrum-2a-3-cavo-scart-rgb-cable-rieti-452955323.htm'},
#  {'city': '(PD)',
#   'date': datetime.datetime(2022, 8, 20, 0, 0),
#   'name': 'Spectrum sinclair QL varie',
#   'price': '',
#   'shipping': None,
#   'sold': None,
#   'town': 'Este ',
#   'url': 'https://www.subito.it/informatica/spectrum-sinclair-ql-varie-padova-452344819.htm'},
#  {'city': None,
#   'date': None,
#   'name': 'Sinclair ZX Spectrum plus',
#   'price': '120',
#   'shipping': None,
#   'sold': 'Venduto',
#   'town': None,
#   'url': 'https://www.subito.it/hobby-collezionismo/sinclair-zx-spectrum-plus-aosta-451087337.htm'},
#  {'city': '(IS)',
#   'date': datetime.datetime(2022, 7, 14, 0, 0),
#   'name': 'Personal Computer vintage SinclairZX Spectrum 16K',
#   'price': '200',
#   'shipping': None,
#   'sold': None,
#   'town': 'Isernia ',
#   'url': 'https://www.subito.it/annunci-vari/personal-computer-vintage-sinclairzx-spectrum-16k-isernia-447539260.htm'},
#  {'city': '(VR)',
#   'date': datetime.datetime(2022, 6, 22, 0, 0),
#   'name': 'Computer vintage Olivetti e IBM',
#   'price': '1',
#   'shipping': None,
#   'sold': None,
#   'town': 'Verona ',
#   'url': 'https://www.subito.it/informatica/computer-vintage-olivetti-e-ibm-verona-444062014.htm'}]
