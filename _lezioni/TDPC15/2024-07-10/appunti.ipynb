# %% [markdown]
# ## Indice delle lezioni e argomenti trattati
#
# [INDICE DELLE LEZIONI](../README.md)

# %% [markdown]
# ## draw.io
#
# - Sito dove scaricare l'app: https://www.drawio.com/
#
# - Web-app per uso online: https://app.diagrams.net/

# %% [markdown]
# ## Diagramma applicazione "gruppo di acquisto"
#
# Vedi file draw.io: [caso_uso_app_GAS.drawio](caso_uso_app_GAS.drawio)
#
#
# ![caso_uso_app_GAS.png](attachment:caso_uso_app_GAS.png)
