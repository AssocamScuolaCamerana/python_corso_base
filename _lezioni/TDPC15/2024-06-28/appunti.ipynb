# %% [markdown]
# ## VEDI REPOSITORY BACKEND
#
# Tutte le lezioni sul backend con Flask le abbiamo riaportate e ordinate nel repository ad hoc:
#
# https://github.com/camerana-tdpc15/backend

# %% [markdown]
# ## Guestbook con DB
#
# ![guestbook_db_diagram.jpg](attachment:guestbook_db_diagram.jpg)

# %% [markdown]
# ## Draw.io
#
# Il diagramma dello schema del database è stato realizzato con draw.io:
#
# https://draw.io

# %% [markdown]
# ## Flask-DebugToolbar
#
# https://github.com/pallets-eco/flask-debugtoolbar

# %% [markdown]
# ## SQLAlchemy-serializer
#
# https://github.com/n0nSmoker/SQLAlchemy-serializer
